# %%
#********************
# Name: Jonah Zembower
# Project: Harvard Research Study on Postural Stability during Heart Catheterization Surgeries
# Date: January 19, 2025
#********************

# %%
# Import all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the Data

# %%
# Load the APDF data for each case
case_1_001_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\001\\001_case1.xlsx', sheet_name = 'APDF 1')
case_2_001_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\001\\001_case2.xlsx', sheet_name = 'APDF 2')
case_4_001_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\001\\001_case4.xlsx', sheet_name = 'APDF 4')
case_6_001_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\001\\001_case6.xlsx', sheet_name = 'APDF 6')
case_1_002_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\002\\002_case1.xlsx', sheet_name = 'APDF 1')
case_2_002_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\002\\002_case2.xlsx', sheet_name = 'APDF 2')
case_3_002_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\002\\002_case3.xlsx', sheet_name = 'APDF 3')
case_4_002_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\002\\002_case4.xlsx', sheet_name = 'APDF 4')
case_1_003_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\003\\003_case1.xlsx', sheet_name = 'APDF 1')
case_2_003_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\003\\003_case2.xlsx', sheet_name = 'APDF 2')
case_4_003_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\003\\003_case4.xlsx', sheet_name = 'APDF 4')
case_1_004_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\004\\004_case1.xlsx', sheet_name = 'APDF 1')
case_3_004_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\004\\004_case3.xlsx', sheet_name = 'APDF 3')
case_4_004_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\004\\004_case4.xlsx', sheet_name = 'APDF 4')
case_1_005_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\005\\005_case1.xlsx', sheet_name = 'APDF 1')
case_3_005_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\005\\005_case3.xlsx', sheet_name = 'APDF 3')
case_4_005_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\005\\005_case4.xlsx', sheet_name = 'APDF 4')
case_5_005_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\005\\005_case5.xlsx', sheet_name = 'APDF 5')
case_1_006_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\006\\006_case1.xlsx', sheet_name = 'APDF 1')
case_2_006_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\006\\006_case2.xlsx', sheet_name = 'APDF 2')
case_3_006_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\006\\006_case3.xlsx', sheet_name = 'APDF 3')
case_4_006_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\006\\006_case4.xlsx', sheet_name = 'APDF 4')
case_1_007_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\007\\007_case1.xlsx', sheet_name = 'APDF 1')
case_2_007_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\007\\007_case2.xlsx', sheet_name = 'APDF 2')
case_3_007_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\007\\007_case3.xlsx', sheet_name = 'APDF 3')
case_4_007_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\007\\007_case4.xlsx', sheet_name = 'APDF 4')
case_1_008_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\008\\008_case1.xlsx', sheet_name = 'APDF 1')
case_2_008_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\008\\008_case2.xlsx', sheet_name = 'APDF 2')
case_3_008_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\008\\008_case3.xlsx', sheet_name = 'APDF 3')
case_4_008_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\008\\008_case4.xlsx', sheet_name = 'APDF 4')
case_1_019_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\019\\019_case1.xlsx', sheet_name = 'APDF 1')
case_2_019_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\019\\019_case2.xlsx', sheet_name = 'APDF 2')
case_3_019_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\019\\019_case3.xlsx', sheet_name = 'APDF 3')
case_4_019_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\019\\019_case4.xlsx', sheet_name = 'APDF 4')
case_1_020_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\020\\020_case1.xlsx', sheet_name = 'APDF 1')
case_2_020_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\020\\020_case2.xlsx', sheet_name = 'APDF 2')
case_1_021_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\021\\021_case1.xlsx', sheet_name = 'APDF 1')
case_2_021_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\021\\021_case2.xlsx', sheet_name = 'APDF 2')
case_1_022_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\022\\022_case1.xlsx', sheet_name = 'APDF 1')
case_2_022_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\022\\022_case2.xlsx', sheet_name = 'APDF 2')
case_3_022_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\022\\022_case3.xlsx', sheet_name = 'APDF 3')
case_4_022_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\022\\022_case4.xlsx', sheet_name = 'APDF 4')
case_1_023_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\023\\023_case1.xlsx', sheet_name = 'APDF 1')
case_2_023_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\023\\023_case2.xlsx', sheet_name = 'APDF 2')
case_4_023_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\023\\023_case4.xlsx', sheet_name = 'APDF 4')
case_1_024_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\024\\024_case1.xlsx', sheet_name = 'APDF 1')
case_2_024_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\024\\024_case2.xlsx', sheet_name = 'APDF 2')
case_1_026_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\026\\026_case1.xlsx', sheet_name = 'APDF 1')
case_2_026_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\026\\026_case2.xlsx', sheet_name = 'APDF 2')
case_1_027_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\027\\027_case1.xlsx', sheet_name = 'APDF 1')
case_2_027_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\027\\027_case2.xlsx', sheet_name = 'APDF 2')
case_1_028_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\028\\028_case1.xlsx', sheet_name = 'APDF 1')
case_2_028_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\028\\028_case2.xlsx', sheet_name = 'APDF 2')
case_1_029_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\029\\029_case1.xlsx', sheet_name = 'APDF 1')
case_2_029_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\029\\029_case2.xlsx', sheet_name = 'APDF 2')
case_1_030_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\030\\030_case1.xlsx', sheet_name = 'APDF 1')
case_2_030_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\030\\030_case2.xlsx', sheet_name = 'APDF 2')
case_3_030_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\030\\030_case3.xlsx', sheet_name = 'APDF 3')
case_1_031_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\031\\031_case1.xlsx', sheet_name = 'APDF 1')
case_2_031_APDF = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\031\\031_case2.xlsx', sheet_name = 'APDF 2')

# %% [markdown]
# #### Extract the data from each APDF to get for the future CSVs related to each Time[Ch. units] related to the different case subjects.

# %%
# Extract APDF data for each case of subject 001
Time_00_001_1 = case_1_001_APDF.iloc[0,1:].astype(float)
Time_01_001_1 = case_1_001_APDF.iloc[1,1:].astype(float)
Time_02_001_1 = case_1_001_APDF.iloc[2,1:].astype(float)
Time_03_001_1 = case_1_001_APDF.iloc[3,1:].astype(float)
Time_04_001_1 = case_1_001_APDF.iloc[4,1:].astype(float)
Time_05_001_1 = case_1_001_APDF.iloc[5,1:].astype(float)
Time_06_001_1 = case_1_001_APDF.iloc[6,1:].astype(float)
Time_07_001_1 = case_1_001_APDF.iloc[7,1:].astype(float)
Time_08_001_1 = case_1_001_APDF.iloc[8,1:].astype(float)
Time_09_001_1 = case_1_001_APDF.iloc[9,1:].astype(float)
Time_10_001_1 = case_1_001_APDF.iloc[10,1:].astype(float)
Time_00_001_2 = case_2_001_APDF.iloc[0,1:].astype(float)
Time_01_001_2 = case_2_001_APDF.iloc[1,1:].astype(float)
Time_02_001_2 = case_2_001_APDF.iloc[2,1:].astype(float)
Time_03_001_2 = case_2_001_APDF.iloc[3,1:].astype(float)
Time_04_001_2 = case_2_001_APDF.iloc[4,1:].astype(float)
Time_05_001_2 = case_2_001_APDF.iloc[5,1:].astype(float)
Time_06_001_2 = case_2_001_APDF.iloc[6,1:].astype(float)
Time_07_001_2 = case_2_001_APDF.iloc[7,1:].astype(float)
Time_08_001_2 = case_2_001_APDF.iloc[8,1:].astype(float)
Time_09_001_2 = case_2_001_APDF.iloc[9,1:].astype(float)
Time_10_001_2 = case_2_001_APDF.iloc[10,1:].astype(float)
Time_00_001_4 = case_4_001_APDF.iloc[0,1:].astype(float)
Time_01_001_4 = case_4_001_APDF.iloc[1,1:].astype(float)
Time_02_001_4 = case_4_001_APDF.iloc[2,1:].astype(float)
Time_03_001_4 = case_4_001_APDF.iloc[3,1:].astype(float)
Time_04_001_4 = case_4_001_APDF.iloc[4,1:].astype(float)
Time_05_001_4 = case_4_001_APDF.iloc[5,1:].astype(float)
Time_06_001_4 = case_4_001_APDF.iloc[6,1:].astype(float)
Time_07_001_4 = case_4_001_APDF.iloc[7,1:].astype(float)
Time_08_001_4 = case_4_001_APDF.iloc[8,1:].astype(float)
Time_09_001_4 = case_4_001_APDF.iloc[9,1:].astype(float)
Time_10_001_4 = case_4_001_APDF.iloc[10,1:].astype(float)
Time_00_001_6 = case_6_001_APDF.iloc[0,1:].astype(float)
Time_01_001_6 = case_6_001_APDF.iloc[1,1:].astype(float)
Time_02_001_6 = case_6_001_APDF.iloc[2,1:].astype(float)
Time_03_001_6 = case_6_001_APDF.iloc[3,1:].astype(float)
Time_04_001_6 = case_6_001_APDF.iloc[4,1:].astype(float)
Time_05_001_6 = case_6_001_APDF.iloc[5,1:].astype(float)
Time_06_001_6 = case_6_001_APDF.iloc[6,1:].astype(float)
Time_07_001_6 = case_6_001_APDF.iloc[7,1:].astype(float)
Time_08_001_6 = case_6_001_APDF.iloc[8,1:].astype(float)
Time_09_001_6 = case_6_001_APDF.iloc[9,1:].astype(float)
Time_10_001_6 = case_6_001_APDF.iloc[10,1:].astype(float)

# %%
# Extract APDF data for each case of subject 002
Time_00_002_1 = case_1_002_APDF.iloc[0,1:].astype(float)
Time_01_002_1 = case_1_002_APDF.iloc[1,1:].astype(float)
Time_02_002_1 = case_1_002_APDF.iloc[2,1:].astype(float)
Time_03_002_1 = case_1_002_APDF.iloc[3,1:].astype(float)
Time_04_002_1 = case_1_002_APDF.iloc[4,1:].astype(float)
Time_05_002_1 = case_1_002_APDF.iloc[5,1:].astype(float)
Time_06_002_1 = case_1_002_APDF.iloc[6,1:].astype(float)
Time_07_002_1 = case_1_002_APDF.iloc[7,1:].astype(float)
Time_08_002_1 = case_1_002_APDF.iloc[8,1:].astype(float)
Time_09_002_1 = case_1_002_APDF.iloc[9,1:].astype(float)
Time_10_002_1 = case_1_002_APDF.iloc[10,1:].astype(float)
Time_00_002_2 = case_2_002_APDF.iloc[0,1:].astype(float)
Time_01_002_2 = case_2_002_APDF.iloc[1,1:].astype(float)
Time_02_002_2 = case_2_002_APDF.iloc[2,1:].astype(float)
Time_03_002_2 = case_2_002_APDF.iloc[3,1:].astype(float)
Time_04_002_2 = case_2_002_APDF.iloc[4,1:].astype(float)
Time_05_002_2 = case_2_002_APDF.iloc[5,1:].astype(float)
Time_06_002_2 = case_2_002_APDF.iloc[6,1:].astype(float)
Time_07_002_2 = case_2_002_APDF.iloc[7,1:].astype(float)
Time_08_002_2 = case_2_002_APDF.iloc[8,1:].astype(float)
Time_09_002_2 = case_2_002_APDF.iloc[9,1:].astype(float)
Time_10_002_2 = case_2_002_APDF.iloc[10,1:].astype(float)
Time_00_002_3 = case_3_002_APDF.iloc[0,1:].astype(float)
Time_01_002_3 = case_3_002_APDF.iloc[1,1:].astype(float)
Time_02_002_3 = case_3_002_APDF.iloc[2,1:].astype(float)
Time_03_002_3 = case_3_002_APDF.iloc[3,1:].astype(float)
Time_04_002_3 = case_3_002_APDF.iloc[4,1:].astype(float)
Time_05_002_3 = case_3_002_APDF.iloc[5,1:].astype(float)
Time_06_002_3 = case_3_002_APDF.iloc[6,1:].astype(float)
Time_07_002_3 = case_3_002_APDF.iloc[7,1:].astype(float)
Time_08_002_3 = case_3_002_APDF.iloc[8,1:].astype(float)
Time_09_002_3 = case_3_002_APDF.iloc[9,1:].astype(float)
Time_10_002_3 = case_3_002_APDF.iloc[10,1:].astype(float)
Time_00_002_4 = case_4_002_APDF.iloc[0,1:].astype(float)
Time_01_002_4 = case_4_002_APDF.iloc[1,1:].astype(float)
Time_02_002_4 = case_4_002_APDF.iloc[2,1:].astype(float)
Time_03_002_4 = case_4_002_APDF.iloc[3,1:].astype(float)
Time_04_002_4 = case_4_002_APDF.iloc[4,1:].astype(float)
Time_05_002_4 = case_4_002_APDF.iloc[5,1:].astype(float)
Time_06_002_4 = case_4_002_APDF.iloc[6,1:].astype(float)
Time_07_002_4 = case_4_002_APDF.iloc[7,1:].astype(float)
Time_08_002_4 = case_4_002_APDF.iloc[8,1:].astype(float)
Time_09_002_4 = case_4_002_APDF.iloc[9,1:].astype(float)
Time_10_002_4 = case_4_002_APDF.iloc[10,1:].astype(float)

# %%
# Extract APDF data for each case of subject 003
Time_00_003_1 = case_1_003_APDF.iloc[0,1:].astype(float)
Time_01_003_1 = case_1_003_APDF.iloc[1,1:].astype(float)
Time_02_003_1 = case_1_003_APDF.iloc[2,1:].astype(float)
Time_03_003_1 = case_1_003_APDF.iloc[3,1:].astype(float)
Time_04_003_1 = case_1_003_APDF.iloc[4,1:].astype(float)
Time_05_003_1 = case_1_003_APDF.iloc[5,1:].astype(float)
Time_06_003_1 = case_1_003_APDF.iloc[6,1:].astype(float)
Time_07_003_1 = case_1_003_APDF.iloc[7,1:].astype(float)
Time_08_003_1 = case_1_003_APDF.iloc[8,1:].astype(float)
Time_09_003_1 = case_1_003_APDF.iloc[9,1:].astype(float)
Time_10_003_1 = case_1_003_APDF.iloc[10,1:].astype(float)
Time_00_003_2 = case_2_003_APDF.iloc[0,1:].astype(float)
Time_01_003_2 = case_2_003_APDF.iloc[1,1:].astype(float)
Time_02_003_2 = case_2_003_APDF.iloc[2,1:].astype(float)
Time_03_003_2 = case_2_003_APDF.iloc[3,1:].astype(float)
Time_04_003_2 = case_2_003_APDF.iloc[4,1:].astype(float)
Time_05_003_2 = case_2_003_APDF.iloc[5,1:].astype(float)
Time_06_003_2 = case_2_003_APDF.iloc[6,1:].astype(float)
Time_07_003_2 = case_2_003_APDF.iloc[7,1:].astype(float)
Time_08_003_2 = case_2_003_APDF.iloc[8,1:].astype(float)
Time_09_003_2 = case_2_003_APDF.iloc[9,1:].astype(float)
Time_10_003_2 = case_2_003_APDF.iloc[10,1:].astype(float)
Time_00_003_4 = case_4_003_APDF.iloc[0,1:].astype(float)
Time_01_003_4 = case_4_003_APDF.iloc[1,1:].astype(float)
Time_02_003_4 = case_4_003_APDF.iloc[2,1:].astype(float)
Time_03_003_4 = case_4_003_APDF.iloc[3,1:].astype(float)
Time_04_003_4 = case_4_003_APDF.iloc[4,1:].astype(float)
Time_05_003_4 = case_4_003_APDF.iloc[5,1:].astype(float)
Time_06_003_4 = case_4_003_APDF.iloc[6,1:].astype(float)
Time_07_003_4 = case_4_003_APDF.iloc[7,1:].astype(float)
Time_08_003_4 = case_4_003_APDF.iloc[8,1:].astype(float)
Time_09_003_4 = case_4_003_APDF.iloc[9,1:].astype(float)
Time_10_003_4 = case_4_003_APDF.iloc[10,1:].astype(float)

# %%
# Extract APDF data for each case of subject 004
Time_00_004_1 = case_1_004_APDF.iloc[0,1:].astype(float)
Time_01_004_1 = case_1_004_APDF.iloc[1,1:].astype(float)
Time_02_004_1 = case_1_004_APDF.iloc[2,1:].astype(float)
Time_03_004_1 = case_1_004_APDF.iloc[3,1:].astype(float)
Time_04_004_1 = case_1_004_APDF.iloc[4,1:].astype(float)
Time_05_004_1 = case_1_004_APDF.iloc[5,1:].astype(float)
Time_06_004_1 = case_1_004_APDF.iloc[6,1:].astype(float)
Time_07_004_1 = case_1_004_APDF.iloc[7,1:].astype(float)
Time_08_004_1 = case_1_004_APDF.iloc[8,1:].astype(float)
Time_09_004_1 = case_1_004_APDF.iloc[9,1:].astype(float)
Time_10_004_1 = case_1_004_APDF.iloc[10,1:].astype(float)
Time_00_004_3 = case_3_004_APDF.iloc[0,1:].astype(float)
Time_01_004_3 = case_3_004_APDF.iloc[1,1:].astype(float)
Time_02_004_3 = case_3_004_APDF.iloc[2,1:].astype(float)
Time_03_004_3 = case_3_004_APDF.iloc[3,1:].astype(float)
Time_04_004_3 = case_3_004_APDF.iloc[4,1:].astype(float)
Time_05_004_3 = case_3_004_APDF.iloc[5,1:].astype(float)
Time_06_004_3 = case_3_004_APDF.iloc[6,1:].astype(float)
Time_07_004_3 = case_3_004_APDF.iloc[7,1:].astype(float)
Time_08_004_3 = case_3_004_APDF.iloc[8,1:].astype(float)
Time_09_004_3 = case_3_004_APDF.iloc[9,1:].astype(float)
Time_10_004_3 = case_3_004_APDF.iloc[10,1:].astype(float)
Time_00_004_4 = case_4_004_APDF.iloc[0,1:].astype(float)
Time_01_004_4 = case_4_004_APDF.iloc[1,1:].astype(float)
Time_02_004_4 = case_4_004_APDF.iloc[2,1:].astype(float)
Time_03_004_4 = case_4_004_APDF.iloc[3,1:].astype(float)
Time_04_004_4 = case_4_004_APDF.iloc[4,1:].astype(float)
Time_05_004_4 = case_4_004_APDF.iloc[5,1:].astype(float)
Time_06_004_4 = case_4_004_APDF.iloc[6,1:].astype(float)
Time_07_004_4 = case_4_004_APDF.iloc[7,1:].astype(float)
Time_08_004_4 = case_4_004_APDF.iloc[8,1:].astype(float)
Time_09_004_4 = case_4_004_APDF.iloc[9,1:].astype(float)
Time_10_004_4 = case_4_004_APDF.iloc[10,1:].astype(float)

# %%
# Extract APDF data for each case of subject 005
Time_00_005_1 = case_1_005_APDF.iloc[0,1:].astype(float)
Time_01_005_1 = case_1_005_APDF.iloc[1,1:].astype(float)
Time_02_005_1 = case_1_005_APDF.iloc[2,1:].astype(float)
Time_03_005_1 = case_1_005_APDF.iloc[3,1:].astype(float)
Time_04_005_1 = case_1_005_APDF.iloc[4,1:].astype(float)
Time_05_005_1 = case_1_005_APDF.iloc[5,1:].astype(float)
Time_06_005_1 = case_1_005_APDF.iloc[6,1:].astype(float)
Time_07_005_1 = case_1_005_APDF.iloc[7,1:].astype(float)
Time_08_005_1 = case_1_005_APDF.iloc[8,1:].astype(float)
Time_09_005_1 = case_1_005_APDF.iloc[9,1:].astype(float)
Time_10_005_1 = case_1_005_APDF.iloc[10,1:].astype(float)
Time_00_005_3 = case_3_005_APDF.iloc[0,1:].astype(float)
Time_01_005_3 = case_3_005_APDF.iloc[1,1:].astype(float)
Time_02_005_3 = case_3_005_APDF.iloc[2,1:].astype(float)
Time_03_005_3 = case_3_005_APDF.iloc[3,1:].astype(float)
Time_04_005_3 = case_3_005_APDF.iloc[4,1:].astype(float)
Time_05_005_3 = case_3_005_APDF.iloc[5,1:].astype(float)
Time_06_005_3 = case_3_005_APDF.iloc[6,1:].astype(float)
Time_07_005_3 = case_3_005_APDF.iloc[7,1:].astype(float)
Time_08_005_3 = case_3_005_APDF.iloc[8,1:].astype(float)
Time_09_005_3 = case_3_005_APDF.iloc[9,1:].astype(float)
Time_10_005_3 = case_3_005_APDF.iloc[10,1:].astype(float)
Time_00_005_4 = case_4_005_APDF.iloc[0,1:].astype(float)
Time_01_005_4 = case_4_005_APDF.iloc[1,1:].astype(float)
Time_02_005_4 = case_4_005_APDF.iloc[2,1:].astype(float)
Time_03_005_4 = case_4_005_APDF.iloc[3,1:].astype(float)
Time_04_005_4 = case_4_005_APDF.iloc[4,1:].astype(float)
Time_05_005_4 = case_4_005_APDF.iloc[5,1:].astype(float)
Time_06_005_4 = case_4_005_APDF.iloc[6,1:].astype(float)
Time_07_005_4 = case_4_005_APDF.iloc[7,1:].astype(float)
Time_08_005_4 = case_4_005_APDF.iloc[8,1:].astype(float)
Time_09_005_4 = case_4_005_APDF.iloc[9,1:].astype(float)
Time_10_005_4 = case_4_005_APDF.iloc[10,1:].astype(float)
Time_00_005_5 = case_5_005_APDF.iloc[0,1:].astype(float)
Time_01_005_5 = case_5_005_APDF.iloc[1,1:].astype(float)
Time_02_005_5 = case_5_005_APDF.iloc[2,1:].astype(float)
Time_03_005_5 = case_5_005_APDF.iloc[3,1:].astype(float)
Time_04_005_5 = case_5_005_APDF.iloc[4,1:].astype(float)
Time_05_005_5 = case_5_005_APDF.iloc[5,1:].astype(float)
Time_06_005_5 = case_5_005_APDF.iloc[6,1:].astype(float)
Time_07_005_5 = case_5_005_APDF.iloc[7,1:].astype(float)
Time_08_005_5 = case_5_005_APDF.iloc[8,1:].astype(float)
Time_09_005_5 = case_5_005_APDF.iloc[9,1:].astype(float)
Time_10_005_5 = case_5_005_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 006
Time_00_006_1 = case_1_006_APDF.iloc[0,1:].astype(float)
Time_01_006_1 = case_1_006_APDF.iloc[1,1:].astype(float)
Time_02_006_1 = case_1_006_APDF.iloc[2,1:].astype(float)
Time_03_006_1 = case_1_006_APDF.iloc[3,1:].astype(float)
Time_04_006_1 = case_1_006_APDF.iloc[4,1:].astype(float)
Time_05_006_1 = case_1_006_APDF.iloc[5,1:].astype(float)
Time_06_006_1 = case_1_006_APDF.iloc[6,1:].astype(float)
Time_07_006_1 = case_1_006_APDF.iloc[7,1:].astype(float)
Time_08_006_1 = case_1_006_APDF.iloc[8,1:].astype(float)
Time_09_006_1 = case_1_006_APDF.iloc[9,1:].astype(float)
Time_10_006_1 = case_1_006_APDF.iloc[10,1:].astype(float)
Time_00_006_2 = case_2_006_APDF.iloc[0,1:].astype(float)
Time_01_006_2 = case_2_006_APDF.iloc[1,1:].astype(float)
Time_02_006_2 = case_2_006_APDF.iloc[2,1:].astype(float)
Time_03_006_2 = case_2_006_APDF.iloc[3,1:].astype(float)
Time_04_006_2 = case_2_006_APDF.iloc[4,1:].astype(float)
Time_05_006_2 = case_2_006_APDF.iloc[5,1:].astype(float)
Time_06_006_2 = case_2_006_APDF.iloc[6,1:].astype(float)
Time_07_006_2 = case_2_006_APDF.iloc[7,1:].astype(float)
Time_08_006_2 = case_2_006_APDF.iloc[8,1:].astype(float)
Time_09_006_2 = case_2_006_APDF.iloc[9,1:].astype(float)
Time_10_006_2 = case_2_006_APDF.iloc[10,1:].astype(float)
Time_00_006_3 = case_3_006_APDF.iloc[0,1:].astype(float)
Time_01_006_3 = case_3_006_APDF.iloc[1,1:].astype(float)
Time_02_006_3 = case_3_006_APDF.iloc[2,1:].astype(float)
Time_03_006_3 = case_3_006_APDF.iloc[3,1:].astype(float)
Time_04_006_3 = case_3_006_APDF.iloc[4,1:].astype(float)
Time_05_006_3 = case_3_006_APDF.iloc[5,1:].astype(float)
Time_06_006_3 = case_3_006_APDF.iloc[6,1:].astype(float)
Time_07_006_3 = case_3_006_APDF.iloc[7,1:].astype(float)
Time_08_006_3 = case_3_006_APDF.iloc[8,1:].astype(float)
Time_09_006_3 = case_3_006_APDF.iloc[9,1:].astype(float)
Time_10_006_3 = case_3_006_APDF.iloc[10,1:].astype(float)
Time_00_006_4 = case_4_006_APDF.iloc[0,1:].astype(float)
Time_01_006_4 = case_4_006_APDF.iloc[1,1:].astype(float)
Time_02_006_4 = case_4_006_APDF.iloc[2,1:].astype(float)
Time_03_006_4 = case_4_006_APDF.iloc[3,1:].astype(float)
Time_04_006_4 = case_4_006_APDF.iloc[4,1:].astype(float)
Time_05_006_4 = case_4_006_APDF.iloc[5,1:].astype(float)
Time_06_006_4 = case_4_006_APDF.iloc[6,1:].astype(float)
Time_07_006_4 = case_4_006_APDF.iloc[7,1:].astype(float)
Time_08_006_4 = case_4_006_APDF.iloc[8,1:].astype(float)
Time_09_006_4 = case_4_006_APDF.iloc[9,1:].astype(float)
Time_10_006_4 = case_4_006_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 007
Time_00_007_1 = case_1_007_APDF.iloc[0,1:].astype(float)
Time_01_007_1 = case_1_007_APDF.iloc[1,1:].astype(float)
Time_02_007_1 = case_1_007_APDF.iloc[2,1:].astype(float)
Time_03_007_1 = case_1_007_APDF.iloc[3,1:].astype(float)
Time_04_007_1 = case_1_007_APDF.iloc[4,1:].astype(float)
Time_05_007_1 = case_1_007_APDF.iloc[5,1:].astype(float)
Time_06_007_1 = case_1_007_APDF.iloc[6,1:].astype(float)
Time_07_007_1 = case_1_007_APDF.iloc[7,1:].astype(float)
Time_08_007_1 = case_1_007_APDF.iloc[8,1:].astype(float)
Time_09_007_1 = case_1_007_APDF.iloc[9,1:].astype(float)
Time_10_007_1 = case_1_007_APDF.iloc[10,1:].astype(float)
Time_00_007_2 = case_2_007_APDF.iloc[0,1:].astype(float)
Time_01_007_2 = case_2_007_APDF.iloc[1,1:].astype(float)
Time_02_007_2 = case_2_007_APDF.iloc[2,1:].astype(float)
Time_03_007_2 = case_2_007_APDF.iloc[3,1:].astype(float)
Time_04_007_2 = case_2_007_APDF.iloc[4,1:].astype(float)
Time_05_007_2 = case_2_007_APDF.iloc[5,1:].astype(float)
Time_06_007_2 = case_2_007_APDF.iloc[6,1:].astype(float)
Time_07_007_2 = case_2_007_APDF.iloc[7,1:].astype(float)
Time_08_007_2 = case_2_007_APDF.iloc[8,1:].astype(float)
Time_09_007_2 = case_2_007_APDF.iloc[9,1:].astype(float)
Time_10_007_2 = case_2_007_APDF.iloc[10,1:].astype(float)
Time_00_007_3 = case_3_007_APDF.iloc[0,1:].astype(float)
Time_01_007_3 = case_3_007_APDF.iloc[1,1:].astype(float)
Time_02_007_3 = case_3_007_APDF.iloc[2,1:].astype(float)
Time_03_007_3 = case_3_007_APDF.iloc[3,1:].astype(float)
Time_04_007_3 = case_3_007_APDF.iloc[4,1:].astype(float)
Time_05_007_3 = case_3_007_APDF.iloc[5,1:].astype(float)
Time_06_007_3 = case_3_007_APDF.iloc[6,1:].astype(float)
Time_07_007_3 = case_3_007_APDF.iloc[7,1:].astype(float)
Time_08_007_3 = case_3_007_APDF.iloc[8,1:].astype(float)
Time_09_007_3 = case_3_007_APDF.iloc[9,1:].astype(float)
Time_10_007_3 = case_3_007_APDF.iloc[10,1:].astype(float)
Time_00_007_4 = case_4_007_APDF.iloc[0,1:].astype(float)
Time_01_007_4 = case_4_007_APDF.iloc[1,1:].astype(float)
Time_02_007_4 = case_4_007_APDF.iloc[2,1:].astype(float)
Time_03_007_4 = case_4_007_APDF.iloc[3,1:].astype(float)
Time_04_007_4 = case_4_007_APDF.iloc[4,1:].astype(float)
Time_05_007_4 = case_4_007_APDF.iloc[5,1:].astype(float)
Time_06_007_4 = case_4_007_APDF.iloc[6,1:].astype(float)
Time_07_007_4 = case_4_007_APDF.iloc[7,1:].astype(float)
Time_08_007_4 = case_4_007_APDF.iloc[8,1:].astype(float)
Time_09_007_4 = case_4_007_APDF.iloc[9,1:].astype(float)
Time_10_007_4 = case_4_007_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 008
Time_00_008_1 = case_1_008_APDF.iloc[0,1:].astype(float)
Time_01_008_1 = case_1_008_APDF.iloc[1,1:].astype(float)
Time_02_008_1 = case_1_008_APDF.iloc[2,1:].astype(float)
Time_03_008_1 = case_1_008_APDF.iloc[3,1:].astype(float)
Time_04_008_1 = case_1_008_APDF.iloc[4,1:].astype(float)
Time_05_008_1 = case_1_008_APDF.iloc[5,1:].astype(float)
Time_06_008_1 = case_1_008_APDF.iloc[6,1:].astype(float)
Time_07_008_1 = case_1_008_APDF.iloc[7,1:].astype(float)
Time_08_008_1 = case_1_008_APDF.iloc[8,1:].astype(float)
Time_09_008_1 = case_1_008_APDF.iloc[9,1:].astype(float)
Time_10_008_1 = case_1_008_APDF.iloc[10,1:].astype(float)
Time_00_008_2 = case_2_008_APDF.iloc[0,1:].astype(float)
Time_01_008_2 = case_2_008_APDF.iloc[1,1:].astype(float)
Time_02_008_2 = case_2_008_APDF.iloc[2,1:].astype(float)
Time_03_008_2 = case_2_008_APDF.iloc[3,1:].astype(float)
Time_04_008_2 = case_2_008_APDF.iloc[4,1:].astype(float)
Time_05_008_2 = case_2_008_APDF.iloc[5,1:].astype(float)
Time_06_008_2 = case_2_008_APDF.iloc[6,1:].astype(float)
Time_07_008_2 = case_2_008_APDF.iloc[7,1:].astype(float)
Time_08_008_2 = case_2_008_APDF.iloc[8,1:].astype(float)
Time_09_008_2 = case_2_008_APDF.iloc[9,1:].astype(float)
Time_10_008_2 = case_2_008_APDF.iloc[10,1:].astype(float)
Time_00_008_3 = case_3_008_APDF.iloc[0,1:].astype(float)
Time_01_008_3 = case_3_008_APDF.iloc[1,1:].astype(float)
Time_02_008_3 = case_3_008_APDF.iloc[2,1:].astype(float)
Time_03_008_3 = case_3_008_APDF.iloc[3,1:].astype(float)
Time_04_008_3 = case_3_008_APDF.iloc[4,1:].astype(float)
Time_05_008_3 = case_3_008_APDF.iloc[5,1:].astype(float)
Time_06_008_3 = case_3_008_APDF.iloc[6,1:].astype(float)
Time_07_008_3 = case_3_008_APDF.iloc[7,1:].astype(float)
Time_08_008_3 = case_3_008_APDF.iloc[8,1:].astype(float)
Time_09_008_3 = case_3_008_APDF.iloc[9,1:].astype(float)
Time_10_008_3 = case_3_008_APDF.iloc[10,1:].astype(float)
Time_00_008_4 = case_4_008_APDF.iloc[0,1:].astype(float)
Time_01_008_4 = case_4_008_APDF.iloc[1,1:].astype(float)
Time_02_008_4 = case_4_008_APDF.iloc[2,1:].astype(float)
Time_03_008_4 = case_4_008_APDF.iloc[3,1:].astype(float)
Time_04_008_4 = case_4_008_APDF.iloc[4,1:].astype(float)
Time_05_008_4 = case_4_008_APDF.iloc[5,1:].astype(float)
Time_06_008_4 = case_4_008_APDF.iloc[6,1:].astype(float)
Time_07_008_4 = case_4_008_APDF.iloc[7,1:].astype(float)
Time_08_008_4 = case_4_008_APDF.iloc[8,1:].astype(float)
Time_09_008_4 = case_4_008_APDF.iloc[9,1:].astype(float)
Time_10_008_4 = case_4_008_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 019
Time_00_019_1 = case_1_019_APDF.iloc[0,1:].astype(float)
Time_01_019_1 = case_1_019_APDF.iloc[1,1:].astype(float)
Time_02_019_1 = case_1_019_APDF.iloc[2,1:].astype(float)
Time_03_019_1 = case_1_019_APDF.iloc[3,1:].astype(float)
Time_04_019_1 = case_1_019_APDF.iloc[4,1:].astype(float)
Time_05_019_1 = case_1_019_APDF.iloc[5,1:].astype(float)
Time_06_019_1 = case_1_019_APDF.iloc[6,1:].astype(float)
Time_07_019_1 = case_1_019_APDF.iloc[7,1:].astype(float)
Time_08_019_1 = case_1_019_APDF.iloc[8,1:].astype(float)
Time_09_019_1 = case_1_019_APDF.iloc[9,1:].astype(float)
Time_10_019_1 = case_1_019_APDF.iloc[10,1:].astype(float)
Time_00_019_2 = case_2_019_APDF.iloc[0,1:].astype(float)
Time_01_019_2 = case_2_019_APDF.iloc[1,1:].astype(float)
Time_02_019_2 = case_2_019_APDF.iloc[2,1:].astype(float)
Time_03_019_2 = case_2_019_APDF.iloc[3,1:].astype(float)
Time_04_019_2 = case_2_019_APDF.iloc[4,1:].astype(float)
Time_05_019_2 = case_2_019_APDF.iloc[5,1:].astype(float)
Time_06_019_2 = case_2_019_APDF.iloc[6,1:].astype(float)
Time_07_019_2 = case_2_019_APDF.iloc[7,1:].astype(float)
Time_08_019_2 = case_2_019_APDF.iloc[8,1:].astype(float)
Time_09_019_2 = case_2_019_APDF.iloc[9,1:].astype(float)
Time_10_019_2 = case_2_019_APDF.iloc[10,1:].astype(float)
Time_00_019_3 = case_3_019_APDF.iloc[0,1:].astype(float)
Time_01_019_3 = case_3_019_APDF.iloc[1,1:].astype(float)
Time_02_019_3 = case_3_019_APDF.iloc[2,1:].astype(float)
Time_03_019_3 = case_3_019_APDF.iloc[3,1:].astype(float)
Time_04_019_3 = case_3_019_APDF.iloc[4,1:].astype(float)
Time_05_019_3 = case_3_019_APDF.iloc[5,1:].astype(float)
Time_06_019_3 = case_3_019_APDF.iloc[6,1:].astype(float)
Time_07_019_3 = case_3_019_APDF.iloc[7,1:].astype(float)
Time_08_019_3 = case_3_019_APDF.iloc[8,1:].astype(float)
Time_09_019_3 = case_3_019_APDF.iloc[9,1:].astype(float)
Time_10_019_3 = case_3_019_APDF.iloc[10,1:].astype(float)
Time_00_019_4 = case_4_019_APDF.iloc[0,1:].astype(float)
Time_01_019_4 = case_4_019_APDF.iloc[1,1:].astype(float)
Time_02_019_4 = case_4_019_APDF.iloc[2,1:].astype(float)
Time_03_019_4 = case_4_019_APDF.iloc[3,1:].astype(float)
Time_04_019_4 = case_4_019_APDF.iloc[4,1:].astype(float)
Time_05_019_4 = case_4_019_APDF.iloc[5,1:].astype(float)
Time_06_019_4 = case_4_019_APDF.iloc[6,1:].astype(float)
Time_07_019_4 = case_4_019_APDF.iloc[7,1:].astype(float)
Time_08_019_4 = case_4_019_APDF.iloc[8,1:].astype(float)
Time_09_019_4 = case_4_019_APDF.iloc[9,1:].astype(float)
Time_10_019_4 = case_4_019_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 020
Time_00_020_1 = case_1_020_APDF.iloc[0,1:].astype(float)
Time_01_020_1 = case_1_020_APDF.iloc[1,1:].astype(float)
Time_02_020_1 = case_1_020_APDF.iloc[2,1:].astype(float)
Time_03_020_1 = case_1_020_APDF.iloc[3,1:].astype(float)
Time_04_020_1 = case_1_020_APDF.iloc[4,1:].astype(float)
Time_05_020_1 = case_1_020_APDF.iloc[5,1:].astype(float)
Time_06_020_1 = case_1_020_APDF.iloc[6,1:].astype(float)
Time_07_020_1 = case_1_020_APDF.iloc[7,1:].astype(float)
Time_08_020_1 = case_1_020_APDF.iloc[8,1:].astype(float)
Time_09_020_1 = case_1_020_APDF.iloc[9,1:].astype(float)
Time_10_020_1 = case_1_020_APDF.iloc[10,1:].astype(float)
Time_00_020_2 = case_2_020_APDF.iloc[0,1:].astype(float)
Time_01_020_2 = case_2_020_APDF.iloc[1,1:].astype(float)
Time_02_020_2 = case_2_020_APDF.iloc[2,1:].astype(float)
Time_03_020_2 = case_2_020_APDF.iloc[3,1:].astype(float)
Time_04_020_2 = case_2_020_APDF.iloc[4,1:].astype(float)
Time_05_020_2 = case_2_020_APDF.iloc[5,1:].astype(float)
Time_06_020_2 = case_2_020_APDF.iloc[6,1:].astype(float)
Time_07_020_2 = case_2_020_APDF.iloc[7,1:].astype(float)
Time_08_020_2 = case_2_020_APDF.iloc[8,1:].astype(float)
Time_09_020_2 = case_2_020_APDF.iloc[9,1:].astype(float)
Time_10_020_2 = case_2_020_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 021
Time_00_021_1 = case_1_021_APDF.iloc[0,1:].astype(float)
Time_01_021_1 = case_1_021_APDF.iloc[1,1:].astype(float)
Time_02_021_1 = case_1_021_APDF.iloc[2,1:].astype(float)
Time_03_021_1 = case_1_021_APDF.iloc[3,1:].astype(float)
Time_04_021_1 = case_1_021_APDF.iloc[4,1:].astype(float)
Time_05_021_1 = case_1_021_APDF.iloc[5,1:].astype(float)
Time_06_021_1 = case_1_021_APDF.iloc[6,1:].astype(float)
Time_07_021_1 = case_1_021_APDF.iloc[7,1:].astype(float)
Time_08_021_1 = case_1_021_APDF.iloc[8,1:].astype(float)
Time_09_021_1 = case_1_021_APDF.iloc[9,1:].astype(float)
Time_10_021_1 = case_1_021_APDF.iloc[10,1:].astype(float)
Time_00_021_2 = case_2_021_APDF.iloc[0,1:].astype(float)
Time_01_021_2 = case_2_021_APDF.iloc[1,1:].astype(float)
Time_02_021_2 = case_2_021_APDF.iloc[2,1:].astype(float)
Time_03_021_2 = case_2_021_APDF.iloc[3,1:].astype(float)
Time_04_021_2 = case_2_021_APDF.iloc[4,1:].astype(float)
Time_05_021_2 = case_2_021_APDF.iloc[5,1:].astype(float)
Time_06_021_2 = case_2_021_APDF.iloc[6,1:].astype(float)
Time_07_021_2 = case_2_021_APDF.iloc[7,1:].astype(float)
Time_08_021_2 = case_2_021_APDF.iloc[8,1:].astype(float)
Time_09_021_2 = case_2_021_APDF.iloc[9,1:].astype(float)
Time_10_021_2 = case_2_021_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 022
Time_00_022_1 = case_1_022_APDF.iloc[0,1:].astype(float)
Time_01_022_1 = case_1_022_APDF.iloc[1,1:].astype(float)
Time_02_022_1 = case_1_022_APDF.iloc[2,1:].astype(float)
Time_03_022_1 = case_1_022_APDF.iloc[3,1:].astype(float)
Time_04_022_1 = case_1_022_APDF.iloc[4,1:].astype(float)
Time_05_022_1 = case_1_022_APDF.iloc[5,1:].astype(float)
Time_06_022_1 = case_1_022_APDF.iloc[6,1:].astype(float)
Time_07_022_1 = case_1_022_APDF.iloc[7,1:].astype(float)
Time_08_022_1 = case_1_022_APDF.iloc[8,1:].astype(float)
Time_09_022_1 = case_1_022_APDF.iloc[9,1:].astype(float)
Time_10_022_1 = case_1_022_APDF.iloc[10,1:].astype(float)
Time_00_022_2 = case_2_022_APDF.iloc[0,1:].astype(float)
Time_01_022_2 = case_2_022_APDF.iloc[1,1:].astype(float)
Time_02_022_2 = case_2_022_APDF.iloc[2,1:].astype(float)
Time_03_022_2 = case_2_022_APDF.iloc[3,1:].astype(float)
Time_04_022_2 = case_2_022_APDF.iloc[4,1:].astype(float)
Time_05_022_2 = case_2_022_APDF.iloc[5,1:].astype(float)
Time_06_022_2 = case_2_022_APDF.iloc[6,1:].astype(float)
Time_07_022_2 = case_2_022_APDF.iloc[7,1:].astype(float)
Time_08_022_2 = case_2_022_APDF.iloc[8,1:].astype(float)
Time_09_022_2 = case_2_022_APDF.iloc[9,1:].astype(float)
Time_10_022_2 = case_2_022_APDF.iloc[10,1:].astype(float)
Time_00_022_3 = case_3_022_APDF.iloc[0,1:].astype(float)
Time_01_022_3 = case_3_022_APDF.iloc[1,1:].astype(float)
Time_02_022_3 = case_3_022_APDF.iloc[2,1:].astype(float)
Time_03_022_3 = case_3_022_APDF.iloc[3,1:].astype(float)
Time_04_022_3 = case_3_022_APDF.iloc[4,1:].astype(float)
Time_05_022_3 = case_3_022_APDF.iloc[5,1:].astype(float)
Time_06_022_3 = case_3_022_APDF.iloc[6,1:].astype(float)
Time_07_022_3 = case_3_022_APDF.iloc[7,1:].astype(float)
Time_08_022_3 = case_3_022_APDF.iloc[8,1:].astype(float)
Time_09_022_3 = case_3_022_APDF.iloc[9,1:].astype(float)
Time_10_022_3 = case_3_022_APDF.iloc[10,1:].astype(float)
Time_00_022_4 = case_4_022_APDF.iloc[0,1:].astype(float)
Time_01_022_4 = case_4_022_APDF.iloc[1,1:].astype(float)
Time_02_022_4 = case_4_022_APDF.iloc[2,1:].astype(float)
Time_03_022_4 = case_4_022_APDF.iloc[3,1:].astype(float)
Time_04_022_4 = case_4_022_APDF.iloc[4,1:].astype(float)
Time_05_022_4 = case_4_022_APDF.iloc[5,1:].astype(float)
Time_06_022_4 = case_4_022_APDF.iloc[6,1:].astype(float)
Time_07_022_4 = case_4_022_APDF.iloc[7,1:].astype(float)
Time_08_022_4 = case_4_022_APDF.iloc[8,1:].astype(float)
Time_09_022_4 = case_4_022_APDF.iloc[9,1:].astype(float)
Time_10_022_4 = case_4_022_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 023
Time_00_023_1 = case_1_023_APDF.iloc[0,1:].astype(float)
Time_01_023_1 = case_1_023_APDF.iloc[1,1:].astype(float)
Time_02_023_1 = case_1_023_APDF.iloc[2,1:].astype(float)
Time_03_023_1 = case_1_023_APDF.iloc[3,1:].astype(float)
Time_04_023_1 = case_1_023_APDF.iloc[4,1:].astype(float)
Time_05_023_1 = case_1_023_APDF.iloc[5,1:].astype(float)
Time_06_023_1 = case_1_023_APDF.iloc[6,1:].astype(float)
Time_07_023_1 = case_1_023_APDF.iloc[7,1:].astype(float)
Time_08_023_1 = case_1_023_APDF.iloc[8,1:].astype(float)
Time_09_023_1 = case_1_023_APDF.iloc[9,1:].astype(float)
Time_10_023_1 = case_1_023_APDF.iloc[10,1:].astype(float)
Time_00_023_2 = case_2_023_APDF.iloc[0,1:].astype(float)
Time_01_023_2 = case_2_023_APDF.iloc[1,1:].astype(float)
Time_02_023_2 = case_2_023_APDF.iloc[2,1:].astype(float)
Time_03_023_2 = case_2_023_APDF.iloc[3,1:].astype(float)
Time_04_023_2 = case_2_023_APDF.iloc[4,1:].astype(float)
Time_05_023_2 = case_2_023_APDF.iloc[5,1:].astype(float)
Time_06_023_2 = case_2_023_APDF.iloc[6,1:].astype(float)
Time_07_023_2 = case_2_023_APDF.iloc[7,1:].astype(float)
Time_08_023_2 = case_2_023_APDF.iloc[8,1:].astype(float)
Time_09_023_2 = case_2_023_APDF.iloc[9,1:].astype(float)
Time_10_023_2 = case_2_023_APDF.iloc[10,1:].astype(float)
Time_00_023_4 = case_4_023_APDF.iloc[0,1:].astype(float)
Time_01_023_4 = case_4_023_APDF.iloc[1,1:].astype(float)
Time_02_023_4 = case_4_023_APDF.iloc[2,1:].astype(float)
Time_03_023_4 = case_4_023_APDF.iloc[3,1:].astype(float)
Time_04_023_4 = case_4_023_APDF.iloc[4,1:].astype(float)
Time_05_023_4 = case_4_023_APDF.iloc[5,1:].astype(float)
Time_06_023_4 = case_4_023_APDF.iloc[6,1:].astype(float)
Time_07_023_4 = case_4_023_APDF.iloc[7,1:].astype(float)
Time_08_023_4 = case_4_023_APDF.iloc[8,1:].astype(float)
Time_09_023_4 = case_4_023_APDF.iloc[9,1:].astype(float)
Time_10_023_4 = case_4_023_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 024
Time_00_024_1 = case_1_024_APDF.iloc[0,1:].astype(float)
Time_01_024_1 = case_1_024_APDF.iloc[1,1:].astype(float)
Time_02_024_1 = case_1_024_APDF.iloc[2,1:].astype(float)
Time_03_024_1 = case_1_024_APDF.iloc[3,1:].astype(float)
Time_04_024_1 = case_1_024_APDF.iloc[4,1:].astype(float)
Time_05_024_1 = case_1_024_APDF.iloc[5,1:].astype(float)
Time_06_024_1 = case_1_024_APDF.iloc[6,1:].astype(float)
Time_07_024_1 = case_1_024_APDF.iloc[7,1:].astype(float)
Time_08_024_1 = case_1_024_APDF.iloc[8,1:].astype(float)
Time_09_024_1 = case_1_024_APDF.iloc[9,1:].astype(float)
Time_10_024_1 = case_1_024_APDF.iloc[10,1:].astype(float)
Time_00_024_2 = case_2_024_APDF.iloc[0,1:].astype(float)
Time_01_024_2 = case_2_024_APDF.iloc[1,1:].astype(float)
Time_02_024_2 = case_2_024_APDF.iloc[2,1:].astype(float)
Time_03_024_2 = case_2_024_APDF.iloc[3,1:].astype(float)
Time_04_024_2 = case_2_024_APDF.iloc[4,1:].astype(float)
Time_05_024_2 = case_2_024_APDF.iloc[5,1:].astype(float)
Time_06_024_2 = case_2_024_APDF.iloc[6,1:].astype(float)
Time_07_024_2 = case_2_024_APDF.iloc[7,1:].astype(float)
Time_08_024_2 = case_2_024_APDF.iloc[8,1:].astype(float)
Time_09_024_2 = case_2_024_APDF.iloc[9,1:].astype(float)
Time_10_024_2 = case_2_024_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 026
Time_00_026_1 = case_1_026_APDF.iloc[0,1:].astype(float)
Time_01_026_1 = case_1_026_APDF.iloc[1,1:].astype(float)
Time_02_026_1 = case_1_026_APDF.iloc[2,1:].astype(float)
Time_03_026_1 = case_1_026_APDF.iloc[3,1:].astype(float)
Time_04_026_1 = case_1_026_APDF.iloc[4,1:].astype(float)
Time_05_026_1 = case_1_026_APDF.iloc[5,1:].astype(float)
Time_06_026_1 = case_1_026_APDF.iloc[6,1:].astype(float)
Time_07_026_1 = case_1_026_APDF.iloc[7,1:].astype(float)
Time_08_026_1 = case_1_026_APDF.iloc[8,1:].astype(float)
Time_09_026_1 = case_1_026_APDF.iloc[9,1:].astype(float)
Time_10_026_1 = case_1_026_APDF.iloc[10,1:].astype(float)
Time_00_026_2 = case_2_026_APDF.iloc[0,1:].astype(float)
Time_01_026_2 = case_2_026_APDF.iloc[1,1:].astype(float)
Time_02_026_2 = case_2_026_APDF.iloc[2,1:].astype(float)
Time_03_026_2 = case_2_026_APDF.iloc[3,1:].astype(float)
Time_04_026_2 = case_2_026_APDF.iloc[4,1:].astype(float)
Time_05_026_2 = case_2_026_APDF.iloc[5,1:].astype(float)
Time_06_026_2 = case_2_026_APDF.iloc[6,1:].astype(float)
Time_07_026_2 = case_2_026_APDF.iloc[7,1:].astype(float)
Time_08_026_2 = case_2_026_APDF.iloc[8,1:].astype(float)
Time_09_026_2 = case_2_026_APDF.iloc[9,1:].astype(float)
Time_10_026_2 = case_2_026_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 027
Time_00_027_1 = case_1_027_APDF.iloc[0,1:].astype(float)
Time_01_027_1 = case_1_027_APDF.iloc[1,1:].astype(float)
Time_02_027_1 = case_1_027_APDF.iloc[2,1:].astype(float)
Time_03_027_1 = case_1_027_APDF.iloc[3,1:].astype(float)
Time_04_027_1 = case_1_027_APDF.iloc[4,1:].astype(float)
Time_05_027_1 = case_1_027_APDF.iloc[5,1:].astype(float)
Time_06_027_1 = case_1_027_APDF.iloc[6,1:].astype(float)
Time_07_027_1 = case_1_027_APDF.iloc[7,1:].astype(float)
Time_08_027_1 = case_1_027_APDF.iloc[8,1:].astype(float)
Time_09_027_1 = case_1_027_APDF.iloc[9,1:].astype(float)
Time_10_027_1 = case_1_027_APDF.iloc[10,1:].astype(float)
Time_00_027_2 = case_2_027_APDF.iloc[0,1:].astype(float)
Time_01_027_2 = case_2_027_APDF.iloc[1,1:].astype(float)
Time_02_027_2 = case_2_027_APDF.iloc[2,1:].astype(float)
Time_03_027_2 = case_2_027_APDF.iloc[3,1:].astype(float)
Time_04_027_2 = case_2_027_APDF.iloc[4,1:].astype(float)
Time_05_027_2 = case_2_027_APDF.iloc[5,1:].astype(float)
Time_06_027_2 = case_2_027_APDF.iloc[6,1:].astype(float)
Time_07_027_2 = case_2_027_APDF.iloc[7,1:].astype(float)
Time_08_027_2 = case_2_027_APDF.iloc[8,1:].astype(float)
Time_09_027_2 = case_2_027_APDF.iloc[9,1:].astype(float)
Time_10_027_2 = case_2_027_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 028
Time_00_028_1 = case_1_028_APDF.iloc[0,1:].astype(float)
Time_01_028_1 = case_1_028_APDF.iloc[1,1:].astype(float)
Time_02_028_1 = case_1_028_APDF.iloc[2,1:].astype(float)
Time_03_028_1 = case_1_028_APDF.iloc[3,1:].astype(float)
Time_04_028_1 = case_1_028_APDF.iloc[4,1:].astype(float)
Time_05_028_1 = case_1_028_APDF.iloc[5,1:].astype(float)
Time_06_028_1 = case_1_028_APDF.iloc[6,1:].astype(float)
Time_07_028_1 = case_1_028_APDF.iloc[7,1:].astype(float)
Time_08_028_1 = case_1_028_APDF.iloc[8,1:].astype(float)
Time_09_028_1 = case_1_028_APDF.iloc[9,1:].astype(float)
Time_10_028_1 = case_1_028_APDF.iloc[10,1:].astype(float)
Time_00_028_2 = case_2_028_APDF.iloc[0,1:].astype(float)
Time_01_028_2 = case_2_028_APDF.iloc[1,1:].astype(float)
Time_02_028_2 = case_2_028_APDF.iloc[2,1:].astype(float)
Time_03_028_2 = case_2_028_APDF.iloc[3,1:].astype(float)
Time_04_028_2 = case_2_028_APDF.iloc[4,1:].astype(float)
Time_05_028_2 = case_2_028_APDF.iloc[5,1:].astype(float)
Time_06_028_2 = case_2_028_APDF.iloc[6,1:].astype(float)
Time_07_028_2 = case_2_028_APDF.iloc[7,1:].astype(float)
Time_08_028_2 = case_2_028_APDF.iloc[8,1:].astype(float)
Time_09_028_2 = case_2_028_APDF.iloc[9,1:].astype(float)
Time_10_028_2 = case_2_028_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 029
Time_00_029_1 = case_1_029_APDF.iloc[0,1:].astype(float)
Time_01_029_1 = case_1_029_APDF.iloc[1,1:].astype(float)
Time_02_029_1 = case_1_029_APDF.iloc[2,1:].astype(float)
Time_03_029_1 = case_1_029_APDF.iloc[3,1:].astype(float)
Time_04_029_1 = case_1_029_APDF.iloc[4,1:].astype(float)
Time_05_029_1 = case_1_029_APDF.iloc[5,1:].astype(float)
Time_06_029_1 = case_1_029_APDF.iloc[6,1:].astype(float)
Time_07_029_1 = case_1_029_APDF.iloc[7,1:].astype(float)
Time_08_029_1 = case_1_029_APDF.iloc[8,1:].astype(float)
Time_09_029_1 = case_1_029_APDF.iloc[9,1:].astype(float)
Time_10_029_1 = case_1_029_APDF.iloc[10,1:].astype(float)
Time_00_029_2 = case_2_029_APDF.iloc[0,1:].astype(float)
Time_01_029_2 = case_2_029_APDF.iloc[1,1:].astype(float)
Time_02_029_2 = case_2_029_APDF.iloc[2,1:].astype(float)
Time_03_029_2 = case_2_029_APDF.iloc[3,1:].astype(float)
Time_04_029_2 = case_2_029_APDF.iloc[4,1:].astype(float)
Time_05_029_2 = case_2_029_APDF.iloc[5,1:].astype(float)
Time_06_029_2 = case_2_029_APDF.iloc[6,1:].astype(float)
Time_07_029_2 = case_2_029_APDF.iloc[7,1:].astype(float)
Time_08_029_2 = case_2_029_APDF.iloc[8,1:].astype(float)
Time_09_029_2 = case_2_029_APDF.iloc[9,1:].astype(float)
Time_10_029_2 = case_2_029_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 030
Time_00_030_1 = case_1_030_APDF.iloc[0,1:].astype(float)
Time_01_030_1 = case_1_030_APDF.iloc[1,1:].astype(float)
Time_02_030_1 = case_1_030_APDF.iloc[2,1:].astype(float)
Time_03_030_1 = case_1_030_APDF.iloc[3,1:].astype(float)
Time_04_030_1 = case_1_030_APDF.iloc[4,1:].astype(float)
Time_05_030_1 = case_1_030_APDF.iloc[5,1:].astype(float)
Time_06_030_1 = case_1_030_APDF.iloc[6,1:].astype(float)
Time_07_030_1 = case_1_030_APDF.iloc[7,1:].astype(float)
Time_08_030_1 = case_1_030_APDF.iloc[8,1:].astype(float)
Time_09_030_1 = case_1_030_APDF.iloc[9,1:].astype(float)
Time_10_030_1 = case_1_030_APDF.iloc[10,1:].astype(float)
Time_00_030_2 = case_2_030_APDF.iloc[0,1:].astype(float)
Time_01_030_2 = case_2_030_APDF.iloc[1,1:].astype(float)
Time_02_030_2 = case_2_030_APDF.iloc[2,1:].astype(float)
Time_03_030_2 = case_2_030_APDF.iloc[3,1:].astype(float)
Time_04_030_2 = case_2_030_APDF.iloc[4,1:].astype(float)
Time_05_030_2 = case_2_030_APDF.iloc[5,1:].astype(float)
Time_06_030_2 = case_2_030_APDF.iloc[6,1:].astype(float)
Time_07_030_2 = case_2_030_APDF.iloc[7,1:].astype(float)
Time_08_030_2 = case_2_030_APDF.iloc[8,1:].astype(float)
Time_09_030_2 = case_2_030_APDF.iloc[9,1:].astype(float)
Time_10_030_2 = case_2_030_APDF.iloc[10,1:].astype(float)
Time_00_030_3 = case_3_030_APDF.iloc[0,1:].astype(float)
Time_01_030_3 = case_3_030_APDF.iloc[1,1:].astype(float)
Time_02_030_3 = case_3_030_APDF.iloc[2,1:].astype(float)
Time_03_030_3 = case_3_030_APDF.iloc[3,1:].astype(float)
Time_04_030_3 = case_3_030_APDF.iloc[4,1:].astype(float)
Time_05_030_3 = case_3_030_APDF.iloc[5,1:].astype(float)
Time_06_030_3 = case_3_030_APDF.iloc[6,1:].astype(float)
Time_07_030_3 = case_3_030_APDF.iloc[7,1:].astype(float)
Time_08_030_3 = case_3_030_APDF.iloc[8,1:].astype(float)
Time_09_030_3 = case_3_030_APDF.iloc[9,1:].astype(float)
Time_10_030_3 = case_3_030_APDF.iloc[10,1:].astype(float)

# %%
# Extract the APDF data for each case of subject 031
Time_00_031_1 = case_1_031_APDF.iloc[0,1:].astype(float)
Time_01_031_1 = case_1_031_APDF.iloc[1,1:].astype(float)
Time_02_031_1 = case_1_031_APDF.iloc[2,1:].astype(float)
Time_03_031_1 = case_1_031_APDF.iloc[3,1:].astype(float)
Time_04_031_1 = case_1_031_APDF.iloc[4,1:].astype(float)
Time_05_031_1 = case_1_031_APDF.iloc[5,1:].astype(float)
Time_06_031_1 = case_1_031_APDF.iloc[6,1:].astype(float)
Time_07_031_1 = case_1_031_APDF.iloc[7,1:].astype(float)
Time_08_031_1 = case_1_031_APDF.iloc[8,1:].astype(float)
Time_09_031_1 = case_1_031_APDF.iloc[9,1:].astype(float)
Time_10_031_1 = case_1_031_APDF.iloc[10,1:].astype(float)
Time_00_031_2 = case_2_031_APDF.iloc[0,1:].astype(float)
Time_01_031_2 = case_2_031_APDF.iloc[1,1:].astype(float)
Time_02_031_2 = case_2_031_APDF.iloc[2,1:].astype(float)
Time_03_031_2 = case_2_031_APDF.iloc[3,1:].astype(float)
Time_04_031_2 = case_2_031_APDF.iloc[4,1:].astype(float)
Time_05_031_2 = case_2_031_APDF.iloc[5,1:].astype(float)
Time_06_031_2 = case_2_031_APDF.iloc[6,1:].astype(float)
Time_07_031_2 = case_2_031_APDF.iloc[7,1:].astype(float)
Time_08_031_2 = case_2_031_APDF.iloc[8,1:].astype(float)
Time_09_031_2 = case_2_031_APDF.iloc[9,1:].astype(float)
Time_10_031_2 = case_2_031_APDF.iloc[10,1:].astype(float)

# %%
# Set the index for the lead subjects
subject_ids_lead = [
 '1_001', '2_001', '4_001', '2_002', '3_002', 
    '1_003', '2_003', '4_003',             
    '1_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '2_019', '3_019', '1_020','2_020', '1_021','2_021',
    '1_022', '4_022', '1_023',
    '2_023', '1_024','2_024', '1_026', '2_026','1_027','2_027',
    '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]
# Set the index for the rampart subjects
subject_ids_rampart = [
    '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022', '4_023',
    '1_030', '1_031'
]

# %%
# Create a dictionary to store the dataframes
time_dataframes = {
    'Time_00': [Time_00_001_1, Time_00_001_2, Time_00_001_4, Time_00_001_6, Time_00_002_1, Time_00_002_2, Time_00_002_3, Time_00_002_4, Time_00_003_1, Time_00_003_2, Time_00_003_4, Time_00_004_1, Time_00_004_3, Time_00_004_4, Time_00_005_1, Time_00_005_3, Time_00_005_4, Time_00_005_5, Time_00_006_1, Time_00_006_2, Time_00_006_3, Time_00_006_4, Time_00_007_1, Time_00_007_2, Time_00_007_3, Time_00_007_4, Time_00_008_1, Time_00_008_2, Time_00_008_3, Time_00_008_4, Time_00_019_1, Time_00_019_2, Time_00_019_3, Time_00_019_4, Time_00_020_1, Time_00_020_2, Time_00_021_1, Time_00_021_2, Time_00_022_1, Time_00_022_2, Time_00_022_3, Time_00_022_4, Time_00_023_1, Time_00_023_2, Time_00_023_4, Time_00_024_1, Time_00_024_2, Time_00_026_1, Time_00_026_2, Time_00_027_1, Time_00_027_2, Time_00_028_1, Time_00_028_2, Time_00_029_1, Time_00_029_2, Time_00_030_1, Time_00_030_2, Time_00_030_3, Time_00_031_1, Time_00_031_2],
    'Time_01': [Time_01_001_1, Time_01_001_2, Time_01_001_4, Time_01_001_6, Time_01_002_1, Time_01_002_2, Time_01_002_3, Time_01_002_4, Time_01_003_1, Time_01_003_2, Time_01_003_4, Time_01_004_1, Time_01_004_3, Time_01_004_4, Time_01_005_1, Time_01_005_3, Time_01_005_4, Time_01_005_5, Time_01_006_1, Time_01_006_2, Time_01_006_3, Time_01_006_4, Time_01_007_1, Time_01_007_2, Time_01_007_3, Time_01_007_4, Time_01_008_1, Time_01_008_2, Time_01_008_3, Time_01_008_4, Time_01_019_1, Time_01_019_2, Time_01_019_3, Time_01_019_4, Time_01_020_1, Time_01_020_2, Time_01_021_1, Time_01_021_2, Time_01_022_1, Time_01_022_2, Time_01_022_3, Time_01_022_4, Time_01_023_1, Time_01_023_2, Time_01_023_4, Time_01_024_1, Time_01_024_2, Time_01_026_1, Time_01_026_2, Time_01_027_1, Time_01_027_2, Time_01_028_1, Time_01_028_2, Time_01_029_1, Time_01_029_2, Time_01_030_1, Time_01_030_2, Time_01_030_3, Time_01_031_1, Time_01_031_2],
    'Time_02': [Time_02_001_1, Time_02_001_2, Time_02_001_4, Time_02_001_6, Time_02_002_1, Time_02_002_2, Time_02_002_3, Time_02_002_4, Time_02_003_1, Time_02_003_2, Time_02_003_4, Time_02_004_1, Time_02_004_3, Time_02_004_4, Time_02_005_1, Time_02_005_3, Time_02_005_4, Time_02_005_5, Time_02_006_1, Time_02_006_2, Time_02_006_3, Time_02_006_4, Time_02_007_1, Time_02_007_2, Time_02_007_3, Time_02_007_4, Time_02_008_1, Time_02_008_2, Time_02_008_3, Time_02_008_4, Time_02_019_1, Time_02_019_2, Time_02_019_3, Time_02_019_4, Time_02_020_1, Time_02_020_2, Time_02_021_1, Time_02_021_2, Time_02_022_1, Time_02_022_2, Time_02_022_3, Time_02_022_4, Time_02_023_1, Time_02_023_2, Time_02_023_4, Time_02_024_1, Time_02_024_2, Time_02_026_1, Time_02_026_2, Time_02_027_1, Time_02_027_2, Time_02_028_1, Time_02_028_2, Time_02_029_1, Time_02_029_2, Time_02_030_1, Time_02_030_2, Time_02_030_3, Time_02_031_1, Time_02_031_2],
    'Time_03': [Time_03_001_1, Time_03_001_2, Time_03_001_4, Time_03_001_6, Time_03_002_1, Time_03_002_2, Time_03_002_3, Time_03_002_4, Time_03_003_1, Time_03_003_2, Time_03_003_4, Time_03_004_1, Time_03_004_3, Time_03_004_4, Time_03_005_1, Time_03_005_3, Time_03_005_4, Time_03_005_5, Time_03_006_1, Time_03_006_2, Time_03_006_3, Time_03_006_4, Time_03_007_1, Time_03_007_2, Time_03_007_3, Time_03_007_4, Time_03_008_1, Time_03_008_2, Time_03_008_3, Time_03_008_4, Time_03_019_1, Time_03_019_2, Time_03_019_3, Time_03_019_4, Time_03_020_1, Time_03_020_2, Time_03_021_1, Time_03_021_2, Time_03_022_1, Time_03_022_2, Time_03_022_3, Time_03_022_4, Time_03_023_1, Time_03_023_2, Time_03_023_4, Time_03_024_1, Time_03_024_2, Time_03_026_1, Time_03_026_2, Time_03_027_1, Time_03_027_2, Time_03_028_1, Time_03_028_2, Time_03_029_1, Time_03_029_2, Time_03_030_1, Time_03_030_2, Time_03_030_3, Time_03_031_1, Time_03_031_2],
    'Time_04': [Time_04_001_1, Time_04_001_2, Time_04_001_4, Time_04_001_6, Time_04_002_1, Time_04_002_2, Time_04_002_3, Time_04_002_4, Time_04_003_1, Time_04_003_2, Time_04_003_4, Time_04_004_1, Time_04_004_3, Time_04_004_4, Time_04_005_1, Time_04_005_3, Time_04_005_4, Time_04_005_5, Time_04_006_1, Time_04_006_2, Time_04_006_3, Time_04_006_4, Time_04_007_1, Time_04_007_2, Time_04_007_3, Time_04_007_4, Time_04_008_1, Time_04_008_2, Time_04_008_3, Time_04_008_4, Time_04_019_1, Time_04_019_2, Time_04_019_3, Time_04_019_4, Time_04_020_1, Time_04_020_2, Time_04_021_1, Time_04_021_2, Time_04_022_1, Time_04_022_2, Time_04_022_3, Time_04_022_4, Time_04_023_1, Time_04_023_2, Time_04_023_4, Time_04_024_1, Time_04_024_2, Time_04_026_1, Time_04_026_2, Time_04_027_1, Time_04_027_2, Time_04_028_1, Time_04_028_2, Time_04_029_1, Time_04_029_2, Time_04_030_1, Time_04_030_2, Time_04_030_3, Time_04_031_1, Time_04_031_2],
    'Time_05': [Time_05_001_1, Time_05_001_2, Time_05_001_4, Time_05_001_6, Time_05_002_1, Time_05_002_2, Time_05_002_3, Time_05_002_4, Time_05_003_1, Time_05_003_2, Time_05_003_4, Time_05_004_1, Time_05_004_3, Time_05_004_4, Time_05_005_1, Time_05_005_3, Time_05_005_4, Time_05_005_5, Time_05_006_1, Time_05_006_2, Time_05_006_3, Time_05_006_4, Time_05_007_1, Time_05_007_2, Time_05_007_3, Time_05_007_4, Time_05_008_1, Time_05_008_2, Time_05_008_3, Time_05_008_4, Time_05_019_1, Time_05_019_2, Time_05_019_3, Time_05_019_4, Time_05_020_1, Time_05_020_2, Time_05_021_1, Time_05_021_2, Time_05_022_1, Time_05_022_2, Time_05_022_3, Time_05_022_4, Time_05_023_1, Time_05_023_2, Time_05_023_4, Time_05_024_1, Time_05_024_2, Time_05_026_1, Time_05_026_2, Time_05_027_1, Time_05_027_2, Time_05_028_1, Time_05_028_2, Time_05_029_1, Time_05_029_2, Time_05_030_1, Time_05_030_2, Time_05_030_3, Time_05_031_1, Time_05_031_2],
    'Time_06': [Time_06_001_1, Time_06_001_2, Time_06_001_4, Time_06_001_6, Time_06_002_1, Time_06_002_2, Time_06_002_3, Time_06_002_4, Time_06_003_1, Time_06_003_2, Time_06_003_4, Time_06_004_1, Time_06_004_3, Time_06_004_4, Time_06_005_1, Time_06_005_3, Time_06_005_4, Time_06_005_5, Time_06_006_1, Time_06_006_2, Time_06_006_3, Time_06_006_4, Time_06_007_1, Time_06_007_2, Time_06_007_3, Time_06_007_4, Time_06_008_1, Time_06_008_2, Time_06_008_3, Time_06_008_4, Time_06_019_1, Time_06_019_2, Time_06_019_3, Time_06_019_4, Time_06_020_1, Time_06_020_2, Time_06_021_1, Time_06_021_2, Time_06_022_1, Time_06_022_2, Time_06_022_3, Time_06_022_4, Time_06_023_1, Time_06_023_2, Time_06_023_4, Time_06_024_1, Time_06_024_2, Time_06_026_1, Time_06_026_2, Time_06_027_1, Time_06_027_2, Time_06_028_1, Time_06_028_2, Time_06_029_1, Time_06_029_2, Time_06_030_1, Time_06_030_2, Time_06_030_3, Time_06_031_1, Time_06_031_2],
    'Time_07': [Time_07_001_1, Time_07_001_2, Time_07_001_4, Time_07_001_6, Time_07_002_1, Time_07_002_2, Time_07_002_3, Time_07_002_4, Time_07_003_1, Time_07_003_2, Time_07_003_4, Time_07_004_1, Time_07_004_3, Time_07_004_4, Time_07_005_1, Time_07_005_3, Time_07_005_4, Time_07_005_5, Time_07_006_1, Time_07_006_2, Time_07_006_3, Time_07_006_4, Time_07_007_1, Time_07_007_2, Time_07_007_3, Time_07_007_4, Time_07_008_1, Time_07_008_2, Time_07_008_3, Time_07_008_4, Time_07_019_1, Time_07_019_2, Time_07_019_3, Time_07_019_4, Time_07_020_1, Time_07_020_2, Time_07_021_1, Time_07_021_2, Time_07_022_1, Time_07_022_2, Time_07_022_3, Time_07_022_4, Time_07_023_1, Time_07_023_2, Time_07_023_4, Time_07_024_1, Time_07_024_2, Time_07_026_1, Time_07_026_2, Time_07_027_1, Time_07_027_2, Time_07_028_1, Time_07_028_2, Time_07_029_1, Time_07_029_2, Time_07_030_1, Time_07_030_2, Time_07_030_3, Time_07_031_1, Time_07_031_2],
    'Time_08': [Time_08_001_1, Time_08_001_2, Time_08_001_4, Time_08_001_6, Time_08_002_1, Time_08_002_2, Time_08_002_3, Time_08_002_4, Time_08_003_1, Time_08_003_2, Time_08_003_4, Time_08_004_1, Time_08_004_3, Time_08_004_4, Time_08_005_1, Time_08_005_3, Time_08_005_4, Time_08_005_5, Time_08_006_1, Time_08_006_2, Time_08_006_3, Time_08_006_4, Time_08_007_1, Time_08_007_2, Time_08_007_3, Time_08_007_4, Time_08_008_1, Time_08_008_2, Time_08_008_3, Time_08_008_4, Time_08_019_1, Time_08_019_2, Time_08_019_3, Time_08_019_4, Time_08_020_1, Time_08_020_2, Time_08_021_1, Time_08_021_2, Time_08_022_1, Time_08_022_2, Time_08_022_3, Time_08_022_4, Time_08_023_1, Time_08_023_2, Time_08_023_4, Time_08_024_1, Time_08_024_2, Time_08_026_1, Time_08_026_2, Time_08_027_1, Time_08_027_2, Time_08_028_1, Time_08_028_2, Time_08_029_1, Time_08_029_2, Time_08_030_1, Time_08_030_2, Time_08_030_3, Time_08_031_1, Time_08_031_2],
    'Time_09': [Time_09_001_1, Time_09_001_2, Time_09_001_4, Time_09_001_6, Time_09_002_1, Time_09_002_2, Time_09_002_3, Time_09_002_4, Time_09_003_1, Time_09_003_2, Time_09_003_4, Time_09_004_1, Time_09_004_3, Time_09_004_4, Time_09_005_1, Time_09_005_3, Time_09_005_4, Time_09_005_5, Time_09_006_1, Time_09_006_2, Time_09_006_3, Time_09_006_4, Time_09_007_1, Time_09_007_2, Time_09_007_3, Time_09_007_4, Time_09_008_1, Time_09_008_2, Time_09_008_3, Time_09_008_4, Time_09_019_1, Time_09_019_2, Time_09_019_3, Time_09_019_4, Time_09_020_1, Time_09_020_2, Time_09_021_1, Time_09_021_2, Time_09_022_1, Time_09_022_2, Time_09_022_3, Time_09_022_4, Time_09_023_1, Time_09_023_2, Time_09_023_4, Time_09_024_1, Time_09_024_2, Time_09_026_1, Time_09_026_2, Time_09_027_1, Time_09_027_2, Time_09_028_1, Time_09_028_2, Time_09_029_1, Time_09_029_2, Time_09_030_1, Time_09_030_2, Time_09_030_3, Time_09_031_1, Time_09_031_2],
    'Time_10': [Time_10_001_1, Time_10_001_2, Time_10_001_4, Time_10_001_6, Time_10_002_1, Time_10_002_2, Time_10_002_3, Time_10_002_4, Time_10_003_1, Time_10_003_2, Time_10_003_4, Time_10_004_1, Time_10_004_3, Time_10_004_4, Time_10_005_1, Time_10_005_3, Time_10_005_4, Time_10_005_5, Time_10_006_1, Time_10_006_2, Time_10_006_3, Time_10_006_4, Time_10_007_1, Time_10_007_2, Time_10_007_3, Time_10_007_4, Time_10_008_1, Time_10_008_2, Time_10_008_3, Time_10_008_4, Time_10_019_1, Time_10_019_2, Time_10_019_3, Time_10_019_4, Time_10_020_1, Time_10_020_2, Time_10_021_1, Time_10_021_2, Time_10_022_1, Time_10_022_2, Time_10_022_3, Time_10_022_4, Time_10_023_1, Time_10_023_2, Time_10_023_4, Time_10_024_1, Time_10_024_2, Time_10_026_1, Time_10_026_2, Time_10_027_1, Time_10_027_2, Time_10_028_1, Time_10_028_2, Time_10_029_1, Time_10_029_2, Time_10_030_1, Time_10_030_2, Time_10_030_3, Time_10_031_1, Time_10_031_2]
}

# Index for each CSV file:
index = [
    '1_001','2_001','4_001','6_001', '1_002', '2_002', '3_002', '4_002',
    '1_003','2_003','4_003','1_004','3_004','4_004',
    '1_005','3_005','4_005','5_005','1_006', 
    '2_006', '3_006', '4_006', '1_007', '2_007',
      '3_007', '4_007', '1_008', '2_008', '3_008', '4_008',
      '1_019', '2_019', '3_019', '4_019','1_020','2_020',
       '1_021','2_021','1_022','2_022','3_022','4_022',
        '1_023','2_023','4_023','1_024','2_024','1_026','2_026',
         '1_027','2_027','1_028','2_028','1_029','2_029',
         '1_030','2_030','3_030',  '1_031', '2_031'
]

column_headers = [
    'CERVICAL PS LT [%]', 'CERVICAL PS RT [%]','UPPER TRAP. LT [%]','UPPER TRAP. RT [%]',
    'LUMBAR ES LT [%]','LUMBAR ES RT [%]','MIDDLE TRAP. LT [%]','MIDDLE TRAP. RT [%]'
]

# Save each dataframe to a CSV file
for key in time_dataframes:
    df = pd.DataFrame(time_dataframes[key], columns=column_headers, index=index)
    df.to_csv(f'{key}.csv')

# %% [markdown]
# #### Extract the data from each EMG Stat for each case

# %%
# Load the EMG data for each case
case_1_001_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\001\\001_case1.xlsx', sheet_name = 'EMG 1')
case_2_001_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\001\\001_case2.xlsx', sheet_name = 'EMG 2')
case_4_001_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\001\\001_case4.xlsx', sheet_name = 'EMG 4')
case_6_001_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\001\\001_case6.xlsx', sheet_name = 'EMG 6')
case_1_002_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\002\\002_case1.xlsx', sheet_name = 'EMG 1')
case_2_002_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\002\\002_case2.xlsx', sheet_name = 'EMG 2')
case_3_002_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\002\\002_case3.xlsx', sheet_name = 'EMG 3')
case_4_002_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\002\\002_case4.xlsx', sheet_name = 'EMG 4')
case_1_003_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\003\\003_case1.xlsx', sheet_name = 'EMG 1')
case_2_003_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\003\\003_case2.xlsx', sheet_name = 'EMG 2')
case_4_003_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\003\\003_case4.xlsx', sheet_name = 'EMG 4')
case_1_004_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\004\\004_case1.xlsx', sheet_name = 'EMG 1')
case_3_004_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\004\\004_case3.xlsx', sheet_name = 'EMG 3')
case_4_004_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\004\\004_case4.xlsx', sheet_name = 'EMG 4')
case_1_005_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\005\\005_case1.xlsx', sheet_name = 'EMG 1')
case_3_005_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\005\\005_case3.xlsx', sheet_name = 'EMG 3')
case_4_005_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\005\\005_case4.xlsx', sheet_name = 'EMG 4')
case_5_005_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\005\\005_case5.xlsx', sheet_name = 'EMG 5')
case_1_006_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\006\\006_case1.xlsx', sheet_name = 'EMG 1')
case_2_006_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\006\\006_case2.xlsx', sheet_name = 'EMG 2')
case_3_006_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\006\\006_case3.xlsx', sheet_name = 'EMG 3')
case_4_006_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\006\\006_case4.xlsx', sheet_name = 'EMG 4')
case_1_007_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\007\\007_case1.xlsx', sheet_name = 'EMG 1')
case_2_007_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\007\\007_case2.xlsx', sheet_name = 'EMG 2')
case_3_007_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\007\\007_case3.xlsx', sheet_name = 'EMG 3')
case_4_007_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\007\\007_case4.xlsx', sheet_name = 'EMG 4')
case_1_008_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\008\\008_case1.xlsx', sheet_name = 'EMG 1')
case_2_008_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\008\\008_case2.xlsx', sheet_name = 'EMG 2')
case_3_008_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\008\\008_case3.xlsx', sheet_name = 'EMG 3')
case_4_008_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\008\\008_case4.xlsx', sheet_name = 'EMG 4')
case_1_019_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\019\\019_case1.xlsx', sheet_name = 'EMG 1')
case_2_019_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\019\\019_case2.xlsx', sheet_name = 'EMG 2')
case_3_019_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\019\\019_case3.xlsx', sheet_name = 'EMG 3')
case_4_019_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\019\\019_case4.xlsx', sheet_name = 'EMG 4')
case_1_020_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\020\\020_case1.xlsx', sheet_name = 'EMG 1')
case_2_020_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\020\\020_case2.xlsx', sheet_name = 'EMG 2')
case_1_021_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\021\\021_case1.xlsx', sheet_name = 'EMG 1')
case_2_021_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\021\\021_case2.xlsx', sheet_name = 'EMG 2')
case_1_022_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\022\\022_case1.xlsx', sheet_name = 'EMG 1')
case_2_022_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\022\\022_case2.xlsx', sheet_name = 'EMG 2')
case_3_022_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\022\\022_case3.xlsx', sheet_name = 'EMG 3')
case_4_022_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\022\\022_case4.xlsx', sheet_name = 'EMG 4')
case_1_023_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\023\\023_case1.xlsx', sheet_name = 'EMG 1')
case_2_023_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\023\\023_case2.xlsx', sheet_name = 'EMG 2')
case_4_023_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\023\\023_case4.xlsx', sheet_name = 'EMG 4')
case_1_024_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\024\\024_case1.xlsx', sheet_name = 'EMG 1')
case_2_024_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\024\\024_case2.xlsx', sheet_name = 'EMG 2')
case_1_026_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\026\\026_case1.xlsx', sheet_name = 'EMG 1')
case_2_026_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\026\\026_case2.xlsx', sheet_name = 'EMG 2')
case_1_027_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\027\\027_case1.xlsx', sheet_name = 'EMG 1')
case_2_027_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\027\\027_case2.xlsx', sheet_name = 'EMG 2')
case_1_028_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\028\\028_case1.xlsx', sheet_name = 'EMG 1')
case_2_028_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\028\\028_case2.xlsx', sheet_name = 'EMG 2')
case_1_029_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\029\\029_case1.xlsx', sheet_name = 'EMG 1')
case_2_029_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\029\\029_case2.xlsx', sheet_name = 'EMG 2')
case_1_030_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\030\\030_case1.xlsx', sheet_name = 'EMG 1')
case_2_030_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\030\\030_case2.xlsx', sheet_name = 'EMG 2')
case_3_030_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\030\\030_case3.xlsx', sheet_name = 'EMG 3')
case_1_031_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\031\\031_case1.xlsx', sheet_name = 'EMG 1')
case_2_031_EMG = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Harvard Data\\EMG reports\\031\\031_case2.xlsx', sheet_name = 'EMG 2')

# %%
# Extract the Mean% row from each case
Mean_001_1 = case_1_001_EMG.iloc[0, 1:].astype(float)
Mean_001_2 = case_2_001_EMG.iloc[0, 1:].astype(float)
Mean_001_4 = case_4_001_EMG.iloc[0, 1:].astype(float)
Mean_001_6 = case_6_001_EMG.iloc[0, 1:].astype(float)
Mean_002_1 = case_1_002_EMG.iloc[0, 1:].astype(float)
Mean_002_2 = case_2_002_EMG.iloc[0, 1:].astype(float)
Mean_002_3 = case_3_002_EMG.iloc[0, 1:].astype(float)
Mean_002_4 = case_4_002_EMG.iloc[0, 1:].astype(float)
Mean_003_1 = case_1_003_EMG.iloc[0, 1:].astype(float)
Mean_003_2 = case_2_003_EMG.iloc[0, 1:].astype(float)
Mean_003_4 = case_4_003_EMG.iloc[0, 1:].astype(float)
Mean_004_1 = case_1_004_EMG.iloc[0, 1:].astype(float)
Mean_004_3 = case_3_004_EMG.iloc[0, 1:].astype(float)
Mean_004_4 = case_4_004_EMG.iloc[0, 1:].astype(float)
Mean_005_1 = case_1_005_EMG.iloc[0, 1:].astype(float)
Mean_005_3 = case_3_005_EMG.iloc[0, 1:].astype(float)
Mean_005_4 = case_4_005_EMG.iloc[0, 1:].astype(float)
Mean_005_5 = case_5_005_EMG.iloc[0, 1:].astype(float)
Mean_006_1 = case_1_006_EMG.iloc[0, 1:].astype(float)
Mean_006_2 = case_2_006_EMG.iloc[0, 1:].astype(float)
Mean_006_3 = case_3_006_EMG.iloc[0, 1:].astype(float)
Mean_006_4 = case_4_006_EMG.iloc[0, 1:].astype(float)
Mean_007_1 = case_1_007_EMG.iloc[0, 1:].astype(float)
Mean_007_2 = case_2_007_EMG.iloc[0, 1:].astype(float)
Mean_007_3 = case_3_007_EMG.iloc[0, 1:].astype(float)
Mean_007_4 = case_4_007_EMG.iloc[0, 1:].astype(float)
Mean_008_1 = case_1_008_EMG.iloc[0, 1:].astype(float)
Mean_008_2 = case_2_008_EMG.iloc[0, 1:].astype(float)
Mean_008_3 = case_3_008_EMG.iloc[0, 1:].astype(float)
Mean_008_4 = case_4_008_EMG.iloc[0, 1:].astype(float)
Mean_019_1 = case_1_019_EMG.iloc[0, 1:].astype(float)
Mean_019_2 = case_2_019_EMG.iloc[0, 1:].astype(float)
Mean_019_3 = case_3_019_EMG.iloc[0, 1:].astype(float)
Mean_019_4 = case_4_019_EMG.iloc[0, 1:].astype(float)
Mean_020_1 = case_1_020_EMG.iloc[0, 1:].astype(float)
Mean_020_2 = case_2_020_EMG.iloc[0, 1:].astype(float)
Mean_021_1 = case_1_021_EMG.iloc[0, 1:].astype(float)
Mean_021_2 = case_2_021_EMG.iloc[0, 1:].astype(float)
Mean_022_1 = case_1_022_EMG.iloc[0, 1:].astype(float)
Mean_022_2 = case_2_022_EMG.iloc[0, 1:].astype(float)
Mean_022_3 = case_3_022_EMG.iloc[0, 1:].astype(float)
Mean_022_4 = case_4_022_EMG.iloc[0, 1:].astype(float)
Mean_023_1 = case_1_023_EMG.iloc[0, 1:].astype(float)
Mean_023_2 = case_2_023_EMG.iloc[0, 1:].astype(float)
Mean_023_4 = case_4_023_EMG.iloc[0, 1:].astype(float)
Mean_024_1 = case_1_024_EMG.iloc[0, 1:].astype(float)
Mean_024_2 = case_2_024_EMG.iloc[0, 1:].astype(float)
Mean_026_1 = case_1_026_EMG.iloc[0, 1:].astype(float)
Mean_026_2 = case_2_026_EMG.iloc[0, 1:].astype(float)
Mean_027_1 = case_1_027_EMG.iloc[0, 1:].astype(float)
Mean_027_2 = case_2_027_EMG.iloc[0, 1:].astype(float)
Mean_028_1 = case_1_028_EMG.iloc[0, 1:].astype(float)
Mean_028_2 = case_2_028_EMG.iloc[0, 1:].astype(float)
Mean_029_1 = case_1_029_EMG.iloc[0, 1:].astype(float)
Mean_029_2 = case_2_029_EMG.iloc[0, 1:].astype(float)
Mean_030_1 = case_1_030_EMG.iloc[0, 1:].astype(float)
Mean_030_2 = case_2_030_EMG.iloc[0, 1:].astype(float)
Mean_030_3 = case_3_030_EMG.iloc[0, 1:].astype(float)
Mean_031_1 = case_1_031_EMG.iloc[0, 1:].astype(float)
Mean_031_2 = case_2_031_EMG.iloc[0, 1:].astype(float)

# %%
# Extract the Peak Absolute% from each case
Peak_001_1 = case_1_001_EMG.iloc[1,1:].astype(float)
Peak_001_2 = case_2_001_EMG.iloc[1,1:].astype(float)
Peak_001_4 = case_4_001_EMG.iloc[1,1:].astype(float)
Peak_001_6 = case_6_001_EMG.iloc[1,1:].astype(float)
Peak_002_1 = case_1_002_EMG.iloc[1,1:].astype(float)
Peak_002_2 = case_2_002_EMG.iloc[1,1:].astype(float)
Peak_002_3 = case_3_002_EMG.iloc[1,1:].astype(float)
Peak_002_4 = case_4_002_EMG.iloc[1,1:].astype(float)
Peak_003_1 = case_1_003_EMG.iloc[1,1:].astype(float)
Peak_003_2 = case_2_003_EMG.iloc[1,1:].astype(float)
Peak_003_4 = case_4_003_EMG.iloc[1,1:].astype(float)
Peak_004_1 = case_1_004_EMG.iloc[1,1:].astype(float)
Peak_004_3 = case_3_004_EMG.iloc[1,1:].astype(float)
Peak_004_4 = case_4_004_EMG.iloc[1,1:].astype(float)
Peak_005_1 = case_1_005_EMG.iloc[1,1:].astype(float)
Peak_005_3 = case_3_005_EMG.iloc[1,1:].astype(float)
Peak_005_4 = case_4_005_EMG.iloc[1,1:].astype(float)
Peak_005_5 = case_5_005_EMG.iloc[1,1:].astype(float)
Peak_006_1 = case_1_006_EMG.iloc[1,1:].astype(float)
Peak_006_2 = case_2_006_EMG.iloc[1,1:].astype(float)
Peak_006_3 = case_3_006_EMG.iloc[1,1:].astype(float)
Peak_006_4 = case_4_006_EMG.iloc[1,1:].astype(float)
Peak_007_1 = case_1_007_EMG.iloc[1,1:].astype(float)
Peak_007_2 = case_2_007_EMG.iloc[1,1:].astype(float)
Peak_007_3 = case_3_007_EMG.iloc[1,1:].astype(float)
Peak_007_4 = case_4_007_EMG.iloc[1,1:].astype(float)
Peak_008_1 = case_1_008_EMG.iloc[1,1:].astype(float)
Peak_008_2 = case_2_008_EMG.iloc[1,1:].astype(float)
Peak_008_3 = case_3_008_EMG.iloc[1,1:].astype(float)
Peak_008_4 = case_4_008_EMG.iloc[1,1:].astype(float)
Peak_019_1 = case_1_019_EMG.iloc[1,1:].astype(float)
Peak_019_2 = case_2_019_EMG.iloc[1,1:].astype(float)
Peak_019_3 = case_3_019_EMG.iloc[1,1:].astype(float)
Peak_019_4 = case_4_019_EMG.iloc[1,1:].astype(float)
Peak_020_1 = case_1_020_EMG.iloc[1,1:].astype(float)
Peak_020_2 = case_2_020_EMG.iloc[1,1:].astype(float)
Peak_021_1 = case_1_021_EMG.iloc[1,1:].astype(float)
Peak_021_2 = case_2_021_EMG.iloc[1,1:].astype(float)
Peak_022_1 = case_1_022_EMG.iloc[1,1:].astype(float)
Peak_022_2 = case_2_022_EMG.iloc[1,1:].astype(float)
Peak_022_3 = case_3_022_EMG.iloc[1,1:].astype(float)
Peak_022_4 = case_4_022_EMG.iloc[1,1:].astype(float)
Peak_023_1 = case_1_023_EMG.iloc[1,1:].astype(float)
Peak_023_2 = case_2_023_EMG.iloc[1,1:].astype(float)
Peak_023_4 = case_4_023_EMG.iloc[1,1:].astype(float)
Peak_024_1 = case_1_024_EMG.iloc[1,1:].astype(float)
Peak_024_2 = case_2_024_EMG.iloc[1,1:].astype(float)
Peak_026_1 = case_1_026_EMG.iloc[1,1:].astype(float)
Peak_026_2 = case_2_026_EMG.iloc[1,1:].astype(float)
Peak_027_1 = case_1_027_EMG.iloc[1,1:].astype(float)
Peak_027_2 = case_2_027_EMG.iloc[1,1:].astype(float)
Peak_028_1 = case_1_028_EMG.iloc[1,1:].astype(float)
Peak_028_2 = case_2_028_EMG.iloc[1,1:].astype(float)
Peak_029_1 = case_1_029_EMG.iloc[1,1:].astype(float)
Peak_029_2 = case_2_029_EMG.iloc[1,1:].astype(float)
Peak_030_1 = case_1_030_EMG.iloc[1,1:].astype(float)
Peak_030_2 = case_2_030_EMG.iloc[1,1:].astype(float)
Peak_030_3 = case_3_030_EMG.iloc[1,1:].astype(float)
Peak_031_1 = case_1_031_EMG.iloc[1,1:].astype(float)
Peak_031_2 = case_2_031_EMG.iloc[1,1:].astype(float)

# %%
# Extract the Variability% from each case
Var_001_1 = case_1_001_EMG.iloc[2,1:].astype(float)
Var_001_2 = case_2_001_EMG.iloc[2,1:].astype(float)
Var_001_4 = case_4_001_EMG.iloc[2,1:].astype(float)
Var_001_6 = case_6_001_EMG.iloc[2,1:].astype(float)
Var_002_1 = case_1_002_EMG.iloc[2,1:].astype(float)
Var_002_2 = case_2_002_EMG.iloc[2,1:].astype(float)
Var_002_3 = case_3_002_EMG.iloc[2,1:].astype(float)
Var_002_4 = case_4_002_EMG.iloc[2,1:].astype(float)
Var_003_1 = case_1_003_EMG.iloc[2,1:].astype(float)
Var_003_2 = case_2_003_EMG.iloc[2,1:].astype(float)
Var_003_4 = case_4_003_EMG.iloc[2,1:].astype(float)
Var_004_1 = case_1_004_EMG.iloc[2,1:].astype(float)
Var_004_3 = case_3_004_EMG.iloc[2,1:].astype(float)
Var_004_4 = case_4_004_EMG.iloc[2,1:].astype(float)
Var_005_1 = case_1_005_EMG.iloc[2,1:].astype(float)
Var_005_3 = case_3_005_EMG.iloc[2,1:].astype(float)
Var_005_4 = case_4_005_EMG.iloc[2,1:].astype(float)
Var_005_5 = case_5_005_EMG.iloc[2,1:].astype(float)
Var_006_1 = case_1_006_EMG.iloc[2,1:].astype(float)
Var_006_2 = case_2_006_EMG.iloc[2,1:].astype(float)
Var_006_3 = case_3_006_EMG.iloc[2,1:].astype(float)
Var_006_4 = case_4_006_EMG.iloc[2,1:].astype(float)
Var_007_1 = case_1_007_EMG.iloc[2,1:].astype(float)
Var_007_2 = case_2_007_EMG.iloc[2,1:].astype(float)
Var_007_3 = case_3_007_EMG.iloc[2,1:].astype(float)
Var_007_4 = case_4_007_EMG.iloc[2,1:].astype(float)
Var_008_1 = case_1_008_EMG.iloc[2,1:].astype(float)
Var_008_2 = case_2_008_EMG.iloc[2,1:].astype(float)
Var_008_3 = case_3_008_EMG.iloc[2,1:].astype(float)
Var_008_4 = case_4_008_EMG.iloc[2,1:].astype(float)
Var_019_1 = case_1_019_EMG.iloc[2,1:].astype(float)
Var_019_2 = case_2_019_EMG.iloc[2,1:].astype(float)
Var_019_3 = case_3_019_EMG.iloc[2,1:].astype(float)
Var_019_4 = case_4_019_EMG.iloc[2,1:].astype(float)
Var_020_1 = case_1_020_EMG.iloc[2,1:].astype(float)
Var_020_2 = case_2_020_EMG.iloc[2,1:].astype(float)
Var_021_1 = case_1_021_EMG.iloc[2,1:].astype(float)
Var_021_2 = case_2_021_EMG.iloc[2,1:].astype(float)
Var_022_1 = case_1_022_EMG.iloc[2,1:].astype(float)
Var_022_2 = case_2_022_EMG.iloc[2,1:].astype(float)
Var_022_3 = case_3_022_EMG.iloc[2,1:].astype(float)
Var_022_4 = case_4_022_EMG.iloc[2,1:].astype(float)
Var_023_1 = case_1_023_EMG.iloc[2,1:].astype(float)
Var_023_2 = case_2_023_EMG.iloc[2,1:].astype(float)
Var_023_4 = case_4_023_EMG.iloc[2,1:].astype(float)
Var_024_1 = case_1_024_EMG.iloc[2,1:].astype(float)
Var_024_2 = case_2_024_EMG.iloc[2,1:].astype(float)
Var_026_1 = case_1_026_EMG.iloc[2,1:].astype(float)
Var_026_2 = case_2_026_EMG.iloc[2,1:].astype(float)
Var_027_1 = case_1_027_EMG.iloc[2,1:].astype(float)
Var_027_2 = case_2_027_EMG.iloc[2,1:].astype(float)
Var_028_1 = case_1_028_EMG.iloc[2,1:].astype(float)
Var_028_2 = case_2_028_EMG.iloc[2,1:].astype(float)
Var_029_1 = case_1_029_EMG.iloc[2,1:].astype(float)
Var_029_2 = case_2_029_EMG.iloc[2,1:].astype(float)
Var_030_1 = case_1_030_EMG.iloc[2,1:].astype(float)
Var_030_2 = case_2_030_EMG.iloc[2,1:].astype(float)
Var_030_3 = case_3_030_EMG.iloc[2,1:].astype(float)
Var_031_1 = case_1_031_EMG.iloc[2,1:].astype(float)
Var_031_2 = case_2_031_EMG.iloc[2,1:].astype(float)

# %%
# Create dictionaries to store the dataframes for mean, peak, and variability
mean_dataframes = {
    'Mean': [Mean_001_1, Mean_001_2, Mean_001_4, Mean_001_6, Mean_002_1, Mean_002_2, Mean_002_3, Mean_002_4, Mean_003_1, Mean_003_2, Mean_003_4, Mean_004_1, Mean_004_3, Mean_004_4, Mean_005_1, Mean_005_3, Mean_005_4, Mean_005_5, Mean_006_1, Mean_006_2, Mean_006_3, Mean_006_4, Mean_007_1, Mean_007_2, Mean_007_3, Mean_007_4, Mean_008_1, Mean_008_2, Mean_008_3, Mean_008_4, Mean_019_1, Mean_019_2, Mean_019_3, Mean_019_4, Mean_020_1, Mean_020_2, Mean_021_1, Mean_021_2, Mean_022_1, Mean_022_2, Mean_022_3, Mean_022_4, Mean_023_1, Mean_023_2, Mean_023_4, Mean_024_1, Mean_024_2, Mean_026_1, Mean_026_2, Mean_027_1, Mean_027_2, Mean_028_1, Mean_028_2, Mean_029_1, Mean_029_2, Mean_030_1, Mean_030_2, Mean_030_3, Mean_031_1, Mean_031_2]
}

peak_dataframes = {
    'Peak': [Peak_001_1, Peak_001_2, Peak_001_4, Peak_001_6, Peak_002_1, Peak_002_2, Peak_002_3, Peak_002_4, Peak_003_1, Peak_003_2, Peak_003_4, Peak_004_1, Peak_004_3, Peak_004_4, Peak_005_1, Peak_005_3, Peak_005_4, Peak_005_5, Peak_006_1, Peak_006_2, Peak_006_3, Peak_006_4, Peak_007_1, Peak_007_2, Peak_007_3, Peak_007_4, Peak_008_1, Peak_008_2, Peak_008_3, Peak_008_4, Peak_019_1, Peak_019_2, Peak_019_3, Peak_019_4, Peak_020_1, Peak_020_2, Peak_021_1, Peak_021_2, Peak_022_1, Peak_022_2, Peak_022_3, Peak_022_4, Peak_023_1, Peak_023_2, Peak_023_4, Peak_024_1, Peak_024_2, Peak_026_1, Peak_026_2, Peak_027_1, Peak_027_2, Peak_028_1, Peak_028_2, Peak_029_1, Peak_029_2, Peak_030_1, Peak_030_2, Peak_030_3, Peak_031_1, Peak_031_2]
}

variability_dataframes = {
    'Variability': [Var_001_1, Var_001_2, Var_001_4, Var_001_6, Var_002_1, Var_002_2, Var_002_3, Var_002_4, Var_003_1, Var_003_2, Var_003_4, Var_004_1, Var_004_3, Var_004_4, Var_005_1, Var_005_3, Var_005_4, Var_005_5, Var_006_1, Var_006_2, Var_006_3, Var_006_4, Var_007_1, Var_007_2, Var_007_3, Var_007_4, Var_008_1, Var_008_2, Var_008_3, Var_008_4, Var_019_1, Var_019_2, Var_019_3, Var_019_4, Var_020_1, Var_020_2, Var_021_1, Var_021_2, Var_022_1, Var_022_2, Var_022_3, Var_022_4, Var_023_1, Var_023_2, Var_023_4, Var_024_1, Var_024_2, Var_026_1, Var_026_2, Var_027_1, Var_027_2, Var_028_1, Var_028_2, Var_029_1, Var_029_2, Var_030_1, Var_030_2, Var_030_3, Var_031_1, Var_031_2]
}

# Index for each CSV file:
index = [
    '1_001','2_001','4_001','6_001', '1_002', '2_002', '3_002', '4_002',
    '1_003','2_003','4_003','1_004','3_004','4_004',
    '1_005','3_005','4_005','5_005','1_006', 
    '2_006', '3_006', '4_006', '1_007', '2_007',
      '3_007', '4_007', '1_008', '2_008', '3_008', '4_008',
      '1_019', '2_019', '3_019', '4_019','1_020','2_020',
       '1_021','2_021','1_022','2_022','3_022','4_022',
        '1_023','2_023','4_023','1_024','2_024','1_026','2_026',
         '1_027','2_027','1_028','2_028','1_029','2_029',
         '1_030','2_030','3_030',  '1_031', '2_031'
]

column_headers = [
    'CERVICAL PS LT [%]', 'CERVICAL PS RT [%]','UPPER TRAP. LT [%]','UPPER TRAP. RT [%]',
    'LUMBAR ES LT [%]','LUMBAR ES RT [%]','MIDDLE TRAP. LT [%]','MIDDLE TRAP. RT [%]'
]

# Save each dataframe to a CSV file
for key in mean_dataframes:
    df = pd.DataFrame(mean_dataframes[key], columns=column_headers, index=index)
    df.to_csv(f'{key}.csv')

for key in peak_dataframes:
    df = pd.DataFrame(peak_dataframes[key], columns=column_headers, index=index)
    df.to_csv(f'{key}.csv')

for key in variability_dataframes:
    df = pd.DataFrame(variability_dataframes[key], columns=column_headers, index=index)
    df.to_csv(f'{key}.csv')

# %% [markdown]
# Now I will do more work with the merged CSVs in the EMG analysis Jupyter Notebook.
