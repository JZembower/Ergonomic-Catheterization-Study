# %%
#***************************
# Author: Jonah Zembower
# Date: 01/02/2024
# Project: Harvard Research Study on Postural Stability During Heart Catheterization Surgeries
#***************************

# %%
# Import all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import the code for each subject's kinematics data.

# %%
# Load in all the data
Case_1_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case3_rampart.xlsx', sheet_name = 'Kinematics 3')
Case_4_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case4_lead.xlsx', sheet_name = 'Kinematics 4')
Case_6_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case6_rampart.xlsx', sheet_name = 'Kinematics 6')
Case_1_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_Case1_rampart.xlsx', sheet_name = 'Kinematics 1')
Case_2_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_Case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_Case3_lead.xlsx', sheet_name = 'Kinematics 3')
Case_4_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_Case4_rampart.xlsx', sheet_name = 'Kinematics 4')
Case_1_003 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\003_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_003 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\003_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_4_003 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\003_case4_lead.xlsx', sheet_name = 'Kinematics 4')
Case_1_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_case3_rampart.xlsx', sheet_name = 'Kinematics 3')
Case_4_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_case4_rampart.xlsx', sheet_name = 'Kinematics 4')
Case_1_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_case1_rampart.xlsx', sheet_name = 'Kinematics 1')
Case_3_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_case3_lead.xlsx', sheet_name = 'Kinematics 3')
Case_4_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_case4_rampart.xlsx', sheet_name = 'Kinematics 4')
Case_5_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_case5_lead.xlsx', sheet_name = 'Kinematics 5')
Case_1_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_case3_rampart.xlsx', sheet_name = 'Kinematics 3')
Case_4_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_case4_rampart.xlsx', sheet_name = 'Kinematics 4')
Case_1_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_case3_rampart.xlsx', sheet_name = 'Kinematics 3')
Case_4_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_case4_rampart.xlsx', sheet_name = 'Kinematics 4')
Case_1_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_case1_rampart.xlsx', sheet_name = 'Kinematics 1')
Case_2_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_case3_lead.xlsx', sheet_name = 'Kinematics 3')
Case_4_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_case4_rampart.xlsx', sheet_name = 'Kinematics 4')
Case_1_009 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\009_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_009 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\009_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_010 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\010_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_010 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\010_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_010 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\010_case3_lead.xlsx', sheet_name = 'Kinematics 3')
Case_1_011 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\011_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_011 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\011_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_013 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\013_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_013 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\013_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_014 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\014_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_014 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\014_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_015 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\015_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_015 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\015_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_017 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\017_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_017 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\017_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_018 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\018_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_018 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\018_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_case1_rampart.xlsx', sheet_name = 'Kinematics 1')
Case_2_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_case3_lead.xlsx', sheet_name = 'Kinematics 3')
Case_4_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_case4_rampart.xlsx', sheet_name = 'Kinematics 4')
Case_1_020 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\020_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_020 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\020_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_021 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\021_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_021 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\021_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_case2_rampart.xlsx', sheet_name = 'Kinematics 2')
Case_3_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_case3_rampart.xlsx', sheet_name = 'Kinematics 3')
Case_4_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_case4_lead.xlsx', sheet_name = 'Kinematics 4')
Case_1_023 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\023_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_023 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\023_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_4_023 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\023_case4_rampart.xlsx', sheet_name = 'Kinematics 4')
Case_1_024 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\024_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_024 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\024_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_026 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\026_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_026 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\026_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_027 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\027_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_1_028 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\028_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_028 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\028_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_029 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\029_case1_lead.xlsx', sheet_name = 'Kinematics 1')
Case_2_029 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\029_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_1_030 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\030_case1_rampart.xlsx', sheet_name = 'Kinematics 1')
Case_2_030 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\030_case2_lead.xlsx', sheet_name = 'Kinematics 2')
Case_3_030 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\030_case3_lead.xlsx', sheet_name = 'Kinematics 3')
Case_1_031 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\031_case1_rampart.xlsx', sheet_name = 'Kinematics 1')
Case_2_031 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\031_case2_lead.xlsx', sheet_name = 'Kinematics 2')

# %% [markdown]
# ## Look at the Range Values

# %%
# Extract the ranges for each case
lead_Range_Case_1_001 = Case_1_001.iloc[2, 1:].astype(float)
lead_Range_Case_2_001 = Case_2_001.iloc[2, 1:].astype(float)
ram_Range_Case_3_001 = Case_3_001.iloc[2, 1:].astype(float)
lead_Range_Case_4_001 = Case_4_001.iloc[2, 1:].astype(float)
ram_Range_Case_6_001 = Case_6_001.iloc[2, 1:].astype(float)
ram_Range_Case_1_002 = Case_1_002.iloc[2, 1:].astype(float)
lead_Range_Case_2_002 = Case_2_002.iloc[2, 1:].astype(float)
lead_Range_Case_3_002 = Case_3_002.iloc[2, 1:].astype(float)
ram_Range_Case_4_002 = Case_4_002.iloc[2, 1:].astype(float)
lead_Range_Case_1_003 = Case_1_003.iloc[2, 1:].astype(float)
lead_Range_Case_2_003 = Case_2_003.iloc[2, 1:].astype(float)
lead_Range_Case_4_003 = Case_4_003.iloc[2, 1:].astype(float)
lead_Range_Case_1_004 = Case_1_004.iloc[2, 1:].astype(float)
lead_Range_Case_2_004 = Case_2_004.iloc[2, 1:].astype(float)
ram_Range_Case_3_004 = Case_3_004.iloc[2, 1:].astype(float)
ram_Range_Case_4_004 = Case_4_004.iloc[2, 1:].astype(float)
ram_Range_Case_1_005 = Case_1_005.iloc[2, 1:].astype(float)
lead_Range_Case_3_005 = Case_3_005.iloc[2, 1:].astype(float)
ram_Range_Case_4_005 = Case_4_005.iloc[2, 1:].astype(float)
lead_Range_Case_5_005 = Case_5_005.iloc[2, 1:].astype(float)
lead_Range_Case_1_006 = Case_1_006.iloc[2, 1:].astype(float)
lead_Range_Case_2_006 = Case_2_006.iloc[2, 1:].astype(float)
ram_Range_Case_3_006 = Case_3_006.iloc[2, 1:].astype(float)
ram_Range_Case_4_006 = Case_4_006.iloc[2, 1:].astype(float)
lead_Range_Case_1_007 = Case_1_007.iloc[2, 1:].astype(float)
lead_Range_Case_2_007 = Case_2_007.iloc[2, 1:].astype(float)
ram_Range_Case_3_007 = Case_3_007.iloc[2, 1:].astype(float)
ram_Range_Case_4_007 = Case_4_007.iloc[2, 1:].astype(float)
ram_Range_Case_1_008 = Case_1_008.iloc[2, 1:].astype(float)
lead_Range_Case_2_008 = Case_2_008.iloc[2, 1:].astype(float)
lead_Range_Case_3_008 = Case_3_008.iloc[2, 1:].astype(float)
ram_Range_Case_4_008 = Case_4_008.iloc[2, 1:].astype(float)
lead_Range_Case_1_009 = Case_1_009.iloc[2, 1:].astype(float)
lead_Range_Case_2_009 = Case_2_009.iloc[2, 1:].astype(float)
lead_Range_Case_1_010 = Case_1_010.iloc[2, 1:].astype(float)
lead_Range_Case_2_010 = Case_2_010.iloc[2, 1:].astype(float)
lead_Range_Case_3_010 = Case_3_010.iloc[2, 1:].astype(float)
lead_Range_Case_1_011 = Case_1_011.iloc[2, 1:].astype(float)
lead_Range_Case_2_011 = Case_2_011.iloc[2, 1:].astype(float)
lead_Range_Case_1_013 = Case_1_013.iloc[2, 1:].astype(float)
lead_Range_Case_2_013 = Case_2_013.iloc[2, 1:].astype(float)
lead_Range_Case_1_014 = Case_1_014.iloc[2, 1:].astype(float)
lead_Range_Case_2_014 = Case_2_014.iloc[2, 1:].astype(float)
lead_Range_Case_1_015 = Case_1_015.iloc[2, 1:].astype(float)
lead_Range_Case_2_015 = Case_2_015.iloc[2, 1:].astype(float)
lead_Range_Case_1_017 = Case_1_017.iloc[2, 1:].astype(float)
lead_Range_Case_2_017 = Case_2_017.iloc[2, 1:].astype(float)
lead_Range_Case_1_018 = Case_1_018.iloc[2, 1:].astype(float)
lead_Range_Case_2_018 = Case_2_018.iloc[2, 1:].astype(float)
ram_Range_Case_1_019 = Case_1_019.iloc[2, 1:].astype(float)
lead_Range_Case_2_019 = Case_2_019.iloc[2, 1:].astype(float)
lead_Range_Case_3_019 = Case_3_019.iloc[2, 1:].astype(float)
ram_Range_Case_4_019 = Case_4_019.iloc[2, 1:].astype(float)
lead_Range_Case_1_020 = Case_1_020.iloc[2, 1:].astype(float)
lead_Range_Case_2_020 = Case_2_020.iloc[2, 1:].astype(float)
lead_Range_Case_1_021 = Case_1_021.iloc[2, 1:].astype(float)
lead_Range_Case_2_021 = Case_2_021.iloc[2, 1:].astype(float)
lead_Range_Case_1_022 = Case_1_022.iloc[2, 1:].astype(float)
ram_Range_Case_2_022 = Case_2_022.iloc[2, 1:].astype(float)
ram_Range_Case_3_022 = Case_3_022.iloc[2, 1:].astype(float)
lead_Range_Case_4_022 = Case_4_022.iloc[2, 1:].astype(float)
lead_Range_Case_1_023 = Case_1_023.iloc[2, 1:].astype(float)
lead_Range_Case_2_023 = Case_2_023.iloc[2, 1:].astype(float)
ram_Range_Case_4_023 = Case_4_023.iloc[2, 1:].astype(float)
lead_Range_Case_1_024 = Case_1_024.iloc[2, 1:].astype(float)
lead_Range_Case_2_024 = Case_2_024.iloc[2, 1:].astype(float)
lead_Range_Case_1_026 = Case_1_026.iloc[2, 1:].astype(float)
lead_Range_Case_2_026 = Case_2_026.iloc[2, 1:].astype(float)
lead_Range_Case_1_027 = Case_1_027.iloc[2, 1:].astype(float)
lead_Range_Case_1_028 = Case_1_028.iloc[2, 1:].astype(float)
lead_Range_Case_2_028 = Case_2_028.iloc[2, 1:].astype(float)
lead_Range_Case_1_029 = Case_1_029.iloc[2, 1:].astype(float)
lead_Range_Case_2_029 = Case_2_029.iloc[2, 1:].astype(float)
ram_Range_Case_1_030 = Case_1_030.iloc[2, 1:].astype(float)
lead_Range_Case_2_030 = Case_2_030.iloc[2, 1:].astype(float)
lead_Range_Case_3_030 = Case_3_030.iloc[2, 1:].astype(float)
ram_Range_Case_1_031 = Case_1_031.iloc[2, 1:].astype(float)
lead_Range_Case_2_031 = Case_2_031.iloc[2, 1:].astype(float)

# %%
# Load in the ROM data
ROM_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_003 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\003_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_ROMbaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_009 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\009_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_010 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\010_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_011 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\011_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_013 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\013_ROMbaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_014 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\014_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_015 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\015_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_017 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\017_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_018 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\018_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_020 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\020_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_021 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\021_ROMbaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_023 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\023_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_024 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\024_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_026 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\026_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_027 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\027_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_028 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\028_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_029 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\029_ROMbaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_030 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\030_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')
ROM_031 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\031_ROMBaseline.xlsx', sheet_name = 'Kinematics ROM')

# %%
# Extract the ranges for each case ROM
ROM_case_1 = ROM_001.iloc[2, 1:].astype(float)
ROM_case_2 = ROM_002.iloc[2, 1:].astype(float)
ROM_case_3 = ROM_003.iloc[2, 1:].astype(float)
ROM_case_4 = ROM_004.iloc[2, 1:].astype(float)
ROM_case_5 = ROM_005.iloc[2, 1:].astype(float)
ROM_case_6 = ROM_006.iloc[2, 1:].astype(float)
ROM_case_7 = ROM_007.iloc[2, 1:].astype(float)
ROM_case_8 = ROM_008.iloc[2, 1:].astype(float)
ROM_case_9 = ROM_009.iloc[2, 1:].astype(float)
ROM_case_10 = ROM_010.iloc[2, 1:].astype(float)
ROM_case_11 = ROM_011.iloc[2, 1:].astype(float)
ROM_case_12 = ROM_013.iloc[2, 1:].astype(float)
ROM_case_13 = ROM_014.iloc[2, 1:].astype(float)
ROM_case_14 = ROM_015.iloc[2, 1:].astype(float)
ROM_case_15 = ROM_017.iloc[2, 1:].astype(float)
ROM_case_16 = ROM_018.iloc[2, 1:].astype(float)
ROM_case_17 = ROM_019.iloc[2, 1:].astype(float)
ROM_case_18 = ROM_020.iloc[2, 1:].astype(float)
ROM_case_19 = ROM_021.iloc[2, 1:].astype(float)
ROM_case_20 = ROM_022.iloc[2, 1:].astype(float)
ROM_case_21 = ROM_023.iloc[2, 1:].astype(float)
ROM_case_22 = ROM_024.iloc[2, 1:].astype(float)
ROM_case_23 = ROM_026.iloc[2, 1:].astype(float)
ROM_case_24 = ROM_027.iloc[2, 1:].astype(float)
ROM_case_25 = ROM_028.iloc[2, 1:].astype(float)
ROM_case_26 = ROM_029.iloc[2, 1:].astype(float)
ROM_case_27 = ROM_030.iloc[2, 1:].astype(float)
ROM_case_28 = ROM_031.iloc[2, 1:].astype(float)

# %%
# Average out the rampart values
# Select specific columns for averaging
columns_to_use = [
    'Cervical Flexion Fwd [deg]', 'Cervical Flexion Lat RT [deg]', 'Cervical Axial RT [deg]', 'Torso-Pelvic Flexion Fwd [deg]',
    'Torso-Pelvic Flexion Lat RT [deg]','Torso-Pelvic Axial RT [deg]', 'Thoracic Flexion Fwd [deg]',
    'Thoracic Flexion Lat RT [deg]', 'Thoracic Axial RT [deg]','Lumbar Flexion Fwd [deg]', 'Lumbar Flexion Lat RT [deg]',
    'Lumbar Axial RT [deg]'
]

# Average out the rampart values
ram_avg = (ram_Range_Case_3_001[columns_to_use] +  ram_Range_Case_6_001[columns_to_use] + ram_Range_Case_1_002[columns_to_use] + ram_Range_Case_4_002[columns_to_use] + 
           ram_Range_Case_3_004[columns_to_use] + ram_Range_Case_4_004[columns_to_use] + ram_Range_Case_1_005[columns_to_use] + 
           ram_Range_Case_4_005[columns_to_use] + ram_Range_Case_3_006[columns_to_use] + ram_Range_Case_4_006[columns_to_use] + 
           ram_Range_Case_3_007[columns_to_use] + ram_Range_Case_4_007[columns_to_use] + ram_Range_Case_1_008[columns_to_use] + 
           ram_Range_Case_4_008[columns_to_use] + ram_Range_Case_1_019[columns_to_use] + ram_Range_Case_4_019[columns_to_use] + 
           ram_Range_Case_2_022[columns_to_use] + ram_Range_Case_3_022[columns_to_use] + ram_Range_Case_4_023[columns_to_use] + ram_Range_Case_1_030[columns_to_use] + 
           ram_Range_Case_1_031[columns_to_use]) / 21

# Average out the lead values
lead_avg = (lead_Range_Case_1_001[columns_to_use] + lead_Range_Case_2_001[columns_to_use] + lead_Range_Case_4_001[columns_to_use] + 
            lead_Range_Case_2_002[columns_to_use] + lead_Range_Case_3_002[columns_to_use] + lead_Range_Case_1_003[columns_to_use] +
            lead_Range_Case_2_003[columns_to_use] + lead_Range_Case_4_003[columns_to_use] + lead_Range_Case_1_004[columns_to_use] + 
            lead_Range_Case_2_004[columns_to_use] + lead_Range_Case_3_005[columns_to_use] + lead_Range_Case_5_005[columns_to_use] + 
            lead_Range_Case_1_006[columns_to_use] + lead_Range_Case_2_006[columns_to_use] + lead_Range_Case_1_007[columns_to_use] + 
            lead_Range_Case_2_007[columns_to_use] + lead_Range_Case_2_008[columns_to_use] + lead_Range_Case_3_008[columns_to_use] + 
            lead_Range_Case_1_009[columns_to_use] + lead_Range_Case_2_009[columns_to_use] + lead_Range_Case_1_010[columns_to_use] + 
            lead_Range_Case_2_010[columns_to_use] + lead_Range_Case_3_010[columns_to_use] + lead_Range_Case_1_011[columns_to_use] + 
            lead_Range_Case_2_011[columns_to_use] + lead_Range_Case_1_013[columns_to_use] + lead_Range_Case_2_013[columns_to_use] + 
            lead_Range_Case_1_014[columns_to_use] + lead_Range_Case_2_014[columns_to_use] + lead_Range_Case_1_015[columns_to_use] + 
            lead_Range_Case_2_015[columns_to_use] + lead_Range_Case_1_017[columns_to_use] + lead_Range_Case_2_017[columns_to_use] + 
            lead_Range_Case_1_018[columns_to_use] + lead_Range_Case_2_018[columns_to_use] + lead_Range_Case_2_019[columns_to_use] + 
            lead_Range_Case_3_019[columns_to_use] + lead_Range_Case_1_020[columns_to_use] + lead_Range_Case_2_020[columns_to_use] + 
            lead_Range_Case_1_021[columns_to_use] + lead_Range_Case_2_021[columns_to_use] + lead_Range_Case_1_022[columns_to_use] + 
            lead_Range_Case_4_022[columns_to_use] + lead_Range_Case_1_023[columns_to_use] + lead_Range_Case_2_023[columns_to_use] + 
            lead_Range_Case_1_024[columns_to_use] + lead_Range_Case_2_024[columns_to_use] + lead_Range_Case_1_026[columns_to_use] + 
            lead_Range_Case_2_026[columns_to_use] + lead_Range_Case_1_027[columns_to_use] + lead_Range_Case_1_028[columns_to_use] + 
            lead_Range_Case_2_028[columns_to_use] + lead_Range_Case_1_029[columns_to_use] + lead_Range_Case_2_029[columns_to_use] + 
            lead_Range_Case_2_030[columns_to_use] + lead_Range_Case_3_030[columns_to_use] + lead_Range_Case_2_031[columns_to_use]) / 57

# Average out the ROM values
ROM_avg = (ROM_case_1[columns_to_use] + ROM_case_2[columns_to_use] + ROM_case_3[columns_to_use] + ROM_case_4[columns_to_use] + 
           ROM_case_5[columns_to_use] + ROM_case_6[columns_to_use] + ROM_case_7[columns_to_use] + ROM_case_8[columns_to_use] + 
           ROM_case_9[columns_to_use] + ROM_case_10[columns_to_use] + ROM_case_11[columns_to_use] + ROM_case_12[columns_to_use] + 
           ROM_case_13[columns_to_use] + ROM_case_14[columns_to_use] + ROM_case_15[columns_to_use] + ROM_case_16[columns_to_use] + 
           ROM_case_17[columns_to_use] + ROM_case_18[columns_to_use] + ROM_case_19[columns_to_use] + ROM_case_20[columns_to_use] + 
           ROM_case_21[columns_to_use] + ROM_case_22[columns_to_use] + ROM_case_23[columns_to_use] + ROM_case_24[columns_to_use] + 
           ROM_case_25[columns_to_use] + ROM_case_26[columns_to_use] + ROM_case_27[columns_to_use] + ROM_case_28[columns_to_use])/ 28

# Create a dataframe for the averages
average_df = pd.DataFrame({
    'Rampart Average': ram_avg,
    'Lead Average': lead_avg,
    'ROM Baseline Average': ROM_avg
})

# Plot the comparison
average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Full Range Comparison (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# The Rampart looks to allow for more mobility across all joints in their ROM.

# %%
# Calculate the difference of the rampart and lead averages
average_df['Difference'] = average_df['Rampart Average'] - average_df['Lead Average']
# Plot the difference
average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Full Range (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Above showcases the differences for each joint and how much level of improvement in range of motion there was for the rampart compared to the lead vest. Ergonomically, it would appear the rampart is more effective.

# %% [markdown]
# Now we are assessing for outliers.

# %%
from scipy.stats import zscore

# Combine all lead and rampart cases into separate dataframes
lead_cases = pd.DataFrame([lead_Range_Case_1_001, lead_Range_Case_2_001, lead_Range_Case_4_001, lead_Range_Case_2_002, lead_Range_Case_3_002,
lead_Range_Case_1_003, lead_Range_Case_2_003, lead_Range_Case_4_003,                           
lead_Range_Case_1_004, lead_Range_Case_2_004, lead_Range_Case_3_005, lead_Range_Case_5_005, lead_Range_Case_1_006,
lead_Range_Case_2_006, lead_Range_Case_1_007, lead_Range_Case_2_007, lead_Range_Case_2_008, lead_Range_Case_3_008,
lead_Range_Case_1_009, lead_Range_Case_2_009, lead_Range_Case_1_010, lead_Range_Case_2_010,
lead_Range_Case_3_010, lead_Range_Case_1_011, lead_Range_Case_2_011, lead_Range_Case_1_013, lead_Range_Case_2_013,
lead_Range_Case_1_014, lead_Range_Case_2_014, lead_Range_Case_1_015, lead_Range_Case_2_015, lead_Range_Case_1_017,
lead_Range_Case_2_017, lead_Range_Case_1_018, lead_Range_Case_2_018,
lead_Range_Case_2_019, lead_Range_Case_3_019, lead_Range_Case_1_020, lead_Range_Case_2_020,
lead_Range_Case_1_021, lead_Range_Case_2_021, lead_Range_Case_1_022, lead_Range_Case_4_022, lead_Range_Case_1_023,
lead_Range_Case_2_023, lead_Range_Case_1_024, lead_Range_Case_2_024, lead_Range_Case_1_026, lead_Range_Case_2_026,
lead_Range_Case_1_027, lead_Range_Case_1_028, lead_Range_Case_2_028, lead_Range_Case_1_029, lead_Range_Case_2_029,
lead_Range_Case_2_030, lead_Range_Case_3_030, lead_Range_Case_2_031])

rampart_cases = pd.DataFrame([ram_Range_Case_3_001, ram_Range_Case_6_001, ram_Range_Case_1_002, ram_Range_Case_4_002, ram_Range_Case_3_004, ram_Range_Case_4_004, 
ram_Range_Case_1_005, ram_Range_Case_4_005, ram_Range_Case_3_006, ram_Range_Case_4_006, ram_Range_Case_3_007, 
ram_Range_Case_4_007, ram_Range_Case_1_008, ram_Range_Case_4_008, ram_Range_Case_1_019, ram_Range_Case_4_019, 
ram_Range_Case_2_022, ram_Range_Case_3_022, ram_Range_Case_4_023, ram_Range_Case_1_030, ram_Range_Case_1_031])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022',
    '4_023',
    '1_030', '1_031'
]

rampart_cases.index = subject_ids_rampart

# Calculate z-scores for each joint in lead and rampart cases
lead_zscores = lead_cases.apply(zscore)
rampart_zscores = rampart_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_outliers = lead_zscores[(lead_zscores > 3) | (lead_zscores < -3)]
rampart_outliers = rampart_zscores[(rampart_zscores > 3) | (rampart_zscores < -3)]

# Print the outliers for each case, showcase those that are only outliers and what case they are in
lead_outliers = lead_outliers.dropna(axis=1, how='all')
rampart_outliers = rampart_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
lead_outliers.to_csv('lead_outliers_ranges.csv')
rampart_outliers.to_csv('rampart_outliers_ranges.csv')
# Save the z-scores to a CSV file
lead_zscores.to_csv('lead_zscores_ranges.csv')
rampart_zscores.to_csv('rampart_zscores_ranges.csv')
# Save the lead and rampart cases to a CSV file
lead_cases.to_csv('lead_cases_ranges.csv')
rampart_cases.to_csv('rampart_cases_ranges.csv')

# %% [markdown]
# We can see that there are some outliers based on the z-score of the data that may have some leverage. Let's remove those datapoints or look more into them potentially.

# %% [markdown]
# ## Now looking to assess the minimum and maximum kinematics data.

# %%
# Extract the minimum values for each case
lead_Min_Case_1_001 = Case_1_001.iloc[0, 1:].astype(float)
lead_Min_Case_2_001 = Case_2_001.iloc[0, 1:].astype(float)
ram_Min_Case_3_001 = Case_3_001.iloc[0, 1:].astype(float)
lead_Min_Case_4_001 = Case_4_001.iloc[0, 1:].astype(float)
ram_Min_Case_6_001 = Case_6_001.iloc[0, 1:].astype(float)
ram_Min_Case_1_002 = Case_1_002.iloc[0, 1:].astype(float)
lead_Min_Case_2_002 = Case_2_002.iloc[0, 1:].astype(float)
lead_Min_Case_3_002 = Case_3_002.iloc[0, 1:].astype(float)
ram_Min_Case_4_002 = Case_4_002.iloc[0, 1:].astype(float)
lead_Min_Case_1_003 = Case_1_003.iloc[0, 1:].astype(float)
lead_Min_Case_2_003 = Case_2_003.iloc[0, 1:].astype(float)
lead_Min_Case_4_003 = Case_4_003.iloc[0, 1:].astype(float)
lead_Min_Case_1_004 = Case_1_004.iloc[0, 1:].astype(float)
lead_Min_Case_2_004 = Case_2_004.iloc[0, 1:].astype(float)
ram_Min_Case_3_004 = Case_3_004.iloc[0, 1:].astype(float)
ram_Min_Case_4_004 = Case_4_004.iloc[0, 1:].astype(float)
ram_Min_Case_1_005 = Case_1_005.iloc[0, 1:].astype(float)
lead_Min_Case_3_005 = Case_3_005.iloc[0, 1:].astype(float)
ram_Min_Case_4_005 = Case_4_005.iloc[0, 1:].astype(float)
lead_Min_Case_5_005 = Case_5_005.iloc[0, 1:].astype(float)
lead_Min_Case_1_006 = Case_1_006.iloc[0, 1:].astype(float)
lead_Min_Case_2_006 = Case_2_006.iloc[0, 1:].astype(float)
ram_Min_Case_3_006 = Case_3_006.iloc[0, 1:].astype(float)
ram_Min_Case_4_006 = Case_4_006.iloc[0, 1:].astype(float)
lead_Min_Case_1_007 = Case_1_007.iloc[0, 1:].astype(float)
lead_Min_Case_2_007 = Case_2_007.iloc[0, 1:].astype(float)
ram_Min_Case_3_007 = Case_3_007.iloc[0, 1:].astype(float)
ram_Min_Case_4_007 = Case_4_007.iloc[0, 1:].astype(float)
ram_Min_Case_1_008 = Case_1_008.iloc[0, 1:].astype(float)
lead_Min_Case_2_008 = Case_2_008.iloc[0, 1:].astype(float)
lead_Min_Case_3_008 = Case_3_008.iloc[0, 1:].astype(float)
ram_Min_Case_4_008 = Case_4_008.iloc[0, 1:].astype(float)
lead_Min_Case_1_009 = Case_1_009.iloc[0, 1:].astype(float)
lead_Min_Case_2_009 = Case_2_009.iloc[0, 1:].astype(float)
lead_Min_Case_1_010 = Case_1_010.iloc[0, 1:].astype(float)
lead_Min_Case_2_010 = Case_2_010.iloc[0, 1:].astype(float)
lead_Min_Case_3_010 = Case_3_010.iloc[0, 1:].astype(float)
lead_Min_Case_1_011 = Case_1_011.iloc[0, 1:].astype(float)
lead_Min_Case_2_011 = Case_2_011.iloc[0, 1:].astype(float)
lead_Min_Case_1_013 = Case_1_013.iloc[0, 1:].astype(float)
lead_Min_Case_2_013 = Case_2_013.iloc[0, 1:].astype(float)
lead_Min_Case_1_014 = Case_1_014.iloc[0, 1:].astype(float)
lead_Min_Case_2_014 = Case_2_014.iloc[0, 1:].astype(float)
lead_Min_Case_1_015 = Case_1_015.iloc[0, 1:].astype(float)
lead_Min_Case_2_015 = Case_2_015.iloc[0, 1:].astype(float)
lead_Min_Case_1_017 = Case_1_017.iloc[0, 1:].astype(float)
lead_Min_Case_2_017 = Case_2_017.iloc[0, 1:].astype(float)
lead_Min_Case_1_018 = Case_1_018.iloc[0, 1:].astype(float)
lead_Min_Case_2_018 = Case_2_018.iloc[0, 1:].astype(float)
ram_Min_Case_1_019 = Case_1_019.iloc[0, 1:].astype(float)
lead_Min_Case_2_019 = Case_2_019.iloc[0, 1:].astype(float)
lead_Min_Case_3_019 = Case_3_019.iloc[0, 1:].astype(float)
ram_Min_Case_4_019 = Case_4_019.iloc[0, 1:].astype(float)
lead_Min_Case_1_020 = Case_1_020.iloc[0, 1:].astype(float)
lead_Min_Case_2_020 = Case_2_020.iloc[0, 1:].astype(float)
lead_Min_Case_1_021 = Case_1_021.iloc[0, 1:].astype(float)
lead_Min_Case_2_021 = Case_2_021.iloc[0, 1:].astype(float)
lead_Min_Case_1_022 = Case_1_022.iloc[0, 1:].astype(float)
ram_Min_Case_2_022 = Case_2_022.iloc[0, 1:].astype(float)
ram_Min_Case_3_022 = Case_3_022.iloc[0, 1:].astype(float)
lead_Min_Case_4_022 = Case_4_022.iloc[0, 1:].astype(float)
lead_Min_Case_1_023 = Case_1_023.iloc[0, 1:].astype(float)
lead_Min_Case_2_023 = Case_2_023.iloc[0, 1:].astype(float)
ram_Min_Case_4_023 = Case_4_023.iloc[0, 1:].astype(float)
lead_Min_Case_1_024 = Case_1_024.iloc[0, 1:].astype(float)
lead_Min_Case_2_024 = Case_2_024.iloc[0, 1:].astype(float)
lead_Min_Case_1_026 = Case_1_026.iloc[0, 1:].astype(float)
lead_Min_Case_2_026 = Case_2_026.iloc[0, 1:].astype(float)
lead_Min_Case_1_027 = Case_1_027.iloc[0, 1:].astype(float)
lead_Min_Case_1_028 = Case_1_028.iloc[0, 1:].astype(float)
lead_Min_Case_2_028 = Case_2_028.iloc[0, 1:].astype(float)
lead_Min_Case_1_029 = Case_1_029.iloc[0, 1:].astype(float)
lead_Min_Case_2_029 = Case_2_029.iloc[0, 1:].astype(float)
ram_Min_Case_1_030 = Case_1_030.iloc[0, 1:].astype(float)
lead_Min_Case_2_030 = Case_2_030.iloc[0, 1:].astype(float)
lead_Min_Case_3_030 = Case_3_030.iloc[0, 1:].astype(float)
ram_Min_Case_1_031 = Case_1_031.iloc[0, 1:].astype(float)
lead_Min_Case_2_031 = Case_2_031.iloc[0, 1:].astype(float)

# %%
# Extract the minimum values for each case ROM
ROM_min_case_1 = ROM_001.iloc[0, 1:].astype(float)
ROM_min_case_2 = ROM_002.iloc[0, 1:].astype(float)
ROM_min_case_3 = ROM_003.iloc[0, 1:].astype(float)
ROM_min_case_4 = ROM_004.iloc[0, 1:].astype(float)
ROM_min_case_5 = ROM_005.iloc[0, 1:].astype(float)
ROM_min_case_6 = ROM_006.iloc[0, 1:].astype(float)
ROM_min_case_7 = ROM_007.iloc[0, 1:].astype(float)
ROM_min_case_8 = ROM_008.iloc[0, 1:].astype(float)
ROM_min_case_9 = ROM_009.iloc[0, 1:].astype(float)
ROM_min_case_10 = ROM_010.iloc[0, 1:].astype(float)
ROM_min_case_11 = ROM_011.iloc[0, 1:].astype(float)
ROM_min_case_12 = ROM_013.iloc[0, 1:].astype(float)
ROM_min_case_13 = ROM_014.iloc[0, 1:].astype(float)
ROM_min_case_14 = ROM_015.iloc[0, 1:].astype(float)
ROM_min_case_15 = ROM_017.iloc[0, 1:].astype(float)
ROM_min_case_16 = ROM_018.iloc[0, 1:].astype(float)
ROM_min_case_17 = ROM_019.iloc[0, 1:].astype(float)
ROM_min_case_18 = ROM_020.iloc[0, 1:].astype(float)
ROM_min_case_19 = ROM_021.iloc[0, 1:].astype(float)
ROM_min_case_20 = ROM_022.iloc[0, 1:].astype(float)
ROM_min_case_21 = ROM_023.iloc[0, 1:].astype(float)
ROM_min_case_22 = ROM_024.iloc[0, 1:].astype(float)
ROM_min_case_23 = ROM_026.iloc[0, 1:].astype(float)
ROM_min_case_24 = ROM_027.iloc[0, 1:].astype(float)
ROM_min_case_25 = ROM_028.iloc[0, 1:].astype(float)
ROM_min_case_26 = ROM_029.iloc[0, 1:].astype(float)
ROM_min_case_27 = ROM_030.iloc[0, 1:].astype(float)
ROM_min_case_28 = ROM_031.iloc[0, 1:].astype(float)

# %%
# Average out the rampart minimum values
ram_min_avg = (ram_Min_Case_3_001  + ram_Min_Case_6_001  + ram_Min_Case_1_002 + ram_Min_Case_4_002 + ram_Min_Case_3_004 + ram_Min_Case_4_004 + 
               ram_Min_Case_1_005 + ram_Min_Case_4_005 + ram_Min_Case_3_006 + ram_Min_Case_4_006 + ram_Min_Case_3_007 + 
               ram_Min_Case_4_007 + ram_Min_Case_1_008 + ram_Min_Case_4_008 + ram_Min_Case_1_019 + ram_Min_Case_4_019 + 
               ram_Min_Case_2_022 + ram_Min_Case_3_022 + ram_Min_Case_4_023+ ram_Min_Case_1_030 + ram_Min_Case_1_031) / 21

# Average out the lead minimum values
lead_min_avg = (lead_Min_Case_1_001 + lead_Min_Case_2_001 + lead_Min_Case_4_001 + lead_Min_Case_2_002 + lead_Min_Case_3_002 +
                lead_Min_Case_1_003 + lead_Min_Case_2_003 + lead_Min_Case_4_003 +
                lead_Min_Case_1_004 + lead_Min_Case_2_004 + lead_Min_Case_3_005 + lead_Min_Case_5_005 + lead_Min_Case_1_006 +
                lead_Min_Case_2_006 + lead_Min_Case_1_007 + lead_Min_Case_2_007 + lead_Min_Case_2_008 + lead_Min_Case_3_008 +
                lead_Min_Case_1_009 + lead_Min_Case_2_009 + lead_Min_Case_1_010 + lead_Min_Case_2_010 +
                lead_Min_Case_3_010 + lead_Min_Case_1_011 + lead_Min_Case_2_011 + lead_Min_Case_1_013 + lead_Min_Case_2_013 +
                lead_Min_Case_1_014 + lead_Min_Case_2_014 + lead_Min_Case_1_015 + lead_Min_Case_2_015 + lead_Min_Case_1_017 +
                lead_Min_Case_2_017 + lead_Min_Case_1_018 + lead_Min_Case_2_018 + 
                lead_Min_Case_2_019 + lead_Min_Case_3_019 + lead_Min_Case_1_020 + lead_Min_Case_2_020 +
                lead_Min_Case_1_021 + lead_Min_Case_2_021 + lead_Min_Case_1_022 + lead_Min_Case_4_022 + lead_Min_Case_1_023 +
                lead_Min_Case_2_023 + lead_Min_Case_1_024 + lead_Min_Case_2_024 + lead_Min_Case_1_026 + lead_Min_Case_2_026 +
                lead_Min_Case_1_027 + lead_Min_Case_1_028 + lead_Min_Case_2_028 + lead_Min_Case_1_029 + lead_Min_Case_2_029 +
                lead_Min_Case_2_030 + lead_Min_Case_3_030 + lead_Min_Case_2_031) / 57

# Average out the ROM minimum values
ROM_min_avg = (ROM_min_case_1 + ROM_min_case_2 + ROM_min_case_3 + ROM_min_case_4 + ROM_min_case_5 + ROM_min_case_6 + ROM_min_case_7 + ROM_min_case_8 + ROM_min_case_9 +
               ROM_min_case_10 + ROM_min_case_11 + ROM_min_case_12 + ROM_min_case_13 + ROM_min_case_14 + ROM_min_case_15 + ROM_min_case_16 + ROM_min_case_17 +
               ROM_min_case_18 + ROM_min_case_19 + ROM_min_case_20 + ROM_min_case_21 + ROM_min_case_22 + ROM_min_case_23 + ROM_min_case_24 + ROM_min_case_25 +
               ROM_min_case_26 + ROM_min_case_27+ ROM_min_case_28) / 28

# Create a dataframe for the minimum averages
min_average_df = pd.DataFrame({
    'Rampart Min Average': ram_min_avg,
    'Lead Min Average': lead_min_avg,
    'ROM Baseline Min Average': ROM_min_avg
})

# Plot the comparison
min_average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Minimum Range Comparison (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the rampart and lead averages
min_average_df['Difference'] = min_average_df['Rampart Min Average'] - min_average_df['Lead Min Average']
# Plot the difference
min_average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Minimum Range (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Combine all lead and rampart minimum cases into separate dataframes
lead_min_cases = pd.DataFrame([lead_Min_Case_1_001, lead_Min_Case_2_001, lead_Min_Case_4_001, lead_Min_Case_2_002, lead_Min_Case_3_002,
lead_Min_Case_1_003, lead_Min_Case_2_003, lead_Min_Case_4_003,
lead_Min_Case_1_004, lead_Min_Case_2_004, lead_Min_Case_3_005, lead_Min_Case_5_005, lead_Min_Case_1_006,
lead_Min_Case_2_006, lead_Min_Case_1_007, lead_Min_Case_2_007, lead_Min_Case_2_008, lead_Min_Case_3_008,
lead_Min_Case_1_009, lead_Min_Case_2_009, lead_Min_Case_1_010, lead_Min_Case_2_010,
lead_Min_Case_3_010, lead_Min_Case_1_011, lead_Min_Case_2_011, lead_Min_Case_1_013, lead_Min_Case_2_013,
lead_Min_Case_1_014, lead_Min_Case_2_014, lead_Min_Case_1_015, lead_Min_Case_2_015, lead_Min_Case_1_017,
lead_Min_Case_2_017, lead_Min_Case_1_018, lead_Min_Case_2_018,
lead_Min_Case_2_019, lead_Min_Case_3_019, lead_Min_Case_1_020, lead_Min_Case_2_020,
lead_Min_Case_1_021, lead_Min_Case_2_021, lead_Min_Case_1_022, lead_Min_Case_4_022, lead_Min_Case_1_023,
lead_Min_Case_2_023, lead_Min_Case_1_024, lead_Min_Case_2_024, lead_Min_Case_1_026, lead_Min_Case_2_026,
lead_Min_Case_1_027, lead_Min_Case_1_028, lead_Min_Case_2_028, lead_Min_Case_1_029, lead_Min_Case_2_029,
lead_Min_Case_2_030, lead_Min_Case_3_030, lead_Min_Case_2_031])

rampart_min_cases = pd.DataFrame([ram_Min_Case_3_001,ram_Min_Case_6_001, ram_Min_Case_1_002, ram_Min_Case_4_002, ram_Min_Case_3_004, ram_Min_Case_4_004, 
ram_Min_Case_1_005, ram_Min_Case_4_005, ram_Min_Case_3_006, ram_Min_Case_4_006, ram_Min_Case_3_007, 
ram_Min_Case_4_007, ram_Min_Case_1_008, ram_Min_Case_4_008, ram_Min_Case_1_019, ram_Min_Case_4_019, 
ram_Min_Case_2_022, ram_Min_Case_3_022, ram_Min_Case_4_023, ram_Min_Case_1_030, ram_Min_Case_1_031])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_min_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022', '4_023',
    '1_030', '1_031'
]

rampart_min_cases.index = subject_ids_rampart

# Calculate z-scores for each joint in lead and rampart minimum cases
lead_min_zscores = lead_min_cases.apply(zscore)
rampart_min_zscores = rampart_min_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_min_outliers = lead_min_zscores[(lead_min_zscores > 3) | (lead_min_zscores < -3)]
rampart_min_outliers = rampart_min_zscores[(rampart_min_zscores > 3) | (rampart_min_zscores < -3)]

# Print the outliers for each case, showcase those that are only outliers and what case they are in
lead_min_outliers = lead_min_outliers.dropna(axis=1, how='all')
rampart_min_outliers = rampart_min_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
lead_min_outliers.to_csv('lead_min_outliers.csv')
rampart_min_outliers.to_csv('rampart_min_outliers.csv')
# Save the z-scores to a CSV file
lead_min_zscores.to_csv('lead_min_zscores.csv')
rampart_min_zscores.to_csv('rampart_min_zscores.csv')
# Save the lead and rampart minimum cases to a CSV file
lead_min_cases.to_csv('lead_min_cases.csv')
rampart_min_cases.to_csv('rampart_min_cases.csv')

# %% [markdown]
# There once again are some outliers in the data, but it is pretty small.

# %% [markdown]
# Now let's assess the maximum values.

# %%
# Extract the maximum values for each case
lead_Max_Case_1_001 = Case_1_001.iloc[1, 1:].astype(float)
lead_Max_Case_2_001 = Case_2_001.iloc[1, 1:].astype(float)
ram_Max_Case_3_001 = Case_3_001.iloc[1, 1:].astype(float)
lead_Max_Case_4_001 = Case_4_001.iloc[1, 1:].astype(float)
ram_Max_Case_6_001 = Case_6_001.iloc[1, 1:].astype(float)
ram_Max_Case_1_002 = Case_1_002.iloc[1, 1:].astype(float)
lead_Max_Case_2_002 = Case_2_002.iloc[1, 1:].astype(float)
lead_Max_Case_3_002 = Case_3_002.iloc[1, 1:].astype(float)
ram_Max_Case_4_002 = Case_4_002.iloc[1, 1:].astype(float)
lead_Max_Case_1_003 = Case_1_003.iloc[1, 1:].astype(float)
lead_Max_Case_2_003 = Case_2_003.iloc[1, 1:].astype(float)
lead_Max_Case_4_003 = Case_4_003.iloc[1, 1:].astype(float)
lead_Max_Case_1_004 = Case_1_004.iloc[1, 1:].astype(float)
lead_Max_Case_2_004 = Case_2_004.iloc[1, 1:].astype(float)
ram_Max_Case_3_004 = Case_3_004.iloc[1, 1:].astype(float)
ram_Max_Case_4_004 = Case_4_004.iloc[1, 1:].astype(float)
ram_Max_Case_1_005 = Case_1_005.iloc[1, 1:].astype(float)
lead_Max_Case_3_005 = Case_3_005.iloc[1, 1:].astype(float)
ram_Max_Case_4_005 = Case_4_005.iloc[1, 1:].astype(float)
lead_Max_Case_5_005 = Case_5_005.iloc[1, 1:].astype(float)
lead_Max_Case_1_006 = Case_1_006.iloc[1, 1:].astype(float)
lead_Max_Case_2_006 = Case_2_006.iloc[1, 1:].astype(float)
ram_Max_Case_3_006 = Case_3_006.iloc[1, 1:].astype(float)
ram_Max_Case_4_006 = Case_4_006.iloc[1, 1:].astype(float)
lead_Max_Case_1_007 = Case_1_007.iloc[1, 1:].astype(float)
lead_Max_Case_2_007 = Case_2_007.iloc[1, 1:].astype(float)
ram_Max_Case_3_007 = Case_3_007.iloc[1, 1:].astype(float)
ram_Max_Case_4_007 = Case_4_007.iloc[1, 1:].astype(float)
ram_Max_Case_1_008 = Case_1_008.iloc[1, 1:].astype(float)
lead_Max_Case_2_008 = Case_2_008.iloc[1, 1:].astype(float)
lead_Max_Case_3_008 = Case_3_008.iloc[1, 1:].astype(float)
ram_Max_Case_4_008 = Case_4_008.iloc[1, 1:].astype(float)
lead_Max_Case_1_009 = Case_1_009.iloc[1, 1:].astype(float)
lead_Max_Case_2_009 = Case_2_009.iloc[1, 1:].astype(float)
lead_Max_Case_1_010 = Case_1_010.iloc[1, 1:].astype(float)
lead_Max_Case_2_010 = Case_2_010.iloc[1, 1:].astype(float)
lead_Max_Case_3_010 = Case_3_010.iloc[1, 1:].astype(float)
lead_Max_Case_1_011 = Case_1_011.iloc[1, 1:].astype(float)
lead_Max_Case_2_011 = Case_2_011.iloc[1, 1:].astype(float)
lead_Max_Case_1_013 = Case_1_013.iloc[1, 1:].astype(float)
lead_Max_Case_2_013 = Case_2_013.iloc[1, 1:].astype(float)
lead_Max_Case_1_014 = Case_1_014.iloc[1, 1:].astype(float)
lead_Max_Case_2_014 = Case_2_014.iloc[1, 1:].astype(float)
lead_Max_Case_1_015 = Case_1_015.iloc[1, 1:].astype(float)
lead_Max_Case_2_015 = Case_2_015.iloc[1, 1:].astype(float)
lead_Max_Case_1_017 = Case_1_017.iloc[1, 1:].astype(float)
lead_Max_Case_2_017 = Case_2_017.iloc[1, 1:].astype(float)
lead_Max_Case_1_018 = Case_1_018.iloc[1, 1:].astype(float)
lead_Max_Case_2_018 = Case_2_018.iloc[1, 1:].astype(float)
ram_Max_Case_1_019 = Case_1_019.iloc[1, 1:].astype(float)
lead_Max_Case_2_019 = Case_2_019.iloc[1, 1:].astype(float)
lead_Max_Case_3_019 = Case_3_019.iloc[1, 1:].astype(float)
ram_Max_Case_4_019 = Case_4_019.iloc[1, 1:].astype(float)
lead_Max_Case_1_020 = Case_1_020.iloc[1, 1:].astype(float)
lead_Max_Case_2_020 = Case_2_020.iloc[1, 1:].astype(float)
lead_Max_Case_1_021 = Case_1_021.iloc[1, 1:].astype(float)
lead_Max_Case_2_021 = Case_2_021.iloc[1, 1:].astype(float)
lead_Max_Case_1_022 = Case_1_022.iloc[1, 1:].astype(float)
ram_Max_Case_2_022 = Case_2_022.iloc[1, 1:].astype(float)
ram_Max_Case_3_022 = Case_3_022.iloc[1, 1:].astype(float)
lead_Max_Case_4_022 = Case_4_022.iloc[1, 1:].astype(float)
lead_Max_Case_1_023 = Case_1_023.iloc[1, 1:].astype(float)
lead_Max_Case_2_023 = Case_2_023.iloc[1, 1:].astype(float)
ram_Max_Case_4_023 = Case_4_023.iloc[1, 1:].astype(float)
lead_Max_Case_1_024 = Case_1_024.iloc[1, 1:].astype(float)
lead_Max_Case_2_024 = Case_2_024.iloc[1, 1:].astype(float)
lead_Max_Case_1_026 = Case_1_026.iloc[1, 1:].astype(float)
lead_Max_Case_2_026 = Case_2_026.iloc[1, 1:].astype(float)
lead_Max_Case_1_027 = Case_1_027.iloc[1, 1:].astype(float)
lead_Max_Case_1_028 = Case_1_028.iloc[1, 1:].astype(float)
lead_Max_Case_2_028 = Case_2_028.iloc[1, 1:].astype(float)
lead_Max_Case_1_029 = Case_1_029.iloc[1, 1:].astype(float)
lead_Max_Case_2_029 = Case_2_029.iloc[1, 1:].astype(float)
ram_Max_Case_1_030 = Case_1_030.iloc[1, 1:].astype(float)
lead_Max_Case_2_030 = Case_2_030.iloc[1, 1:].astype(float)
lead_Max_Case_3_030 = Case_3_030.iloc[1, 1:].astype(float)
ram_Max_Case_1_031 = Case_1_031.iloc[1, 1:].astype(float)
lead_Max_Case_2_031 = Case_2_031.iloc[1, 1:].astype(float)

# %%
# Extract the maximum values for each case ROM
ROM_max_case_1 = ROM_001.iloc[1, 1:].astype(float)
ROM_max_case_2 = ROM_002.iloc[1, 1:].astype(float)
ROM_max_case_3 = ROM_003.iloc[1, 1:].astype(float)
ROM_max_case_4 = ROM_004.iloc[1, 1:].astype(float)
ROM_max_case_5 = ROM_005.iloc[1, 1:].astype(float)
ROM_max_case_6 = ROM_006.iloc[1, 1:].astype(float)
ROM_max_case_7 = ROM_007.iloc[1, 1:].astype(float)
ROM_max_case_8 = ROM_008.iloc[1, 1:].astype(float)
ROM_max_case_9 = ROM_009.iloc[1, 1:].astype(float)
ROM_max_case_10 = ROM_010.iloc[1, 1:].astype(float)
ROM_max_case_11 = ROM_011.iloc[1, 1:].astype(float)
ROM_max_case_12 = ROM_013.iloc[1, 1:].astype(float)
ROM_max_case_13 = ROM_014.iloc[1, 1:].astype(float)
ROM_max_case_14 = ROM_015.iloc[1, 1:].astype(float)
ROM_max_case_15 = ROM_017.iloc[1, 1:].astype(float)
ROM_max_case_16 = ROM_018.iloc[1, 1:].astype(float)
ROM_max_case_17 = ROM_019.iloc[1, 1:].astype(float)
ROM_max_case_18 = ROM_020.iloc[1, 1:].astype(float)
ROM_max_case_19 = ROM_021.iloc[1, 1:].astype(float)
ROM_max_case_20 = ROM_022.iloc[1, 1:].astype(float)
ROM_max_case_21 = ROM_023.iloc[1, 1:].astype(float)
ROM_max_case_22 = ROM_024.iloc[1, 1:].astype(float)
ROM_max_case_23 = ROM_026.iloc[1, 1:].astype(float)
ROM_max_case_24 = ROM_027.iloc[1, 1:].astype(float)
ROM_max_case_25 = ROM_028.iloc[1, 1:].astype(float)
ROM_max_case_26 = ROM_029.iloc[1, 1:].astype(float)
ROM_max_case_27 = ROM_030.iloc[1, 1:].astype(float)
ROM_max_case_28 = ROM_031.iloc[1, 1:].astype(float)

# %%
# Average out the rampart maximum values
ram_max_avg = (ram_Max_Case_3_001 +  ram_Max_Case_6_001 + ram_Max_Case_1_002 + ram_Max_Case_4_002 + ram_Max_Case_3_004 + ram_Max_Case_4_004 + 
               ram_Max_Case_1_005 + ram_Max_Case_4_005 + ram_Max_Case_3_006 + ram_Max_Case_4_006 + ram_Max_Case_3_007 + 
               ram_Max_Case_4_007 + ram_Max_Case_1_008 + ram_Max_Case_4_008 + ram_Max_Case_1_019 + ram_Max_Case_4_019 + 
               ram_Max_Case_2_022 + ram_Max_Case_3_022 + ram_Max_Case_4_023 + ram_Max_Case_1_030 + ram_Max_Case_1_031) / 21

# Average out the lead maximum values
lead_max_avg = (lead_Max_Case_1_001 + lead_Max_Case_2_001 + lead_Max_Case_4_001 + lead_Max_Case_2_002 + lead_Max_Case_3_002 +
                lead_Max_Case_1_003 + lead_Max_Case_2_003 + lead_Max_Case_4_003 +
                lead_Max_Case_1_004 + lead_Max_Case_2_004 + lead_Max_Case_3_005 + lead_Max_Case_5_005 + lead_Max_Case_1_006 +
                lead_Max_Case_2_006 + lead_Max_Case_1_007 + lead_Max_Case_2_007 + lead_Max_Case_2_008 + lead_Max_Case_3_008 +
                lead_Max_Case_1_009 + lead_Max_Case_2_009 + lead_Max_Case_1_010 + lead_Max_Case_2_010 +
                lead_Max_Case_3_010 + lead_Max_Case_1_011 + lead_Max_Case_2_011 + lead_Max_Case_1_013 + lead_Max_Case_2_013 +
                lead_Max_Case_1_014 + lead_Max_Case_2_014 + lead_Max_Case_1_015 + lead_Max_Case_2_015 + lead_Max_Case_1_017 +
                lead_Max_Case_2_017 + lead_Max_Case_1_018 + lead_Max_Case_2_018 + 
                lead_Max_Case_2_019 + lead_Max_Case_3_019 + lead_Max_Case_1_020 + lead_Max_Case_2_020 +
                lead_Max_Case_1_021 + lead_Max_Case_2_021 + lead_Max_Case_1_022 + lead_Max_Case_4_022 + lead_Max_Case_1_023 +
                lead_Max_Case_2_023 + lead_Max_Case_1_024 + lead_Max_Case_2_024 + lead_Max_Case_1_026 + lead_Max_Case_2_026 +
                lead_Max_Case_1_027 + lead_Max_Case_1_028 + lead_Max_Case_2_028 + lead_Max_Case_1_029 + lead_Max_Case_2_029 +
                lead_Max_Case_2_030 + lead_Max_Case_3_030 + lead_Max_Case_2_031) / 57

# Average out the ROM maximum values
ROM_max_avg = (ROM_max_case_1 + ROM_max_case_2 + ROM_max_case_3 + ROM_max_case_4 + ROM_max_case_5 + ROM_max_case_6 + ROM_max_case_7 + ROM_max_case_8 + ROM_max_case_9 +
               ROM_max_case_10 + ROM_max_case_11 + ROM_max_case_12 + ROM_max_case_13 + ROM_max_case_14 + ROM_max_case_15 + ROM_max_case_16 + ROM_max_case_17 +
               ROM_max_case_18 + ROM_max_case_19 + ROM_max_case_20 + ROM_max_case_21 + ROM_max_case_22 + ROM_max_case_23 + ROM_max_case_24 + ROM_max_case_25 +
               ROM_max_case_26 + ROM_max_case_27+ ROM_max_case_28) / 28

# Create a dataframe for the maximum averages
max_average_df = pd.DataFrame({
    'Rampart Max Average': ram_max_avg,
    'Lead Max Average': lead_max_avg,
    'ROM Baseline Max Average': ROM_max_avg
})

# Plot the comparison
max_average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Maximum Range Comparison (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the rampart and lead averages
max_average_df['Difference'] = max_average_df['Rampart Max Average'] - max_average_df['Lead Max Average']
# Plot the difference
max_average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Maximum Range (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Combine all lead and rampart maximum cases into separate dataframes
lead_max_cases = pd.DataFrame([lead_Max_Case_1_001, lead_Max_Case_2_001, lead_Max_Case_4_001, lead_Max_Case_2_002, lead_Max_Case_3_002,
lead_Max_Case_1_003, lead_Max_Case_2_003, lead_Max_Case_4_003,
lead_Max_Case_1_004, lead_Max_Case_2_004, lead_Max_Case_3_005, lead_Max_Case_5_005, lead_Max_Case_1_006,
lead_Max_Case_2_006, lead_Max_Case_1_007, lead_Max_Case_2_007, lead_Max_Case_2_008, lead_Max_Case_3_008,
lead_Max_Case_1_009, lead_Max_Case_2_009, lead_Max_Case_1_010, lead_Max_Case_2_010,
lead_Max_Case_3_010, lead_Max_Case_1_011, lead_Max_Case_2_011, lead_Max_Case_1_013, lead_Max_Case_2_013,
lead_Max_Case_1_014, lead_Max_Case_2_014, lead_Max_Case_1_015, lead_Max_Case_2_015, lead_Max_Case_1_017,
lead_Max_Case_2_017, lead_Max_Case_1_018, lead_Max_Case_2_018,
lead_Max_Case_2_019, lead_Max_Case_3_019, lead_Max_Case_1_020, lead_Max_Case_2_020,
lead_Max_Case_1_021, lead_Max_Case_2_021, lead_Max_Case_1_022, lead_Max_Case_4_022, lead_Max_Case_1_023,
lead_Max_Case_2_023, lead_Max_Case_1_024, lead_Max_Case_2_024, lead_Max_Case_1_026, lead_Max_Case_2_026,
lead_Max_Case_1_027, lead_Max_Case_1_028, lead_Max_Case_2_028, lead_Max_Case_1_029, lead_Max_Case_2_029,
lead_Max_Case_2_030, lead_Max_Case_3_030, lead_Max_Case_2_031])

rampart_max_cases = pd.DataFrame([ram_Max_Case_3_001, ram_Max_Case_6_001, ram_Max_Case_1_002, ram_Max_Case_4_002, ram_Max_Case_3_004, ram_Max_Case_4_004, 
ram_Max_Case_1_005, ram_Max_Case_4_005, ram_Max_Case_3_006, ram_Max_Case_4_006, ram_Max_Case_3_007, 
ram_Max_Case_4_007, ram_Max_Case_1_008, ram_Max_Case_4_008, ram_Max_Case_1_019, ram_Max_Case_4_019, 
ram_Max_Case_2_022, ram_Max_Case_3_022, ram_Max_Case_4_023, ram_Max_Case_1_030, ram_Max_Case_1_031])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_max_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022', '4_023',
    '1_030', '1_031'
]

rampart_max_cases.index = subject_ids_rampart

# Calculate z-scores for each joint in lead and rampart maximum cases
lead_max_zscores = lead_max_cases.apply(zscore)
rampart_max_zscores = rampart_max_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_max_outliers = lead_max_zscores[(lead_max_zscores > 3) | (lead_max_zscores < -3)]
rampart_max_outliers = rampart_max_zscores[(rampart_max_zscores > 3) | (rampart_max_zscores < -3)]

# Print the outliers for each case, showcase those that are only outliers and what case they are in
lead_max_outliers = lead_max_outliers.dropna(axis=1, how='all')
rampart_max_outliers = rampart_max_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
lead_max_outliers.to_csv('lead_max_outliers.csv')
rampart_max_outliers.to_csv('rampart_max_outliers.csv')
# Save the z-scores to a CSV file
lead_max_zscores.to_csv('lead_max_zscores.csv')
rampart_max_zscores.to_csv('rampart_max_zscores.csv')
# Save the lead and rampart maximum cases to a CSV file
lead_max_cases.to_csv('lead_max_cases.csv')
rampart_max_cases.to_csv('rampart_max_cases.csv')

# %% [markdown]
# # Now let's Assess the Thresholds

# %%
# File paths for reloaded CSVs after reset
file_paths = {
    "lead_max_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Maximum Values\\lead_max_cases.csv",
    "rampart_max_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Maximum Values\\rampart_max_cases.csv",
    "lead_min_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Minimum Values\\lead_min_cases.csv",
    "rampart_min_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Minimum Values\\rampart_min_cases.csv",
    "lead_cases_ranges": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Range Values\\lead_cases_ranges.csv",
    "rampart_cases_ranges": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Range Values\\rampart_cases_ranges.csv"
}

# Read each CSV into a DataFrame
csv_data = {name: pd.read_csv(path) for name, path in file_paths.items()}

# %%
# Define ergonomic thresholds
threshold_min = -20 # degrees
threshold_max = 20 # degrees

# Function to calculate threshold violations
def calculate_threshold_violations(max_data, min_data):
    violations = {}
    for joint in max_data.columns[1:]:  # Exclude 'Unnamed: 0' or case labels
        # Calculate percentage of cases exceeding the thresholds
        above_max = (max_data[joint] > threshold_max).mean() * 100
        below_min = (min_data[joint] < threshold_min).mean() * 100
        violations[joint] = {"above_max": above_max, "below_min": below_min}
    return pd.DataFrame(violations).T

# Calculate threshold violations for 'Lead' and 'Rampart'
lead_violations = calculate_threshold_violations(
    csv_data["lead_max_cases"], csv_data["lead_min_cases"]
)
rampart_violations = calculate_threshold_violations(
    csv_data["rampart_max_cases"], csv_data["rampart_min_cases"]
)

# Prepare the data for visualization
lead_violations["environment"] = "Lead"
rampart_violations["environment"] = "Rampart"
violation_data = pd.concat([lead_violations, rampart_violations])

violation_data
# Out:
#                                     above_max   below_min environment
# Cervical Flexion Fwd [deg]          80.701754   94.736842        Lead
# Cervical Flexion Lat LT [deg]       78.947368   84.210526        Lead
# Cervical Flexion Lat RT [deg]       84.210526   78.947368        Lead
# Cervical Axial LT [deg]            100.000000  100.000000        Lead
# Cervical Axial RT [deg]            100.000000  100.000000        Lead
# Torso-Pelvic Flexion Fwd [deg]      96.491228    8.771930        Lead
# Torso-Pelvic Flexion Lat LT [deg]   82.456140   80.701754        Lead
# Torso-Pelvic Flexion Lat RT [deg]   80.701754   82.456140        Lead
# Torso-Pelvic Axial LT [deg]         85.964912   82.456140        Lead
# Torso-Pelvic Axial RT [deg]         82.456140   85.964912        Lead
# Thoracic Flexion Fwd [deg]          87.719298   10.526316        Lead
# Thoracic Flexion Lat LT [deg]       78.947368   66.666667        Lead
# ...

# %% [markdown]
# - High Risk Areas:
#     - Cervical Axial Movements: Both left and right axial movements exceeded thresholds in 100% of cases for both environments.
#     - Torso-Pelvic and Thoracic Movements: These also showed high percentages of violations, particularly in flexion and axial angles.
# - Low Risk Areas:
#     - Lumbar Flexion Lateral Movements: No violations were observed in lateral flexion for both left and right sides.
#     - Lumbar Axial Movements: Minimal violations were observed, particularly in "Rampart" cases.
# - Environmental Comparisons:
#     - Slightly higher violations in "Rampart" cases for cervical and thoracic flexion.
#     - Torso-Pelvic and lumbar axial movements were more consistent between environments.

# %%
# Function to plot separate bars for threshold violations
def plot_separate_violations(data, environment):
    plt.figure(figsize=(14, 8))
    violations = data[data["environment"] == environment]
    x = range(len(violations.index))
    above_max = violations["above_max"]
    below_min = violations["below_min"]

    plt.bar(x, above_max, width=0.4, label="Above +20°", align='center', alpha=0.7)
    plt.bar([p + 0.4 for p in x], below_min, width=0.4, label="Below -20°", align='center', alpha=0.7)
    
    plt.xticks([p + 0.2 for p in x], violations.index, rotation=90)
    plt.xlabel("Joint Movements")
    plt.ylabel("Percentage of Cases (%)")
    plt.title(f"Ergonomic Threshold Violations in {environment} Environment")
    plt.legend()
    plt.tight_layout()
    plt.show()

# Plot for Lead cases
plot_separate_violations(violation_data, "Lead")

# Plot for Rampart cases
plot_separate_violations(violation_data, "Rampart")

# %% [markdown]
# # Further Statistical Analysis

# %% [markdown]
# Assess any above 60 degrees showcasing high need for improvement.

# %%
# Define ergonomic thresholds
threshold_min = -60
threshold_max = 60

# Function to calculate threshold violations
def calculate_threshold_violations(max_data, min_data):
    violations = {}
    for joint in max_data.columns[1:]:  # Exclude 'Unnamed: 0' or case labels
        # Calculate percentage of cases exceeding the thresholds
        above_max = (max_data[joint] > threshold_max).mean() * 100
        below_min = (min_data[joint] < threshold_min).mean() * 100
        violations[joint] = {"above_max": above_max, "below_min": below_min}
    return pd.DataFrame(violations).T

# Calculate threshold violations for 'Lead' and 'Rampart'
lead_violations = calculate_threshold_violations(
    csv_data["lead_max_cases"], csv_data["lead_min_cases"]
)
rampart_violations = calculate_threshold_violations(
    csv_data["rampart_max_cases"], csv_data["rampart_min_cases"]
)

# Prepare the data for visualization
lead_violations["environment"] = "Lead"
rampart_violations["environment"] = "Rampart"
violation_data = pd.concat([lead_violations, rampart_violations])

violation_data
# Out:
#                                    above_max  below_min environment
# Cervical Flexion Fwd [deg]          0.000000   0.000000        Lead
# Cervical Flexion Lat LT [deg]       0.000000   0.000000        Lead
# Cervical Flexion Lat RT [deg]       0.000000   0.000000        Lead
# Cervical Axial LT [deg]            57.894737  63.157895        Lead
# Cervical Axial RT [deg]            63.157895  57.894737        Lead
# Torso-Pelvic Flexion Fwd [deg]      0.000000   0.000000        Lead
# Torso-Pelvic Flexion Lat LT [deg]   0.000000   0.000000        Lead
# Torso-Pelvic Flexion Lat RT [deg]   0.000000   0.000000        Lead
# Torso-Pelvic Axial LT [deg]         0.000000   0.000000        Lead
# Torso-Pelvic Axial RT [deg]         0.000000   0.000000        Lead
# Thoracic Flexion Fwd [deg]          0.000000   0.000000        Lead
# Thoracic Flexion Lat LT [deg]       0.000000   0.000000        Lead
# Thoracic Flexion Lat RT [deg]       0.000000   0.000000        Lead
# ...

# %%
# Function to plot separate bars for threshold violations
def plot_separate_violations(data, environment):
    plt.figure(figsize=(14, 8))
    violations = data[data["environment"] == environment]
    x = range(len(violations.index))
    above_max = violations["above_max"]
    below_min = violations["below_min"]

    plt.bar(x, above_max, width=0.4, label="Above +60°", align='center', alpha=0.7)
    plt.bar([p + 0.4 for p in x], below_min, width=0.4, label="Below -60°", align='center', alpha=0.7)
    
    plt.xticks([p + 0.2 for p in x], violations.index, rotation=90)
    plt.xlabel("Joint Movements")
    plt.ylabel("Percentage of Cases (%)")
    plt.title(f"Ergonomic Threshold Violations in {environment} Environment")
    plt.legend()
    plt.tight_layout()
    plt.show()

# Plot for Lead cases
plot_separate_violations(violation_data, "Lead")

# Plot for Rampart cases
plot_separate_violations(violation_data, "Rampart")

# %% [markdown]
# It appears that overall the degrees of motion are more constricted for the lead vest compared to the rampart device. There are times where the rampart cases showcase more elevated risk, but it is important to also consider the isometric considerations that the lead vest seems to be very constricting and thus will keep joints in a certain state for a long period of time.

# %% [markdown]
# Overall, the individuals that are above 60 degrees of motion are definitely at high risk though.

# %% [markdown]
# # ROM Baseline Differences
#
# Now begin to look at the largest ROM differences. Which subject had the highest maximum range of motion and the lowest minimum ranges of motion for each joint.

# %%
# Combine all kinematics data for range of motion into dataframes
Baseline_max_cases = pd.DataFrame([ROM_max_case_1, ROM_max_case_2, ROM_max_case_3, ROM_max_case_4, 
                                   ROM_max_case_5, ROM_max_case_6, ROM_max_case_7, ROM_max_case_8, 
                                   ROM_max_case_9, ROM_max_case_10, ROM_max_case_11, ROM_max_case_12,
                                   ROM_max_case_13, ROM_max_case_14, ROM_max_case_15, ROM_max_case_16,
                                   ROM_max_case_17, ROM_max_case_18, ROM_max_case_19, ROM_max_case_20,
                                   ROM_max_case_21, ROM_max_case_22, ROM_max_case_23, ROM_max_case_24,
                                   ROM_max_case_25, ROM_max_case_26, ROM_max_case_27, ROM_max_case_28])

Baseline_min_cases = pd.DataFrame([ROM_min_case_1, ROM_min_case_2, ROM_min_case_3, ROM_min_case_4,
                                   ROM_min_case_5, ROM_min_case_6, ROM_min_case_7, ROM_min_case_8,
                                   ROM_min_case_9, ROM_min_case_10, ROM_min_case_11, ROM_min_case_12,
                                   ROM_min_case_13, ROM_min_case_14, ROM_min_case_15, ROM_min_case_16,
                                   ROM_min_case_17, ROM_min_case_18, ROM_min_case_19, ROM_min_case_20,
                                   ROM_min_case_21, ROM_min_case_22, ROM_min_case_23, ROM_min_case_24,
                                   ROM_min_case_25, ROM_min_case_26, ROM_min_case_27, ROM_min_case_28])

Baseline_range_cases = pd.DataFrame([ROM_case_1, ROM_case_2, ROM_case_3, ROM_case_4, ROM_case_5,
                                     ROM_case_6, ROM_case_7, ROM_case_8, ROM_case_9, ROM_case_10,
                                     ROM_case_11, ROM_case_12, ROM_case_13, ROM_case_14, ROM_case_15,
                                     ROM_case_16, ROM_case_17, ROM_case_18, ROM_case_19, ROM_case_20,
                                     ROM_case_21, ROM_case_22, ROM_case_23, ROM_case_24, ROM_case_25,
                                     ROM_case_26, ROM_case_27, ROM_case_28])

# Set the index to reflect the original subjects
subject_ids = [
    '001', '002', '003', '004', '005', '006', 
    '007', '008', '009', '010', '011', 
    '013', '014', '015', '017', '018',
    '019', '020', '021', '022', '023',
    '024', '026', '027', '028', '029',
    '030', '031'
]

Baseline_max_cases.index = subject_ids
Baseline_min_cases.index = subject_ids
Baseline_range_cases.index = subject_ids

# Calculate z-scores for each joint in baseline cases
baseline_max_zscores = Baseline_max_cases.apply(zscore)
baseline_min_zscores = Baseline_min_cases.apply(zscore)
baseline_range_zscores = Baseline_range_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
baseline_max_outliers = baseline_max_zscores[(baseline_max_zscores > 3) | (baseline_max_zscores < -3)]
baseline_min_outliers = baseline_min_zscores[(baseline_min_zscores > 3) | (baseline_min_zscores < -3)]
baseline_range_outliers = baseline_range_zscores[(baseline_range_zscores > 3) | (baseline_range_zscores < -3)]

# Print the outliers for each case, showcase those that are only outliers and what case they are in
baseline_max_outliers = baseline_max_outliers.dropna(axis=1, how='all')
baseline_min_outliers = baseline_min_outliers.dropna(axis=1, how='all')
baseline_range_outliers = baseline_range_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
baseline_max_outliers.to_csv('baseline_max_outliers.csv')
baseline_min_outliers.to_csv('baseline_min_outliers.csv')
baseline_range_outliers.to_csv('baseline_range_outliers.csv')
# Save the z-scores to a CSV file
baseline_max_zscores.to_csv('baseline_max_zscores.csv')
baseline_min_zscores.to_csv('baseline_min_zscores.csv')
baseline_range_zscores.to_csv('baseline_range_zscores.csv')
# Save the baseline cases to a CSV file
Baseline_max_cases.to_csv('baseline_max_cases.csv')
Baseline_min_cases.to_csv('baseline_min_cases.csv')
Baseline_range_cases.to_csv('baseline_range_cases.csv')

# %%
# Looking at the minimum, maximum, and range of motion for each subjects' basline data
max_cases = pd.read_csv('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_max_cases.csv')
min_cases = pd.read_csv('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_min_cases.csv')
range_cases = pd.read_csv('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_range_cases.csv')

# %%
# Count the number of maximum values for each subject in the max_cases dataset
max_subject_count = max_cases.iloc[:, 1:].idxmax().value_counts()

# Count the number of minimum values for each subject in the min_cases dataset
min_subject_count = min_cases.iloc[:, 1:].idxmin().value_counts()

# Count the number of maximum range values for each subject in the range_cases dataset
range_subject_count = range_cases.iloc[:, 1:].idxmax().value_counts()

# Find the subjects with the most occurrences of max, min, and range values
max_subject_with_highest_count = max_subject_count.idxmax()
min_subject_with_lowest_count = min_subject_count.idxmax()
range_subject_with_highest_range_count = range_subject_count.idxmax()

max_subject_with_highest_count, min_subject_with_lowest_count, range_subject_with_highest_range_count
# Out:
# (np.int64(7), np.int64(7), np.int64(4))

# %% [markdown]
# For the max and min subject it was number 6 and number 3 for the range count index.

# %%
# Plot the max subject data
plt.figure(figsize=(14, 8))
max_subject_count.plot(kind='bar', legend=False)
plt.title('Subjects with the Most Maximum Values')
plt.ylabel('Count')
plt.xlabel('Subject')
# plot the min subject data separate plot
plt.figure(figsize=(14, 8))
min_subject_count.plot(kind='bar', legend=False, color='red')
plt.title('Subjects with the Most Minimum Values')
plt.ylabel('Count')
plt.xlabel('Subject')
# plot the range subject data separate plot
plt.figure(figsize=(14, 8))
range_subject_count.plot(kind='bar', legend=False, color='green')
plt.title('Subjects with the Most Range Values')
plt.ylabel('Count')
plt.xlabel('Subject')
# Out:
# Text(0.5, 0, 'Subject')

# %% [markdown]
# Plot their data.

# %%
# Extract the maximum and minimum data for index 6
max_data_index_6 = max_cases.iloc[5, 1:]
min_data_index_6 = min_cases.iloc[5, 1:]

# Plot the maximum data
plt.figure(figsize=(14, 8))
max_data_index_6.plot(kind='bar', color='blue', alpha=0.7)
plt.title('Maximum Data for Subject 6')
plt.ylabel('Degrees')
plt.xlabel('Joint Movements')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# Plot the minimum data
plt.figure(figsize=(14, 8))
min_data_index_6.plot(kind='bar', color='red', alpha=0.7)
plt.title('Minimum Data for Subject 6')
plt.ylabel('Degrees')
plt.xlabel('Joint Movements')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# This individual usually had the largeset max and min data. We can also see they were one of the ones that had the highest amount of largest ranges in degrees as well.

# %%
# Extract the range data for index 3, 6, and 14
range_individual_3 = range_cases.iloc[1, 1:]
range_individual_6 = range_cases.iloc[5, 1:]
range_individual_14 = range_cases.iloc[13, 1:]

range_individual_3 = range_individual_3[columns_to_use]
range_individual_6 = range_individual_6[columns_to_use]
range_individual_14 = range_individual_14[columns_to_use]

# Plot the range data for index 3
# Note this is actually subject 2
plt.figure(figsize=(14, 8))
range_individual_3.plot(kind='bar', color='blue', alpha=0.7)
plt.title('Range Data for Individual 2')
plt.ylabel('Degrees')
plt.xlabel('Joint Movements')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# Plot the range data for index 6
plt.figure(figsize=(14, 8))
range_individual_6.plot(kind='bar', color='green', alpha=0.7)
plt.title('Range Data for Individual 6')
plt.ylabel('Degrees')
plt.xlabel('Joint Movements')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# Plot the range data for index 14
# Note this is actually subject 15
plt.figure(figsize=(14, 8))
range_individual_14.plot(kind='bar', color='red', alpha=0.7)
plt.title('Range Data for Individual 15')
plt.ylabel('Degrees')
plt.xlabel('Joint Movements')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# - Now consider about making the data so that we remove the negatives. This is the case for the joints.
# - Also, focus on the data being only cervical, thoracic and lumbar to really hone in on those for some cases too.
# - Do a case analysis for the individuals of these large ranges. Also, find the minimum range individuals.

# %%
# Count the number of maximum range values for each subject in the range_cases dataset
range_subject_count = range_cases.iloc[:, 1:].idxmin().value_counts()

range_subject_with_lowest_range_count = range_subject_count.idxmax()

range_subject_with_lowest_range_count
# Out:
# np.int64(19)

# %% [markdown]
# So, it appears that subject 18 had the smallest ranges. Display the data.

# %%
# Extract the range data for index 18
range_individual_18 = range_cases.iloc[17, 1:]

range_individual_18 = range_individual_18[columns_to_use]

# Plot the range data for index 18
# Note this is actually subject 20 from the study
plt.figure(figsize=(14, 8))
range_individual_18.plot(kind='bar', color='blue', alpha=0.7)
plt.title('Range Data for Individual 20')
plt.ylabel('Degrees')
plt.xlabel('Joint Movements')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the range for the baselines of the individuals
range_total_difference = range_individual_6 - range_individual_18
# Plot the difference
# note this is actually subject 5 - subject 20
range_total_difference.plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Range of Motion (Individual 6 - Individual 20)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
