# %%
#**********************
# Name: Jonah Zembower
# Date: January 7, 2025
# Project: Harvard Research Study on Postural Stability During Heart Catheterization Surgeries
#***************************

# %%
# Import Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import the Code for the Joint Angles Data

# %%
# Load in all the data
Case_1_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case3_rampart.xlsx', sheet_name = 'Joint Angles 3')
Case_4_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case4_lead.xlsx', sheet_name = 'Joint Angles 4')
Case_6_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_case6_rampart.xlsx', sheet_name = 'Joint Angles 6')
Case_1_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_Case1_rampart.xlsx', sheet_name = 'Joint Angles 1')
Case_2_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_Case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_Case3_lead.xlsx', sheet_name = 'Joint Angles 3')
Case_4_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_Case4_rampart.xlsx', sheet_name = 'Joint Angles 4')
Case_1_003 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\003_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_003 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\003_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_4_003 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\003_case4_lead.xlsx', sheet_name = 'Joint Angles 4')
Case_1_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_case3_rampart.xlsx', sheet_name = 'Joint Angles 3')
Case_4_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_case4_rampart.xlsx', sheet_name = 'Joint Angles 4')
Case_1_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_case1_rampart.xlsx', sheet_name = 'Joint Angles 1')
Case_3_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_case3_lead.xlsx', sheet_name = 'Joint Angles 3')
Case_4_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_case4_rampart.xlsx', sheet_name = 'Joint Angles 4')
Case_5_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_case5_lead.xlsx', sheet_name = 'Joint Angles 5')
Case_1_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_case3_rampart.xlsx', sheet_name = 'Joint Angles 3')
Case_4_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_case4_rampart.xlsx', sheet_name = 'Joint Angles 4')
Case_1_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_case3_rampart.xlsx', sheet_name = 'Joint Angles 3')
Case_4_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_case4_rampart.xlsx', sheet_name = 'Joint Angles 4')
Case_1_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_case1_rampart.xlsx', sheet_name = 'Joint Angles 1')
Case_2_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_case3_lead.xlsx', sheet_name = 'Joint Angles 3')
Case_4_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_case4_rampart.xlsx', sheet_name = 'Joint Angles 4')
Case_1_009 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\009_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_009 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\009_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_010 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\010_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_010 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\010_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_010 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\010_case3_lead.xlsx', sheet_name = 'Joint Angles 3')
Case_1_011 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\011_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_011 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\011_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_013 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\013_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_013 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\013_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_014 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\014_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_014 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\014_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_015 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\015_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_015 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\015_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_017 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\017_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_017 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\017_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_018 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\018_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_018 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\018_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_case1_rampart.xlsx', sheet_name = 'Joint Angles 1')
Case_2_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_case3_lead.xlsx', sheet_name = 'Joint Angles 3')
Case_4_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_case4_rampart.xlsx', sheet_name = 'Joint Angles 4')
Case_1_020 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\020_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_020 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\020_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_021 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\021_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_021 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\021_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_case2_rampart.xlsx', sheet_name = 'Joint Angles 2')
Case_3_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_case3_rampart.xlsx', sheet_name = 'Joint Angles 3')
Case_4_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_case4_lead.xlsx', sheet_name = 'Joint Angles 4')
Case_1_023 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\023_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_023 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\023_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_4_023 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\023_case4_rampart.xlsx', sheet_name = 'Joint Angles 4')
Case_1_024 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\024_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_024 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\024_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_026 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\026_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_026 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\026_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_027 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\027_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_1_028 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\028_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_028 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\028_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_029 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\029_case1_lead.xlsx', sheet_name = 'Joint Angles 1')
Case_2_029 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\029_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_1_030 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\030_case1_rampart.xlsx', sheet_name = 'Joint Angles 1')
Case_2_030 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\030_case2_lead.xlsx', sheet_name = 'Joint Angles 2')
Case_3_030 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\030_case3_lead.xlsx', sheet_name = 'Joint Angles 3')
Case_1_031 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\031_case1_rampart.xlsx', sheet_name = 'Joint Angles 1')
Case_2_031 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\031_case2_lead.xlsx', sheet_name = 'Joint Angles 2')

# %% [markdown]
# - This data includes the joint angles in the degrees below, inside, and above the threshold. This showcases the average mean for those values as well.
# - The other rows are the sum of duration percentages for when they are below, inside, and above the threshold.
# - The threshold that was set, was the +20, -20 for each joint. So, that is important to take into account as well.

# %%
# Extract the mean below for each case
lead_mean_below_Case_1_001 = Case_1_001.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_001 = Case_2_001.iloc[0, 1:].astype(float)
ram_mean_below_Case_3_001 = Case_3_001.iloc[0, 1:].astype(float)
lead_mean_below_Case_4_001 = Case_4_001.iloc[0, 1:].astype(float)
ram_mean_below_Case_6_001 = Case_6_001.iloc[0, 1:].astype(float)
ram_mean_below_Case_1_002 = Case_1_002.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_002 = Case_2_002.iloc[0, 1:].astype(float)
lead_mean_below_Case_3_002 = Case_3_002.iloc[0, 1:].astype(float)
ram_mean_below_Case_4_002 = Case_4_002.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_003 = Case_1_003.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_003 = Case_2_003.iloc[0, 1:].astype(float)
lead_mean_below_Case_4_003 = Case_4_003.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_004 = Case_1_004.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_004 = Case_2_004.iloc[0, 1:].astype(float)
ram_mean_below_Case_3_004 = Case_3_004.iloc[0, 1:].astype(float)
ram_mean_below_Case_4_004 = Case_4_004.iloc[0, 1:].astype(float)
ram_mean_below_Case_1_005 = Case_1_005.iloc[0, 1:].astype(float)
lead_mean_below_Case_3_005 = Case_3_005.iloc[0, 1:].astype(float)
ram_mean_below_Case_4_005 = Case_4_005.iloc[0, 1:].astype(float)
lead_mean_below_Case_5_005 = Case_5_005.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_006 = Case_1_006.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_006 = Case_2_006.iloc[0, 1:].astype(float)
ram_mean_below_Case_3_006 = Case_3_006.iloc[0, 1:].astype(float)
ram_mean_below_Case_4_006 = Case_4_006.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_007 = Case_1_007.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_007 = Case_2_007.iloc[0, 1:].astype(float)
ram_mean_below_Case_3_007 = Case_3_007.iloc[0, 1:].astype(float)
ram_mean_below_Case_4_007 = Case_4_007.iloc[0, 1:].astype(float)
ram_mean_below_Case_1_008 = Case_1_008.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_008 = Case_2_008.iloc[0, 1:].astype(float)
lead_mean_below_Case_3_008 = Case_3_008.iloc[0, 1:].astype(float)
ram_mean_below_Case_4_008 = Case_4_008.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_009 = Case_1_009.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_009 = Case_2_009.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_010 = Case_1_010.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_010 = Case_2_010.iloc[0, 1:].astype(float)
lead_mean_below_Case_3_010 = Case_3_010.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_011 = Case_1_011.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_011 = Case_2_011.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_013 = Case_1_013.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_013 = Case_2_013.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_014 = Case_1_014.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_014 = Case_2_014.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_015 = Case_1_015.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_015 = Case_2_015.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_017 = Case_1_017.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_017 = Case_2_017.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_018 = Case_1_018.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_018 = Case_2_018.iloc[0, 1:].astype(float)
ram_mean_below_Case_1_019 = Case_1_019.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_019 = Case_2_019.iloc[0, 1:].astype(float)
lead_mean_below_Case_3_019 = Case_3_019.iloc[0, 1:].astype(float)
ram_mean_below_Case_4_019 = Case_4_019.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_020 = Case_1_020.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_020 = Case_2_020.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_021 = Case_1_021.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_021 = Case_2_021.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_022 = Case_1_022.iloc[0, 1:].astype(float)
ram_mean_below_Case_2_022 = Case_2_022.iloc[0, 1:].astype(float)
ram_mean_below_Case_3_022 = Case_3_022.iloc[0, 1:].astype(float)
lead_mean_below_Case_4_022 = Case_4_022.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_023 = Case_1_023.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_023 = Case_2_023.iloc[0, 1:].astype(float)
ram_mean_below_Case_4_023 = Case_4_023.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_024 = Case_1_024.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_024 = Case_2_024.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_026 = Case_1_026.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_026 = Case_2_026.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_027 = Case_1_027.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_028 = Case_1_028.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_028 = Case_2_028.iloc[0, 1:].astype(float)
lead_mean_below_Case_1_029 = Case_1_029.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_029 = Case_2_029.iloc[0, 1:].astype(float)
ram_mean_below_Case_1_030 = Case_1_030.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_030 = Case_2_030.iloc[0, 1:].astype(float)
lead_mean_below_Case_3_030 = Case_3_030.iloc[0, 1:].astype(float)
ram_mean_below_Case_1_031 = Case_1_031.iloc[0, 1:].astype(float)
lead_mean_below_Case_2_031 = Case_2_031.iloc[0, 1:].astype(float)

# %%
# Load in the ROM data
ROM_001 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\001_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_002 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\002_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_003 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\003_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_004 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\004_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_005 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\005_ROMbaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_006 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\006_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_007 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\007_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_008 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\008_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_009 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\009_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_010 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\010_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_011 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\011_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_013 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\013_ROMbaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_014 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\014_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_015 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\015_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_017 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\017_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_018 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\018_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_019 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\019_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_020 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\020_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_021 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\021_ROMbaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_022 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\022_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_023 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\023_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_024 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\024_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_026 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\026_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_027 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\027_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_028 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\028_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_029 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\029_ROMbaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_030 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\030_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')
ROM_031 = pd.read_excel('C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\Full Subject Data\\031_ROMBaseline.xlsx', sheet_name='Joint Angles ROM')

# %%
# Extract the mean degree below threshold for each ROM Baseline
ROM_mean_below_001 = ROM_001.iloc[0, 1:].astype(float)
ROM_mean_below_002 = ROM_002.iloc[0, 1:].astype(float)
ROM_mean_below_003 = ROM_003.iloc[0, 1:].astype(float)
ROM_mean_below_004 = ROM_004.iloc[0, 1:].astype(float)
ROM_mean_below_005 = ROM_005.iloc[0, 1:].astype(float)
ROM_mean_below_006 = ROM_006.iloc[0, 1:].astype(float)
ROM_mean_below_007 = ROM_007.iloc[0, 1:].astype(float)
ROM_mean_below_008 = ROM_008.iloc[0, 1:].astype(float)
ROM_mean_below_009 = ROM_009.iloc[0, 1:].astype(float)
ROM_mean_below_010 = ROM_010.iloc[0, 1:].astype(float)
ROM_mean_below_011 = ROM_011.iloc[0, 1:].astype(float)
ROM_mean_below_013 = ROM_013.iloc[0, 1:].astype(float)
ROM_mean_below_014 = ROM_014.iloc[0, 1:].astype(float)
ROM_mean_below_015 = ROM_015.iloc[0, 1:].astype(float)
ROM_mean_below_017 = ROM_017.iloc[0, 1:].astype(float)
ROM_mean_below_018 = ROM_018.iloc[0, 1:].astype(float)
ROM_mean_below_019 = ROM_019.iloc[0, 1:].astype(float)
ROM_mean_below_020 = ROM_020.iloc[0, 1:].astype(float)
ROM_mean_below_021 = ROM_021.iloc[0, 1:].astype(float)
ROM_mean_below_022 = ROM_022.iloc[0, 1:].astype(float)
ROM_mean_below_023 = ROM_023.iloc[0, 1:].astype(float)
ROM_mean_below_024 = ROM_024.iloc[0, 1:].astype(float)
ROM_mean_below_026 = ROM_026.iloc[0, 1:].astype(float)
ROM_mean_below_027 = ROM_027.iloc[0, 1:].astype(float)
ROM_mean_below_028 = ROM_028.iloc[0, 1:].astype(float)
ROM_mean_below_029 = ROM_029.iloc[0, 1:].astype(float)
ROM_mean_below_030 = ROM_030.iloc[0, 1:].astype(float)
ROM_mean_below_031 = ROM_031.iloc[0, 1:].astype(float)

# %%
# Average out the rampart values
ram_avg = (ram_mean_below_Case_3_001 +  ram_mean_below_Case_6_001 
            + ram_mean_below_Case_1_002 + ram_mean_below_Case_4_002 + 
           ram_mean_below_Case_3_004 + ram_mean_below_Case_4_004 + ram_mean_below_Case_1_005 + 
           ram_mean_below_Case_4_005 + ram_mean_below_Case_3_006 + ram_mean_below_Case_4_006 + 
           ram_mean_below_Case_3_007 + ram_mean_below_Case_4_007 + ram_mean_below_Case_1_008 + 
           ram_mean_below_Case_4_008 + ram_mean_below_Case_1_019 + ram_mean_below_Case_4_019 + 
           ram_mean_below_Case_2_022 + ram_mean_below_Case_3_022 + ram_mean_below_Case_4_023 + ram_mean_below_Case_1_030 + 
           ram_mean_below_Case_1_031) / 21

# Average out the lead values
lead_avg = (lead_mean_below_Case_1_001 + lead_mean_below_Case_2_001 + lead_mean_below_Case_4_001 + 
            lead_mean_below_Case_2_002 + lead_mean_below_Case_3_002 + lead_mean_below_Case_1_003 +
            + lead_mean_below_Case_2_003 + lead_mean_below_Case_4_003 + lead_mean_below_Case_1_004 + 
            lead_mean_below_Case_2_004 + lead_mean_below_Case_3_005 + lead_mean_below_Case_5_005 + 
            lead_mean_below_Case_1_006 + lead_mean_below_Case_2_006 + lead_mean_below_Case_1_007 + 
            lead_mean_below_Case_2_007 + lead_mean_below_Case_2_008 + lead_mean_below_Case_3_008 + 
            lead_mean_below_Case_1_009 + lead_mean_below_Case_2_009 + lead_mean_below_Case_1_010 + 
            lead_mean_below_Case_2_010 + lead_mean_below_Case_3_010 + lead_mean_below_Case_1_011 + 
            lead_mean_below_Case_2_011 + lead_mean_below_Case_1_013 + lead_mean_below_Case_2_013 + 
            lead_mean_below_Case_1_014 + lead_mean_below_Case_2_014 + lead_mean_below_Case_1_015 + 
            lead_mean_below_Case_2_015 + lead_mean_below_Case_1_017 + lead_mean_below_Case_2_017 + 
            lead_mean_below_Case_1_018 + lead_mean_below_Case_2_018 + lead_mean_below_Case_2_019 + 
            lead_mean_below_Case_3_019 + lead_mean_below_Case_1_020 + lead_mean_below_Case_2_020 + 
            lead_mean_below_Case_1_021 + lead_mean_below_Case_2_021 + lead_mean_below_Case_1_022 + 
            lead_mean_below_Case_4_022 + lead_mean_below_Case_1_023 + lead_mean_below_Case_2_023 + 
            lead_mean_below_Case_1_024 + lead_mean_below_Case_2_024 + lead_mean_below_Case_1_026 + 
            lead_mean_below_Case_2_026 + lead_mean_below_Case_1_027 + lead_mean_below_Case_1_028 + 
            lead_mean_below_Case_2_028 + lead_mean_below_Case_1_029 + lead_mean_below_Case_2_029 + 
            lead_mean_below_Case_2_030 + lead_mean_below_Case_3_030 + lead_mean_below_Case_2_031) / 57

# Average out the ROM values
ROM_avg = (ROM_mean_below_001 + ROM_mean_below_002 + ROM_mean_below_003 + ROM_mean_below_004 + ROM_mean_below_005 + 
           ROM_mean_below_006 + ROM_mean_below_007 + ROM_mean_below_008 + ROM_mean_below_009 + 
           ROM_mean_below_010 + ROM_mean_below_011 + ROM_mean_below_013 + ROM_mean_below_014 + 
           ROM_mean_below_015 + ROM_mean_below_017 + ROM_mean_below_018 + ROM_mean_below_019 + 
           ROM_mean_below_020 + ROM_mean_below_021 + ROM_mean_below_022 + ROM_mean_below_023 + 
           ROM_mean_below_024 + ROM_mean_below_026 + ROM_mean_below_027 + ROM_mean_below_028 + 
           ROM_mean_below_029 + ROM_mean_below_030 + ROM_mean_below_031) / 28

# Create a dataframe for the averages
average_df = pd.DataFrame({
    'Rampart Average': ram_avg,
    'Lead Average': lead_avg,
    'ROM Baseline Average': ROM_avg
})

# Plot the comparison
average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Full Mean Below Threshold Comparison (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the rampart and lead averages
average_df['Difference'] = average_df['Rampart Average'] - average_df['Lead Average']
# Plot the difference
average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Full Mean Below (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
from scipy.stats import zscore

# Combine all lead, rampart, and ROM cases into separate dataframes
lead_cases = pd.DataFrame([
    lead_mean_below_Case_1_001, lead_mean_below_Case_2_001, lead_mean_below_Case_4_001, lead_mean_below_Case_2_002, lead_mean_below_Case_3_002,
    lead_mean_below_Case_1_003, lead_mean_below_Case_2_003, lead_mean_below_Case_4_003,
    lead_mean_below_Case_1_004, lead_mean_below_Case_2_004, lead_mean_below_Case_3_005, lead_mean_below_Case_5_005, lead_mean_below_Case_1_006,
    lead_mean_below_Case_2_006, lead_mean_below_Case_1_007, lead_mean_below_Case_2_007, lead_mean_below_Case_2_008, lead_mean_below_Case_3_008,
    lead_mean_below_Case_1_009, lead_mean_below_Case_2_009, lead_mean_below_Case_1_010, lead_mean_below_Case_2_010, lead_mean_below_Case_3_010,
    lead_mean_below_Case_1_011, lead_mean_below_Case_2_011, lead_mean_below_Case_1_013, lead_mean_below_Case_2_013, lead_mean_below_Case_1_014,
    lead_mean_below_Case_2_014, lead_mean_below_Case_1_015, lead_mean_below_Case_2_015, lead_mean_below_Case_1_017, lead_mean_below_Case_2_017,
    lead_mean_below_Case_1_018, lead_mean_below_Case_2_018, lead_mean_below_Case_2_019, lead_mean_below_Case_3_019, lead_mean_below_Case_1_020,
    lead_mean_below_Case_2_020, lead_mean_below_Case_1_021, lead_mean_below_Case_2_021, lead_mean_below_Case_1_022, lead_mean_below_Case_4_022,
    lead_mean_below_Case_1_023, lead_mean_below_Case_2_023, lead_mean_below_Case_1_024, lead_mean_below_Case_2_024, lead_mean_below_Case_1_026,
    lead_mean_below_Case_2_026, lead_mean_below_Case_1_027, lead_mean_below_Case_1_028, lead_mean_below_Case_2_028, lead_mean_below_Case_1_029,
    lead_mean_below_Case_2_029, lead_mean_below_Case_2_030, lead_mean_below_Case_3_030, lead_mean_below_Case_2_031
])

rampart_cases = pd.DataFrame([
    ram_mean_below_Case_3_001,  ram_mean_below_Case_6_001, ram_mean_below_Case_1_002,
    ram_mean_below_Case_4_002, ram_mean_below_Case_3_004, ram_mean_below_Case_4_004, ram_mean_below_Case_1_005, ram_mean_below_Case_4_005,
    ram_mean_below_Case_3_006, ram_mean_below_Case_4_006, ram_mean_below_Case_3_007, ram_mean_below_Case_4_007, ram_mean_below_Case_1_008,
    ram_mean_below_Case_4_008, ram_mean_below_Case_1_019, ram_mean_below_Case_4_019, ram_mean_below_Case_2_022, ram_mean_below_Case_3_022, ram_mean_below_Case_4_023,
    ram_mean_below_Case_1_030, ram_mean_below_Case_1_031
])

rom_cases = pd.DataFrame([
    ROM_mean_below_001, ROM_mean_below_002, ROM_mean_below_003, ROM_mean_below_004, ROM_mean_below_005, ROM_mean_below_006, ROM_mean_below_007, ROM_mean_below_008,
    ROM_mean_below_009, ROM_mean_below_010, ROM_mean_below_011, ROM_mean_below_013, ROM_mean_below_014, ROM_mean_below_015, ROM_mean_below_017,
    ROM_mean_below_018, ROM_mean_below_019, ROM_mean_below_020, ROM_mean_below_021, ROM_mean_below_022, ROM_mean_below_023, ROM_mean_below_024,
    ROM_mean_below_026, ROM_mean_below_027, ROM_mean_below_028, ROM_mean_below_029, ROM_mean_below_030, ROM_mean_below_031
])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022', '4_023',
    '1_030', '1_031'
]

rampart_cases.index = subject_ids_rampart

subject_ids_rom = [
    '001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '013', '014', '015', '017', '018', '019', '020', '021', '022', '023', '024', '026', '027', '028', '029', '030', '031'
]

rom_cases.index = subject_ids_rom

# Calculate z-scores for each joint in lead, rampart, and ROM cases
lead_zscores = lead_cases.apply(zscore)
rampart_zscores = rampart_cases.apply(zscore)
rom_zscores = rom_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_outliers = lead_zscores[(lead_zscores > 3) | (lead_zscores < -3)]
rampart_outliers = rampart_zscores[(rampart_zscores > 3) | (rampart_zscores < -3)]
rom_outliers = rom_zscores[(rom_zscores > 3) | (rom_zscores < -3)]

# Drop columns with all NaN values
lead_outliers = lead_outliers.dropna(axis=1, how='all')
rampart_outliers = rampart_outliers.dropna(axis=1, how='all')
rom_outliers = rom_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
lead_outliers.to_csv('lead_outliers_mean_below.csv')
rampart_outliers.to_csv('rampart_outliers_mean_below.csv')
rom_outliers.to_csv('baseline_outliers_mean_below.csv')

# Save the z-scores to a CSV file
lead_zscores.to_csv('lead_zscores_mean_below.csv')
rampart_zscores.to_csv('rampart_zscores_mean_below.csv')
rom_zscores.to_csv('baseline_zscores_mean_below.csv')

# Save the lead, rampart, and ROM cases to a CSV file
lead_cases.to_csv('lead_cases_mean_below.csv')
rampart_cases.to_csv('rampart_cases_mean_below.csv')
rom_cases.to_csv('baseline_mean_below.csv')

# %% [markdown]
# Now begin to assess the mean degree inside threshold.

# %%
# Extract the mean inside for each case
lead_mean_inside_Case_1_001 = Case_1_001.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_001 = Case_2_001.iloc[2, 1:].astype(float)
ram_mean_inside_Case_3_001 = Case_3_001.iloc[2, 1:].astype(float)
lead_mean_inside_Case_4_001 = Case_4_001.iloc[2, 1:].astype(float)
ram_mean_inside_Case_6_001 = Case_6_001.iloc[2, 1:].astype(float)
ram_mean_inside_Case_1_002 = Case_1_002.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_002 = Case_2_002.iloc[2, 1:].astype(float)
lead_mean_inside_Case_3_002 = Case_3_002.iloc[2, 1:].astype(float)
ram_mean_inside_Case_4_002 = Case_4_002.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_003 = Case_1_003.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_003 = Case_2_003.iloc[2, 1:].astype(float)
lead_mean_inside_Case_4_003 = Case_4_003.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_004 = Case_1_004.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_004 = Case_2_004.iloc[2, 1:].astype(float)
ram_mean_inside_Case_3_004 = Case_3_004.iloc[2, 1:].astype(float)
ram_mean_inside_Case_4_004 = Case_4_004.iloc[2, 1:].astype(float)
ram_mean_inside_Case_1_005 = Case_1_005.iloc[2, 1:].astype(float)
lead_mean_inside_Case_3_005 = Case_3_005.iloc[2, 1:].astype(float)
ram_mean_inside_Case_4_005 = Case_4_005.iloc[2, 1:].astype(float)
lead_mean_inside_Case_5_005 = Case_5_005.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_006 = Case_1_006.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_006 = Case_2_006.iloc[2, 1:].astype(float)
ram_mean_inside_Case_3_006 = Case_3_006.iloc[2, 1:].astype(float)
ram_mean_inside_Case_4_006 = Case_4_006.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_007 = Case_1_007.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_007 = Case_2_007.iloc[2, 1:].astype(float)
ram_mean_inside_Case_3_007 = Case_3_007.iloc[2, 1:].astype(float)
ram_mean_inside_Case_4_007 = Case_4_007.iloc[2, 1:].astype(float)
ram_mean_inside_Case_1_008 = Case_1_008.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_008 = Case_2_008.iloc[2, 1:].astype(float)
lead_mean_inside_Case_3_008 = Case_3_008.iloc[2, 1:].astype(float)
ram_mean_inside_Case_4_008 = Case_4_008.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_009 = Case_1_009.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_009 = Case_2_009.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_010 = Case_1_010.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_010 = Case_2_010.iloc[2, 1:].astype(float)
lead_mean_inside_Case_3_010 = Case_3_010.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_011 = Case_1_011.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_011 = Case_2_011.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_013 = Case_1_013.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_013 = Case_2_013.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_014 = Case_1_014.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_014 = Case_2_014.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_015 = Case_1_015.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_015 = Case_2_015.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_017 = Case_1_017.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_017 = Case_2_017.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_018 = Case_1_018.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_018 = Case_2_018.iloc[2, 1:].astype(float)
ram_mean_inside_Case_1_019 = Case_1_019.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_019 = Case_2_019.iloc[2, 1:].astype(float)
lead_mean_inside_Case_3_019 = Case_3_019.iloc[2, 1:].astype(float)
ram_mean_inside_Case_4_019 = Case_4_019.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_020 = Case_1_020.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_020 = Case_2_020.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_021 = Case_1_021.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_021 = Case_2_021.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_022 = Case_1_022.iloc[2, 1:].astype(float)
ram_mean_inside_Case_2_022 = Case_2_022.iloc[2, 1:].astype(float)
ram_mean_inside_Case_3_022 = Case_3_022.iloc[2, 1:].astype(float)
lead_mean_inside_Case_4_022 = Case_4_022.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_023 = Case_1_023.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_023 = Case_2_023.iloc[2, 1:].astype(float)
ram_mean_inside_Case_4_023 = Case_4_023.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_024 = Case_1_024.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_024 = Case_2_024.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_026 = Case_1_026.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_026 = Case_2_026.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_027 = Case_1_027.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_028 = Case_1_028.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_028 = Case_2_028.iloc[2, 1:].astype(float)
lead_mean_inside_Case_1_029 = Case_1_029.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_029 = Case_2_029.iloc[2, 1:].astype(float)
ram_mean_inside_Case_1_030 = Case_1_030.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_030 = Case_2_030.iloc[2, 1:].astype(float)
lead_mean_inside_Case_3_030 = Case_3_030.iloc[2, 1:].astype(float)
ram_mean_inside_Case_1_031 = Case_1_031.iloc[2, 1:].astype(float)
lead_mean_inside_Case_2_031 = Case_2_031.iloc[2, 1:].astype(float)

# %%
# Extract the mean degree inside threshold for each ROM Baseline
ROM_mean_inside_001 = ROM_001.iloc[2, 1:].astype(float)
ROM_mean_inside_002 = ROM_002.iloc[2, 1:].astype(float)
ROM_mean_inside_003 = ROM_003.iloc[2, 1:].astype(float)
ROM_mean_inside_004 = ROM_004.iloc[2, 1:].astype(float)
ROM_mean_inside_005 = ROM_005.iloc[2, 1:].astype(float)
ROM_mean_inside_006 = ROM_006.iloc[2, 1:].astype(float)
ROM_mean_inside_007 = ROM_007.iloc[2, 1:].astype(float)
ROM_mean_inside_008 = ROM_008.iloc[2, 1:].astype(float)
ROM_mean_inside_009 = ROM_009.iloc[2, 1:].astype(float)
ROM_mean_inside_010 = ROM_010.iloc[2, 1:].astype(float)
ROM_mean_inside_011 = ROM_011.iloc[2, 1:].astype(float)
ROM_mean_inside_013 = ROM_013.iloc[2, 1:].astype(float)
ROM_mean_inside_014 = ROM_014.iloc[2, 1:].astype(float)
ROM_mean_inside_015 = ROM_015.iloc[2, 1:].astype(float)
ROM_mean_inside_017 = ROM_017.iloc[2, 1:].astype(float)
ROM_mean_inside_018 = ROM_018.iloc[2, 1:].astype(float)
ROM_mean_inside_019 = ROM_019.iloc[2, 1:].astype(float)
ROM_mean_inside_020 = ROM_020.iloc[2, 1:].astype(float)
ROM_mean_inside_021 = ROM_021.iloc[2, 1:].astype(float)
ROM_mean_inside_022 = ROM_022.iloc[2, 1:].astype(float)
ROM_mean_inside_023 = ROM_023.iloc[2, 1:].astype(float)
ROM_mean_inside_024 = ROM_024.iloc[2, 1:].astype(float)
ROM_mean_inside_026 = ROM_026.iloc[2, 1:].astype(float)
ROM_mean_inside_027 = ROM_027.iloc[2, 1:].astype(float)
ROM_mean_inside_028 = ROM_028.iloc[2, 1:].astype(float)
ROM_mean_inside_029 = ROM_029.iloc[2, 1:].astype(float)
ROM_mean_inside_030 = ROM_030.iloc[2, 1:].astype(float)
ROM_mean_inside_031 = ROM_031.iloc[2, 1:].astype(float)

# %%
from scipy.stats import zscore

# Combine all lead and rampart cases into separate dataframes
lead_cases = pd.DataFrame([
    lead_mean_inside_Case_1_001, lead_mean_inside_Case_2_001, lead_mean_inside_Case_4_001, lead_mean_inside_Case_2_002, lead_mean_inside_Case_3_002,
    lead_mean_inside_Case_1_003, lead_mean_inside_Case_2_003, lead_mean_inside_Case_4_003,
    lead_mean_inside_Case_1_004, lead_mean_inside_Case_2_004, lead_mean_inside_Case_3_005, lead_mean_inside_Case_5_005, lead_mean_inside_Case_1_006,
    lead_mean_inside_Case_2_006, lead_mean_inside_Case_1_007, lead_mean_inside_Case_2_007, lead_mean_inside_Case_2_008, lead_mean_inside_Case_3_008,
    lead_mean_inside_Case_1_009, lead_mean_inside_Case_2_009, lead_mean_inside_Case_1_010, lead_mean_inside_Case_2_010, lead_mean_inside_Case_3_010,
    lead_mean_inside_Case_1_011, lead_mean_inside_Case_2_011, lead_mean_inside_Case_1_013, lead_mean_inside_Case_2_013, lead_mean_inside_Case_1_014,
    lead_mean_inside_Case_2_014, lead_mean_inside_Case_1_015, lead_mean_inside_Case_2_015, lead_mean_inside_Case_1_017, lead_mean_inside_Case_2_017,
    lead_mean_inside_Case_1_018, lead_mean_inside_Case_2_018, lead_mean_inside_Case_2_019, lead_mean_inside_Case_3_019, lead_mean_inside_Case_1_020,
    lead_mean_inside_Case_2_020, lead_mean_inside_Case_1_021, lead_mean_inside_Case_2_021, lead_mean_inside_Case_1_022, lead_mean_inside_Case_4_022,
    lead_mean_inside_Case_1_023, lead_mean_inside_Case_2_023, lead_mean_inside_Case_1_024, lead_mean_inside_Case_2_024, lead_mean_inside_Case_1_026,
    lead_mean_inside_Case_2_026, lead_mean_inside_Case_1_027, lead_mean_inside_Case_1_028, lead_mean_inside_Case_2_028, lead_mean_inside_Case_1_029,
    lead_mean_inside_Case_2_029, lead_mean_inside_Case_2_030, lead_mean_inside_Case_3_030, lead_mean_inside_Case_2_031
])

rampart_cases = pd.DataFrame([
    ram_mean_inside_Case_3_001, ram_mean_inside_Case_6_001, ram_mean_inside_Case_1_002,
    ram_mean_inside_Case_4_002, ram_mean_inside_Case_3_004, ram_mean_inside_Case_4_004, ram_mean_inside_Case_1_005, ram_mean_inside_Case_4_005,
    ram_mean_inside_Case_3_006, ram_mean_inside_Case_4_006, ram_mean_inside_Case_3_007, ram_mean_inside_Case_4_007, ram_mean_inside_Case_1_008,
    ram_mean_inside_Case_4_008, ram_mean_inside_Case_1_019, ram_mean_inside_Case_4_019, ram_mean_inside_Case_2_022, ram_mean_inside_Case_3_022, ram_mean_inside_Case_4_023,
    ram_mean_inside_Case_1_030, ram_mean_inside_Case_1_031
])

rom_cases = pd.DataFrame([
    ROM_mean_inside_001, ROM_mean_inside_002, ROM_mean_inside_003, ROM_mean_inside_004, ROM_mean_inside_005, ROM_mean_inside_006, ROM_mean_inside_007, ROM_mean_inside_008,
    ROM_mean_inside_009, ROM_mean_inside_010, ROM_mean_inside_011, ROM_mean_inside_013, ROM_mean_inside_014, ROM_mean_inside_015, ROM_mean_inside_017,
    ROM_mean_inside_018, ROM_mean_inside_019, ROM_mean_inside_020, ROM_mean_inside_021, ROM_mean_inside_022, ROM_mean_inside_023, ROM_mean_inside_024,
    ROM_mean_inside_026, ROM_mean_inside_027, ROM_mean_inside_028, ROM_mean_inside_029, ROM_mean_inside_030, ROM_mean_inside_031
])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022', '4_023',
    '1_030', '1_031'
]

rampart_cases.index = subject_ids_rampart

subject_ids_rom = [
    '001', '002', '003','004', '005', '006', '007', '008', '009', '010', '011', '013', '014', '015', '017', '018', '019', '020', '021', '022', '023', '024', '026', '027', '028', '029', '030', '031'
]

rom_cases.index = subject_ids_rom

# Calculate z-scores for each joint in lead, rampart, and ROM cases
lead_zscores = lead_cases.apply(zscore)
rampart_zscores = rampart_cases.apply(zscore)
rom_zscores = rom_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_outliers = lead_zscores[(lead_zscores > 3) | (lead_zscores < -3)]
rampart_outliers = rampart_zscores[(rampart_zscores > 3) | (rampart_zscores < -3)]
rom_outliers = rom_zscores[(rom_zscores > 3) | (rom_zscores < -3)]

# Drop columns with all NaN values
lead_outliers = lead_outliers.dropna(axis=1, how='all')
rampart_outliers = rampart_outliers.dropna(axis=1, how='all')
rom_outliers = rom_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
lead_outliers.to_csv('lead_outliers_mean_inside.csv')
rampart_outliers.to_csv('rampart_outliers_mean_inside.csv')
rom_outliers.to_csv('baseline_outliers_mean_inside.csv')

# Save the z-scores to a CSV file
lead_zscores.to_csv('lead_zscores_mean_inside.csv')
rampart_zscores.to_csv('rampart_zscores_mean_inside.csv')
rom_zscores.to_csv('baseline_zscores_mean_inside.csv')

# Save the lead, rampart, and ROM cases to a CSV file
lead_cases.to_csv('lead_cases_mean_inside.csv')
rampart_cases.to_csv('rampart_cases_mean_inside.csv')
rom_cases.to_csv('baseline_mean_inside.csv')

# %%
# Average out the rampart values
ram_avg = (ram_mean_inside_Case_3_001 + 
           ram_mean_inside_Case_6_001 + ram_mean_inside_Case_1_002 + ram_mean_inside_Case_4_002 + 
           ram_mean_inside_Case_3_004 + ram_mean_inside_Case_4_004 + ram_mean_inside_Case_1_005 + 
           ram_mean_inside_Case_4_005 + ram_mean_inside_Case_3_006 + ram_mean_inside_Case_4_006 + 
           ram_mean_inside_Case_3_007 + ram_mean_inside_Case_4_007 + ram_mean_inside_Case_1_008 + 
           ram_mean_inside_Case_4_008 + ram_mean_inside_Case_1_019 + ram_mean_inside_Case_4_019 + 
           ram_mean_inside_Case_2_022 + ram_mean_inside_Case_3_022 + ram_mean_inside_Case_4_023+ ram_mean_inside_Case_1_030 + 
           ram_mean_inside_Case_1_031) / 21

# Average out the lead values
lead_avg = (lead_mean_inside_Case_1_001 + lead_mean_inside_Case_2_001 + lead_mean_inside_Case_4_001 + 
            lead_mean_inside_Case_2_002 + lead_mean_inside_Case_3_002 + lead_mean_inside_Case_1_003 +
            + lead_mean_inside_Case_2_003 + lead_mean_inside_Case_4_003 + lead_mean_inside_Case_1_004 + 
            lead_mean_inside_Case_2_004 + lead_mean_inside_Case_3_005 + lead_mean_inside_Case_5_005 + 
            lead_mean_inside_Case_1_006 + lead_mean_inside_Case_2_006 + lead_mean_inside_Case_1_007 + 
            lead_mean_inside_Case_2_007 + lead_mean_inside_Case_2_008 + lead_mean_inside_Case_3_008 + 
            lead_mean_inside_Case_1_009 + lead_mean_inside_Case_2_009 + lead_mean_inside_Case_1_010 + 
            lead_mean_inside_Case_2_010 + lead_mean_inside_Case_3_010 + lead_mean_inside_Case_1_011 + 
            lead_mean_inside_Case_2_011 + lead_mean_inside_Case_1_013 + lead_mean_inside_Case_2_013 + 
            lead_mean_inside_Case_1_014 + lead_mean_inside_Case_2_014 + lead_mean_inside_Case_1_015 + 
            lead_mean_inside_Case_2_015 + lead_mean_inside_Case_1_017 + lead_mean_inside_Case_2_017 + 
            lead_mean_inside_Case_1_018 + lead_mean_inside_Case_2_018 + lead_mean_inside_Case_2_019 + 
            lead_mean_inside_Case_3_019 + lead_mean_inside_Case_1_020 + lead_mean_inside_Case_2_020 + 
            lead_mean_inside_Case_1_021 + lead_mean_inside_Case_2_021 + lead_mean_inside_Case_1_022 + 
            lead_mean_inside_Case_4_022 + lead_mean_inside_Case_1_023 + lead_mean_inside_Case_2_023 + 
            lead_mean_inside_Case_1_024 + lead_mean_inside_Case_2_024 + lead_mean_inside_Case_1_026 + 
            lead_mean_inside_Case_2_026 + lead_mean_inside_Case_1_027 + lead_mean_inside_Case_1_028 + 
            lead_mean_inside_Case_2_028 + lead_mean_inside_Case_1_029 + lead_mean_inside_Case_2_029 + 
            lead_mean_inside_Case_2_030 + lead_mean_inside_Case_3_030 + lead_mean_inside_Case_2_031) / 57

# Average out the ROM values
ROM_avg = (ROM_mean_inside_001 + ROM_mean_inside_002 + ROM_mean_inside_003+ ROM_mean_inside_004 + ROM_mean_inside_005 + 
           ROM_mean_inside_006 + ROM_mean_inside_007 + ROM_mean_inside_008 + ROM_mean_inside_009 + 
           ROM_mean_inside_010 + ROM_mean_inside_011 + ROM_mean_inside_013 + ROM_mean_inside_014 + 
           ROM_mean_inside_015 + ROM_mean_inside_017 + ROM_mean_inside_018 + ROM_mean_inside_019 + 
           ROM_mean_inside_020 + ROM_mean_inside_021 + ROM_mean_inside_022 + ROM_mean_inside_023 + 
           ROM_mean_inside_024 + ROM_mean_inside_026 + ROM_mean_inside_027 + ROM_mean_inside_028 + 
           ROM_mean_inside_029 + ROM_mean_inside_030 + ROM_mean_inside_031) / 28

# Create a dataframe for the averages
average_df = pd.DataFrame({
    'Rampart Average': ram_avg,
    'Lead Average': lead_avg,
    'ROM Baseline Average': ROM_avg
})

# Plot the comparison
average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Full Mean Inside Threshold Comparison (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the rampart and lead averages
average_df['Difference'] = average_df['Rampart Average'] - average_df['Lead Average']
# Plot the difference
average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Full Mean Inside (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Now begin to assess the mean degree above threshold.

# %%
# Extract the mean above for each case
lead_mean_above_Case_1_001 = Case_1_001.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_001 = Case_2_001.iloc[4, 1:].astype(float)
ram_mean_above_Case_3_001 = Case_3_001.iloc[4, 1:].astype(float)
lead_mean_above_Case_4_001 = Case_4_001.iloc[4, 1:].astype(float)
ram_mean_above_Case_6_001 = Case_6_001.iloc[4, 1:].astype(float)
ram_mean_above_Case_1_002 = Case_1_002.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_002 = Case_2_002.iloc[4, 1:].astype(float)
lead_mean_above_Case_3_002 = Case_3_002.iloc[4, 1:].astype(float)
ram_mean_above_Case_4_002 = Case_4_002.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_003 = Case_1_003.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_003 = Case_2_003.iloc[4, 1:].astype(float)
lead_mean_above_Case_4_003 = Case_4_003.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_004 = Case_1_004.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_004 = Case_2_004.iloc[4, 1:].astype(float)
ram_mean_above_Case_3_004 = Case_3_004.iloc[4, 1:].astype(float)
ram_mean_above_Case_4_004 = Case_4_004.iloc[4, 1:].astype(float)
ram_mean_above_Case_1_005 = Case_1_005.iloc[4, 1:].astype(float)
lead_mean_above_Case_3_005 = Case_3_005.iloc[4, 1:].astype(float)
ram_mean_above_Case_4_005 = Case_4_005.iloc[4, 1:].astype(float)
lead_mean_above_Case_5_005 = Case_5_005.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_006 = Case_1_006.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_006 = Case_2_006.iloc[4, 1:].astype(float)
ram_mean_above_Case_3_006 = Case_3_006.iloc[4, 1:].astype(float)
ram_mean_above_Case_4_006 = Case_4_006.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_007 = Case_1_007.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_007 = Case_2_007.iloc[4, 1:].astype(float)
ram_mean_above_Case_3_007 = Case_3_007.iloc[4, 1:].astype(float)
ram_mean_above_Case_4_007 = Case_4_007.iloc[4, 1:].astype(float)
ram_mean_above_Case_1_008 = Case_1_008.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_008 = Case_2_008.iloc[4, 1:].astype(float)
lead_mean_above_Case_3_008 = Case_3_008.iloc[4, 1:].astype(float)
ram_mean_above_Case_4_008 = Case_4_008.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_009 = Case_1_009.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_009 = Case_2_009.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_010 = Case_1_010.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_010 = Case_2_010.iloc[4, 1:].astype(float)
lead_mean_above_Case_3_010 = Case_3_010.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_011 = Case_1_011.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_011 = Case_2_011.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_013 = Case_1_013.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_013 = Case_2_013.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_014 = Case_1_014.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_014 = Case_2_014.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_015 = Case_1_015.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_015 = Case_2_015.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_017 = Case_1_017.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_017 = Case_2_017.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_018 = Case_1_018.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_018 = Case_2_018.iloc[4, 1:].astype(float)
ram_mean_above_Case_1_019 = Case_1_019.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_019 = Case_2_019.iloc[4, 1:].astype(float)
lead_mean_above_Case_3_019 = Case_3_019.iloc[4, 1:].astype(float)
ram_mean_above_Case_4_019 = Case_4_019.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_020 = Case_1_020.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_020 = Case_2_020.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_021 = Case_1_021.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_021 = Case_2_021.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_022 = Case_1_022.iloc[4, 1:].astype(float)
ram_mean_above_Case_2_022 = Case_2_022.iloc[4, 1:].astype(float)
ram_mean_above_Case_3_022 = Case_3_022.iloc[4, 1:].astype(float)
lead_mean_above_Case_4_022 = Case_4_022.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_023 = Case_1_023.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_023 = Case_2_023.iloc[4, 1:].astype(float)
ram_mean_above_Case_4_023 = Case_4_023.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_024 = Case_1_024.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_024 = Case_2_024.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_026 = Case_1_026.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_026 = Case_2_026.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_027 = Case_1_027.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_028 = Case_1_028.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_028 = Case_2_028.iloc[4, 1:].astype(float)
lead_mean_above_Case_1_029 = Case_1_029.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_029 = Case_2_029.iloc[4, 1:].astype(float)
ram_mean_above_Case_1_030 = Case_1_030.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_030 = Case_2_030.iloc[4, 1:].astype(float)
lead_mean_above_Case_3_030 = Case_3_030.iloc[4, 1:].astype(float)
ram_mean_above_Case_1_031 = Case_1_031.iloc[4, 1:].astype(float)
lead_mean_above_Case_2_031 = Case_2_031.iloc[4, 1:].astype(float)

# %%
# Extract the mean degree above threshold for each ROM Baseline
ROM_mean_above_001 = ROM_001.iloc[4, 1:].astype(float)
ROM_mean_above_002 = ROM_002.iloc[4, 1:].astype(float)
ROM_mean_above_003 = ROM_003.iloc[4, 1:].astype(float)
ROM_mean_above_004 = ROM_004.iloc[4, 1:].astype(float)
ROM_mean_above_005 = ROM_005.iloc[4, 1:].astype(float)
ROM_mean_above_006 = ROM_006.iloc[4, 1:].astype(float)
ROM_mean_above_007 = ROM_007.iloc[4, 1:].astype(float)
ROM_mean_above_008 = ROM_008.iloc[4, 1:].astype(float)
ROM_mean_above_009 = ROM_009.iloc[4, 1:].astype(float)
ROM_mean_above_010 = ROM_010.iloc[4, 1:].astype(float)
ROM_mean_above_011 = ROM_011.iloc[4, 1:].astype(float)
ROM_mean_above_013 = ROM_013.iloc[4, 1:].astype(float)
ROM_mean_above_014 = ROM_014.iloc[4, 1:].astype(float)
ROM_mean_above_015 = ROM_015.iloc[4, 1:].astype(float)
ROM_mean_above_017 = ROM_017.iloc[4, 1:].astype(float)
ROM_mean_above_018 = ROM_018.iloc[4, 1:].astype(float)
ROM_mean_above_019 = ROM_019.iloc[4, 1:].astype(float)
ROM_mean_above_020 = ROM_020.iloc[4, 1:].astype(float)
ROM_mean_above_021 = ROM_021.iloc[4, 1:].astype(float)
ROM_mean_above_022 = ROM_022.iloc[4, 1:].astype(float)
ROM_mean_above_023 = ROM_023.iloc[4, 1:].astype(float)
ROM_mean_above_024 = ROM_024.iloc[4, 1:].astype(float)
ROM_mean_above_026 = ROM_026.iloc[4, 1:].astype(float)
ROM_mean_above_027 = ROM_027.iloc[4, 1:].astype(float)
ROM_mean_above_028 = ROM_028.iloc[4, 1:].astype(float)
ROM_mean_above_029 = ROM_029.iloc[4, 1:].astype(float)
ROM_mean_above_030 = ROM_030.iloc[4, 1:].astype(float)
ROM_mean_above_031 = ROM_031.iloc[4, 1:].astype(float)

# %%
from scipy.stats import zscore

# Combine all lead, rampart, and ROM cases into separate dataframes
lead_cases = pd.DataFrame([
    lead_mean_above_Case_1_001, lead_mean_above_Case_2_001, lead_mean_above_Case_4_001, lead_mean_above_Case_2_002, lead_mean_above_Case_3_002,
    lead_mean_above_Case_1_003, lead_mean_above_Case_2_003, lead_mean_above_Case_4_003,
    lead_mean_above_Case_1_004, lead_mean_above_Case_2_004, lead_mean_above_Case_3_005, lead_mean_above_Case_5_005, lead_mean_above_Case_1_006,
    lead_mean_above_Case_2_006, lead_mean_above_Case_1_007, lead_mean_above_Case_2_007, lead_mean_above_Case_2_008, lead_mean_above_Case_3_008,
    lead_mean_above_Case_1_009, lead_mean_above_Case_2_009, lead_mean_above_Case_1_010, lead_mean_above_Case_2_010, lead_mean_above_Case_3_010,
    lead_mean_above_Case_1_011, lead_mean_above_Case_2_011, lead_mean_above_Case_1_013, lead_mean_above_Case_2_013, lead_mean_above_Case_1_014,
    lead_mean_above_Case_2_014, lead_mean_above_Case_1_015, lead_mean_above_Case_2_015, lead_mean_above_Case_1_017, lead_mean_above_Case_2_017,
    lead_mean_above_Case_1_018, lead_mean_above_Case_2_018, lead_mean_above_Case_2_019, lead_mean_above_Case_3_019, lead_mean_above_Case_1_020,
    lead_mean_above_Case_2_020, lead_mean_above_Case_1_021, lead_mean_above_Case_2_021, lead_mean_above_Case_1_022, lead_mean_above_Case_4_022,
    lead_mean_above_Case_1_023, lead_mean_above_Case_2_023, lead_mean_above_Case_1_024, lead_mean_above_Case_2_024, lead_mean_above_Case_1_026,
    lead_mean_above_Case_2_026, lead_mean_above_Case_1_027, lead_mean_above_Case_1_028, lead_mean_above_Case_2_028, lead_mean_above_Case_1_029,
    lead_mean_above_Case_2_029, lead_mean_above_Case_2_030, lead_mean_above_Case_3_030, lead_mean_above_Case_2_031
])

rampart_cases = pd.DataFrame([
    ram_mean_above_Case_3_001, ram_mean_above_Case_6_001, ram_mean_above_Case_1_002,
    ram_mean_above_Case_4_002, ram_mean_above_Case_3_004, ram_mean_above_Case_4_004, ram_mean_above_Case_1_005, ram_mean_above_Case_4_005,
    ram_mean_above_Case_3_006, ram_mean_above_Case_4_006, ram_mean_above_Case_3_007, ram_mean_above_Case_4_007, ram_mean_above_Case_1_008,
    ram_mean_above_Case_4_008, ram_mean_above_Case_1_019, ram_mean_above_Case_4_019, ram_mean_above_Case_2_022, ram_mean_above_Case_3_022, ram_mean_above_Case_4_023,
    ram_mean_above_Case_1_030, ram_mean_above_Case_1_031
])

rom_cases = pd.DataFrame([
    ROM_mean_above_001, ROM_mean_above_002, ROM_mean_above_003, ROM_mean_above_004, ROM_mean_above_005, ROM_mean_above_006, ROM_mean_above_007, ROM_mean_above_008,
    ROM_mean_above_009, ROM_mean_above_010, ROM_mean_above_011, ROM_mean_above_013, ROM_mean_above_014, ROM_mean_above_015, ROM_mean_above_017,
    ROM_mean_above_018, ROM_mean_above_019, ROM_mean_above_020, ROM_mean_above_021, ROM_mean_above_022, ROM_mean_above_023, ROM_mean_above_024,
    ROM_mean_above_026, ROM_mean_above_027, ROM_mean_above_028, ROM_mean_above_029, ROM_mean_above_030, ROM_mean_above_031
])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022','4_023',
    '1_030', '1_031'
]

rampart_cases.index = subject_ids_rampart

subject_ids_rom = [
    '001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011', '013', '014', '015', '017', '018', '019', '020', '021', '022', '023', '024', '026', '027', '028', '029', '030', '031'
]

rom_cases.index = subject_ids_rom

# Calculate z-scores for each joint in lead, rampart, and ROM cases
lead_zscores = lead_cases.apply(zscore)
rampart_zscores = rampart_cases.apply(zscore)
rom_zscores = rom_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_outliers = lead_zscores[(lead_zscores > 3) | (lead_zscores < -3)]
rampart_outliers = rampart_zscores[(rampart_zscores > 3) | (rampart_zscores < -3)]
rom_outliers = rom_zscores[(rom_zscores > 3) | (rom_zscores < -3)]

# Drop columns with all NaN values
lead_outliers = lead_outliers.dropna(axis=1, how='all')
rampart_outliers = rampart_outliers.dropna(axis=1, how='all')
rom_outliers = rom_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
lead_outliers.to_csv('lead_outliers_mean_above.csv')
rampart_outliers.to_csv('rampart_outliers_mean_above.csv')
rom_outliers.to_csv('baseline_outliers_mean_above.csv')

# Save the z-scores to a CSV file
lead_zscores.to_csv('lead_zscores_mean_above.csv')
rampart_zscores.to_csv('rampart_zscores_mean_above.csv')
rom_zscores.to_csv('baseline_zscores_mean_above.csv')

# Save the lead, rampart, and ROM cases to a CSV file
lead_cases.to_csv('lead_cases_mean_above.csv')
rampart_cases.to_csv('rampart_cases_mean_above.csv')
rom_cases.to_csv('baseline_mean_above.csv')

# %%
# Average out the rampart values
ram_avg = (ram_mean_above_Case_3_001 +
           ram_mean_above_Case_6_001 + ram_mean_above_Case_1_002 + ram_mean_above_Case_4_002 + 
           ram_mean_above_Case_3_004 + ram_mean_above_Case_4_004 + ram_mean_above_Case_1_005 + 
           ram_mean_above_Case_4_005 + ram_mean_above_Case_3_006 + ram_mean_above_Case_4_006 + 
           ram_mean_above_Case_3_007 + ram_mean_above_Case_4_007 + ram_mean_above_Case_1_008 + 
           ram_mean_above_Case_4_008 + ram_mean_above_Case_1_019 + ram_mean_above_Case_4_019 + 
           ram_mean_above_Case_2_022 + ram_mean_above_Case_3_022 + ram_mean_above_Case_4_023 + ram_mean_above_Case_1_030 + 
           ram_mean_above_Case_1_031) / 21

# Average out the lead values
lead_avg = (lead_mean_above_Case_1_001 + lead_mean_above_Case_2_001 + lead_mean_above_Case_4_001 + 
            lead_mean_above_Case_2_002 + lead_mean_above_Case_3_002 + lead_mean_above_Case_1_003
            + lead_mean_above_Case_2_003 + lead_mean_above_Case_4_003+ lead_mean_above_Case_1_004 + 
            lead_mean_above_Case_2_004 + lead_mean_above_Case_3_005 + lead_mean_above_Case_5_005 + 
            lead_mean_above_Case_1_006 + lead_mean_above_Case_2_006 + lead_mean_above_Case_1_007 + 
            lead_mean_above_Case_2_007 + lead_mean_above_Case_2_008 + lead_mean_above_Case_3_008 + 
            lead_mean_above_Case_1_009 + lead_mean_above_Case_2_009 + lead_mean_above_Case_1_010 + 
            lead_mean_above_Case_2_010 + lead_mean_above_Case_3_010 + lead_mean_above_Case_1_011 + 
            lead_mean_above_Case_2_011 + lead_mean_above_Case_1_013 + lead_mean_above_Case_2_013 + 
            lead_mean_above_Case_1_014 + lead_mean_above_Case_2_014 + lead_mean_above_Case_1_015 + 
            lead_mean_above_Case_2_015 + lead_mean_above_Case_1_017 + lead_mean_above_Case_2_017 + 
            lead_mean_above_Case_1_018 + lead_mean_above_Case_2_018 + lead_mean_above_Case_2_019 + 
            lead_mean_above_Case_3_019 + lead_mean_above_Case_1_020 + lead_mean_above_Case_2_020 + 
            lead_mean_above_Case_1_021 + lead_mean_above_Case_2_021 + lead_mean_above_Case_1_022 + 
            lead_mean_above_Case_4_022 + lead_mean_above_Case_1_023 + lead_mean_above_Case_2_023 + 
            lead_mean_above_Case_1_024 + lead_mean_above_Case_2_024 + lead_mean_above_Case_1_026 + 
            lead_mean_above_Case_2_026 + lead_mean_above_Case_1_027 + lead_mean_above_Case_1_028 + 
            lead_mean_above_Case_2_028 + lead_mean_above_Case_1_029 + lead_mean_above_Case_2_029 + 
            lead_mean_above_Case_2_030 + lead_mean_above_Case_3_030 + lead_mean_above_Case_2_031) / 57

# Average out the ROM values
ROM_avg = (ROM_mean_above_001 + ROM_mean_above_002 + ROM_mean_above_003+ ROM_mean_above_004 + ROM_mean_above_005 + 
           ROM_mean_above_006 + ROM_mean_above_007 + ROM_mean_above_008 + ROM_mean_above_009 + 
           ROM_mean_above_010 + ROM_mean_above_011 + ROM_mean_above_013 + ROM_mean_above_014 + 
           ROM_mean_above_015 + ROM_mean_above_017 + ROM_mean_above_018 + ROM_mean_above_019 + 
           ROM_mean_above_020 + ROM_mean_above_021 + ROM_mean_above_022 + ROM_mean_above_023 + 
           ROM_mean_above_024 + ROM_mean_above_026 + ROM_mean_above_027 + ROM_mean_above_028 + 
           ROM_mean_above_029 + ROM_mean_above_030 + ROM_mean_above_031) / 28

# Create a dataframe for the averages
average_df = pd.DataFrame({
    'Rampart Average': ram_avg,
    'Lead Average': lead_avg,
    'ROM Baseline Average': ROM_avg
})

# Plot the comparison
average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Full Mean Above Threshold Comparison (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the rampart and lead averages
average_df['Difference'] = average_df['Rampart Average'] - average_df['Lead Average']
# Plot the difference
average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Full Mean Above (All Subjects)')
plt.ylabel('Degrees')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Now we have looked at the mean degrees above, below, and inside the threshold amounts. Next, we will look at the sum of duration quantities and average out the percentages that each case was in these amounts.

# %%
# Extract the sum duration below for each case
lead_sum_duration_below_Case_1_001 = Case_1_001.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_001 = Case_2_001.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_3_001 = Case_3_001.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_4_001 = Case_4_001.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_6_001 = Case_6_001.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_1_002 = Case_1_002.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_002 = Case_2_002.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_3_002 = Case_3_002.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_4_002 = Case_4_002.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_003 = Case_1_003.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_003 = Case_2_003.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_4_003 = Case_4_003.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_004 = Case_1_004.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_004 = Case_2_004.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_3_004 = Case_3_004.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_4_004 = Case_4_004.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_1_005 = Case_1_005.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_3_005 = Case_3_005.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_4_005 = Case_4_005.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_5_005 = Case_5_005.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_006 = Case_1_006.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_006 = Case_2_006.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_3_006 = Case_3_006.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_4_006 = Case_4_006.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_007 = Case_1_007.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_007 = Case_2_007.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_3_007 = Case_3_007.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_4_007 = Case_4_007.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_1_008 = Case_1_008.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_008 = Case_2_008.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_3_008 = Case_3_008.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_4_008 = Case_4_008.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_009 = Case_1_009.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_009 = Case_2_009.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_010 = Case_1_010.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_010 = Case_2_010.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_3_010 = Case_3_010.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_011 = Case_1_011.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_011 = Case_2_011.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_013 = Case_1_013.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_013 = Case_2_013.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_014 = Case_1_014.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_014 = Case_2_014.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_015 = Case_1_015.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_015 = Case_2_015.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_017 = Case_1_017.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_017 = Case_2_017.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_018 = Case_1_018.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_018 = Case_2_018.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_1_019 = Case_1_019.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_019 = Case_2_019.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_3_019 = Case_3_019.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_4_019 = Case_4_019.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_020 = Case_1_020.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_020 = Case_2_020.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_021 = Case_1_021.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_021 = Case_2_021.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_022 = Case_1_022.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_2_022 = Case_2_022.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_3_022 = Case_3_022.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_4_022 = Case_4_022.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_023 = Case_1_023.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_023 = Case_2_023.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_4_023 = Case_4_023.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_024 = Case_1_024.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_024 = Case_2_024.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_026 = Case_1_026.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_026 = Case_2_026.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_027 = Case_1_027.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_028 = Case_1_028.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_028 = Case_2_028.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_1_029 = Case_1_029.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_029 = Case_2_029.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_1_030 = Case_1_030.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_030 = Case_2_030.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_3_030 = Case_3_030.iloc[6, 1:].astype(float)
ram_sum_duration_below_Case_1_031 = Case_1_031.iloc[6, 1:].astype(float)
lead_sum_duration_below_Case_2_031 = Case_2_031.iloc[6, 1:].astype(float)

# %%
# Extract the sum duration below for each ROM Baseline
ROM_sum_duration_below_001 = ROM_001.iloc[6, 1:].astype(float)
ROM_sum_duration_below_002 = ROM_002.iloc[6, 1:].astype(float)
ROM_sum_duration_below_003 = ROM_003.iloc[6, 1:].astype(float)
ROM_sum_duration_below_004 = ROM_004.iloc[6, 1:].astype(float)
ROM_sum_duration_below_005 = ROM_005.iloc[6, 1:].astype(float)
ROM_sum_duration_below_006 = ROM_006.iloc[6, 1:].astype(float)
ROM_sum_duration_below_007 = ROM_007.iloc[6, 1:].astype(float)
ROM_sum_duration_below_008 = ROM_008.iloc[6, 1:].astype(float)
ROM_sum_duration_below_009 = ROM_009.iloc[6, 1:].astype(float)
ROM_sum_duration_below_010 = ROM_010.iloc[6, 1:].astype(float)
ROM_sum_duration_below_011 = ROM_011.iloc[6, 1:].astype(float)
ROM_sum_duration_below_013 = ROM_013.iloc[6, 1:].astype(float)
ROM_sum_duration_below_014 = ROM_014.iloc[6, 1:].astype(float)
ROM_sum_duration_below_015 = ROM_015.iloc[6, 1:].astype(float)
ROM_sum_duration_below_017 = ROM_017.iloc[6, 1:].astype(float)
ROM_sum_duration_below_018 = ROM_018.iloc[6, 1:].astype(float)
ROM_sum_duration_below_019 = ROM_019.iloc[6, 1:].astype(float)
ROM_sum_duration_below_020 = ROM_020.iloc[6, 1:].astype(float)
ROM_sum_duration_below_021 = ROM_021.iloc[6, 1:].astype(float)
ROM_sum_duration_below_022 = ROM_022.iloc[6, 1:].astype(float)
ROM_sum_duration_below_023 = ROM_023.iloc[6, 1:].astype(float)
ROM_sum_duration_below_024 = ROM_024.iloc[6, 1:].astype(float)
ROM_sum_duration_below_026 = ROM_026.iloc[6, 1:].astype(float)
ROM_sum_duration_below_027 = ROM_027.iloc[6, 1:].astype(float)
ROM_sum_duration_below_028 = ROM_028.iloc[6, 1:].astype(float)
ROM_sum_duration_below_029 = ROM_029.iloc[6, 1:].astype(float)
ROM_sum_duration_below_030 = ROM_030.iloc[6, 1:].astype(float)
ROM_sum_duration_below_031 = ROM_031.iloc[6, 1:].astype(float)

# %%
from scipy.stats import zscore

# Combine all lead, rampart, and ROM cases into separate dataframes
lead_cases = pd.DataFrame([
    lead_sum_duration_below_Case_1_001, lead_sum_duration_below_Case_2_001, lead_sum_duration_below_Case_4_001, lead_sum_duration_below_Case_2_002, lead_sum_duration_below_Case_3_002,
    lead_sum_duration_below_Case_1_003, lead_sum_duration_below_Case_2_003, lead_sum_duration_below_Case_4_003,
    lead_sum_duration_below_Case_1_004, lead_sum_duration_below_Case_2_004, lead_sum_duration_below_Case_3_005, lead_sum_duration_below_Case_5_005, lead_sum_duration_below_Case_1_006,
    lead_sum_duration_below_Case_2_006, lead_sum_duration_below_Case_1_007, lead_sum_duration_below_Case_2_007, lead_sum_duration_below_Case_2_008, lead_sum_duration_below_Case_3_008,
    lead_sum_duration_below_Case_1_009, lead_sum_duration_below_Case_2_009, lead_sum_duration_below_Case_1_010, lead_sum_duration_below_Case_2_010, lead_sum_duration_below_Case_3_010,
    lead_sum_duration_below_Case_1_011, lead_sum_duration_below_Case_2_011, lead_sum_duration_below_Case_1_013, lead_sum_duration_below_Case_2_013, lead_sum_duration_below_Case_1_014,
    lead_sum_duration_below_Case_2_014, lead_sum_duration_below_Case_1_015, lead_sum_duration_below_Case_2_015, lead_sum_duration_below_Case_1_017, lead_sum_duration_below_Case_2_017,
    lead_sum_duration_below_Case_1_018, lead_sum_duration_below_Case_2_018, lead_sum_duration_below_Case_2_019, lead_sum_duration_below_Case_3_019, lead_sum_duration_below_Case_1_020,
    lead_sum_duration_below_Case_2_020, lead_sum_duration_below_Case_1_021, lead_sum_duration_below_Case_2_021, lead_sum_duration_below_Case_1_022, lead_sum_duration_below_Case_4_022,
    lead_sum_duration_below_Case_1_023, lead_sum_duration_below_Case_2_023, lead_sum_duration_below_Case_1_024, lead_sum_duration_below_Case_2_024, lead_sum_duration_below_Case_1_026,
    lead_sum_duration_below_Case_2_026, lead_sum_duration_below_Case_1_027, lead_sum_duration_below_Case_1_028, lead_sum_duration_below_Case_2_028, lead_sum_duration_below_Case_1_029,
    lead_sum_duration_below_Case_2_029, lead_sum_duration_below_Case_2_030, lead_sum_duration_below_Case_3_030, lead_sum_duration_below_Case_2_031
])

rampart_cases = pd.DataFrame([
    ram_sum_duration_below_Case_3_001, ram_sum_duration_below_Case_6_001, ram_sum_duration_below_Case_1_002,
    ram_sum_duration_below_Case_4_002, ram_sum_duration_below_Case_3_004, ram_sum_duration_below_Case_4_004, ram_sum_duration_below_Case_1_005, ram_sum_duration_below_Case_4_005,
    ram_sum_duration_below_Case_3_006, ram_sum_duration_below_Case_4_006, ram_sum_duration_below_Case_3_007, ram_sum_duration_below_Case_4_007, ram_sum_duration_below_Case_1_008,
    ram_sum_duration_below_Case_4_008, ram_sum_duration_below_Case_1_019, ram_sum_duration_below_Case_4_019, ram_sum_duration_below_Case_2_022, ram_sum_duration_below_Case_3_022, ram_sum_duration_below_Case_4_023,
    ram_sum_duration_below_Case_1_030, ram_sum_duration_below_Case_1_031
])

rom_cases = pd.DataFrame([
    ROM_sum_duration_below_001, ROM_sum_duration_below_002, ROM_sum_duration_below_003, ROM_sum_duration_below_004, ROM_sum_duration_below_005, ROM_sum_duration_below_006,
    ROM_sum_duration_below_007, ROM_sum_duration_below_008, ROM_sum_duration_below_009, ROM_sum_duration_below_010, ROM_sum_duration_below_011,
    ROM_sum_duration_below_013, ROM_sum_duration_below_014, ROM_sum_duration_below_015, ROM_sum_duration_below_017, ROM_sum_duration_below_018,
    ROM_sum_duration_below_019, ROM_sum_duration_below_020, ROM_sum_duration_below_021, ROM_sum_duration_below_022, ROM_sum_duration_below_023,
    ROM_sum_duration_below_024, ROM_sum_duration_below_026, ROM_sum_duration_below_027, ROM_sum_duration_below_028, ROM_sum_duration_below_029,
    ROM_sum_duration_below_030, ROM_sum_duration_below_031
])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001','6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022','4_023',
    '1_030', '1_031'
]

rampart_cases.index = subject_ids_rampart

subject_ids_rom = [
    '001', '002', '003', '004', '005', '006', '007', '008', '009', '010', '011',
    '013', '014', '015', '017', '018', '019', '020', '021', '022', '023',
    '024', '026', '027', '028', '029', '030', '031'
]

rom_cases.index = subject_ids_rom

# Calculate z-scores for each joint in lead, rampart, and ROM cases
lead_zscores = lead_cases.apply(zscore)
rampart_zscores = rampart_cases.apply(zscore)
rom_zscores = rom_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_outliers = lead_zscores[(lead_zscores > 3) | (lead_zscores < -3)]
rampart_outliers = rampart_zscores[(rampart_zscores > 3) | (rampart_zscores < -3)]
rom_outliers = rom_zscores[(rom_zscores > 3) | (rom_zscores < -3)]

# Drop columns with all NaN values
lead_outliers = lead_outliers.dropna(axis=1, how='all')
rampart_outliers = rampart_outliers.dropna(axis=1, how='all')
rom_outliers = rom_outliers.dropna(axis=1, how='all')

# Save the outliers to CSV files
lead_outliers.to_csv('lead_outliers_sum_duration_below.csv')
rampart_outliers.to_csv('rampart_outliers_sum_duration_below.csv')
rom_outliers.to_csv('baseline_outliers_sum_duration_below.csv')

# Save the z-scores to CSV files
lead_zscores.to_csv('lead_zscores_sum_duration_below.csv')
rampart_zscores.to_csv('rampart_zscores_sum_duration_below.csv')
rom_zscores.to_csv('baseline_zscores_sum_duration_below.csv')

# Save the lead, rampart, and ROM cases to CSV files
lead_cases.to_csv('lead_cases_sum_duration_below.csv')
rampart_cases.to_csv('rampart_cases_sum_duration_below.csv')
rom_cases.to_csv('baseline_sum_duration_below.csv')

# %%
# Average out the rampart values
ram_avg = (ram_sum_duration_below_Case_3_001 + 
           ram_sum_duration_below_Case_6_001 + ram_sum_duration_below_Case_1_002 + ram_sum_duration_below_Case_4_002 + 
           ram_sum_duration_below_Case_3_004 + ram_sum_duration_below_Case_4_004 + ram_sum_duration_below_Case_1_005 + 
           ram_sum_duration_below_Case_4_005 + ram_sum_duration_below_Case_3_006 + ram_sum_duration_below_Case_4_006 + 
           ram_sum_duration_below_Case_3_007 + ram_sum_duration_below_Case_4_007 + ram_sum_duration_below_Case_1_008 + 
           ram_sum_duration_below_Case_4_008 + ram_sum_duration_below_Case_1_019 + ram_sum_duration_below_Case_4_019 + 
           ram_sum_duration_below_Case_2_022 + ram_sum_duration_below_Case_3_022 + ram_sum_duration_below_Case_4_023 + ram_sum_duration_below_Case_1_030 + 
           ram_sum_duration_below_Case_1_031) / 21

# Average out the lead values
lead_avg = (lead_sum_duration_below_Case_1_001 + lead_sum_duration_below_Case_2_001 + lead_sum_duration_below_Case_4_001 + 
            lead_sum_duration_below_Case_2_002 + lead_sum_duration_below_Case_3_002 + lead_sum_duration_below_Case_1_003
            + lead_sum_duration_below_Case_2_003 + lead_sum_duration_below_Case_4_003 + lead_sum_duration_below_Case_1_004 + 
            lead_sum_duration_below_Case_2_004 + lead_sum_duration_below_Case_3_005 + lead_sum_duration_below_Case_5_005 + 
            lead_sum_duration_below_Case_1_006 + lead_sum_duration_below_Case_2_006 + lead_sum_duration_below_Case_1_007 + 
            lead_sum_duration_below_Case_2_007 + lead_sum_duration_below_Case_2_008 + lead_sum_duration_below_Case_3_008 + 
            lead_sum_duration_below_Case_1_009 + lead_sum_duration_below_Case_2_009 + lead_sum_duration_below_Case_1_010 + 
            lead_sum_duration_below_Case_2_010 + lead_sum_duration_below_Case_3_010 + lead_sum_duration_below_Case_1_011 + 
            lead_sum_duration_below_Case_2_011 + lead_sum_duration_below_Case_1_013 + lead_sum_duration_below_Case_2_013 + 
            lead_sum_duration_below_Case_1_014 + lead_sum_duration_below_Case_2_014 + lead_sum_duration_below_Case_1_015 + 
            lead_sum_duration_below_Case_2_015 + lead_sum_duration_below_Case_1_017 + lead_sum_duration_below_Case_2_017 + 
            lead_sum_duration_below_Case_1_018 + lead_sum_duration_below_Case_2_018 + lead_sum_duration_below_Case_2_019 + 
            lead_sum_duration_below_Case_3_019 + lead_sum_duration_below_Case_1_020 + lead_sum_duration_below_Case_2_020 + 
            lead_sum_duration_below_Case_1_021 + lead_sum_duration_below_Case_2_021 + lead_sum_duration_below_Case_1_022 + 
            lead_sum_duration_below_Case_4_022 + lead_sum_duration_below_Case_1_023 + lead_sum_duration_below_Case_2_023 + 
            lead_sum_duration_below_Case_1_024 + lead_sum_duration_below_Case_2_024 + lead_sum_duration_below_Case_1_026 + 
            lead_sum_duration_below_Case_2_026 + lead_sum_duration_below_Case_1_027 + lead_sum_duration_below_Case_1_028 + 
            lead_sum_duration_below_Case_2_028 + lead_sum_duration_below_Case_1_029 + lead_sum_duration_below_Case_2_029 + 
            lead_sum_duration_below_Case_2_030 + lead_sum_duration_below_Case_3_030 + lead_sum_duration_below_Case_2_031) / 57

# Average out the ROM values
ROM_avg = (ROM_sum_duration_below_001 + ROM_sum_duration_below_002 + ROM_sum_duration_below_003 + ROM_sum_duration_below_004 + ROM_sum_duration_below_005 + 
           ROM_sum_duration_below_006 + ROM_sum_duration_below_007 + ROM_sum_duration_below_008 + ROM_sum_duration_below_009 + 
           ROM_sum_duration_below_010 + ROM_sum_duration_below_011 + ROM_sum_duration_below_013 + ROM_sum_duration_below_014 + 
           ROM_sum_duration_below_015 + ROM_sum_duration_below_017 + ROM_sum_duration_below_018 + ROM_sum_duration_below_019 + 
           ROM_sum_duration_below_020 + ROM_sum_duration_below_021 + ROM_sum_duration_below_022 + ROM_sum_duration_below_023 + 
           ROM_sum_duration_below_024 + ROM_sum_duration_below_026 + ROM_sum_duration_below_027 + ROM_sum_duration_below_028 + 
           ROM_sum_duration_below_029 + ROM_sum_duration_below_030 + ROM_sum_duration_below_031) / 28

# Create a dataframe for the averages
average_df = pd.DataFrame({
    'Rampart Average': ram_avg,
    'Lead Average': lead_avg,
    'ROM Baseline Average': ROM_avg
})

# Plot the comparison
average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Full Sum Duration Below Threshold Comparison (All Subjects)')
plt.ylabel('Percentage')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the rampart and lead averages
average_df['Difference'] = average_df['Rampart Average'] - average_df['Lead Average']
# Plot the difference
average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Full Sum Duration Below (All Subjects)')
plt.ylabel('Percentage')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Now look at sum of duration inside.

# %%
# Extract the sum duration inside for each case
lead_sum_duration_inside_Case_1_001 = Case_1_001.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_001 = Case_2_001.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_3_001 = Case_3_001.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_4_001 = Case_4_001.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_6_001 = Case_6_001.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_1_002 = Case_1_002.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_002 = Case_2_002.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_3_002 = Case_3_002.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_4_002 = Case_4_002.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_003 = Case_1_003.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_003 = Case_2_003.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_4_003 = Case_4_003.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_004 = Case_1_004.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_004 = Case_2_004.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_3_004 = Case_3_004.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_4_004 = Case_4_004.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_1_005 = Case_1_005.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_3_005 = Case_3_005.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_4_005 = Case_4_005.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_5_005 = Case_5_005.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_006 = Case_1_006.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_006 = Case_2_006.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_3_006 = Case_3_006.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_4_006 = Case_4_006.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_007 = Case_1_007.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_007 = Case_2_007.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_3_007 = Case_3_007.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_4_007 = Case_4_007.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_1_008 = Case_1_008.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_008 = Case_2_008.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_3_008 = Case_3_008.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_4_008 = Case_4_008.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_009 = Case_1_009.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_009 = Case_2_009.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_010 = Case_1_010.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_010 = Case_2_010.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_3_010 = Case_3_010.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_011 = Case_1_011.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_011 = Case_2_011.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_013 = Case_1_013.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_013 = Case_2_013.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_014 = Case_1_014.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_014 = Case_2_014.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_015 = Case_1_015.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_015 = Case_2_015.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_017 = Case_1_017.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_017 = Case_2_017.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_018 = Case_1_018.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_018 = Case_2_018.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_1_019 = Case_1_019.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_019 = Case_2_019.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_3_019 = Case_3_019.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_4_019 = Case_4_019.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_020 = Case_1_020.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_020 = Case_2_020.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_021 = Case_1_021.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_021 = Case_2_021.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_022 = Case_1_022.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_2_022 = Case_2_022.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_3_022 = Case_3_022.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_4_022 = Case_4_022.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_023 = Case_1_023.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_023 = Case_2_023.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_4_023 = Case_4_023.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_024 = Case_1_024.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_024 = Case_2_024.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_026 = Case_1_026.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_026 = Case_2_026.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_027 = Case_1_027.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_028 = Case_1_028.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_028 = Case_2_028.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_1_029 = Case_1_029.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_029 = Case_2_029.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_1_030 = Case_1_030.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_030 = Case_2_030.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_3_030 = Case_3_030.iloc[8, 1:].astype(float)
ram_sum_duration_inside_Case_1_031 = Case_1_031.iloc[8, 1:].astype(float)
lead_sum_duration_inside_Case_2_031 = Case_2_031.iloc[8, 1:].astype(float)

# %%
# Extract the sum duration inside for each ROM Baseline
ROM_sum_duration_inside_001 = ROM_001.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_002 = ROM_002.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_003 = ROM_003.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_004 = ROM_004.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_005 = ROM_005.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_006 = ROM_006.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_007 = ROM_007.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_008 = ROM_008.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_009 = ROM_009.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_010 = ROM_010.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_011 = ROM_011.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_013 = ROM_013.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_014 = ROM_014.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_015 = ROM_015.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_017 = ROM_017.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_018 = ROM_018.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_019 = ROM_019.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_020 = ROM_020.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_021 = ROM_021.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_022 = ROM_022.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_023 = ROM_023.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_024 = ROM_024.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_026 = ROM_026.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_027 = ROM_027.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_028 = ROM_028.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_029 = ROM_029.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_030 = ROM_030.iloc[8, 1:].astype(float)
ROM_sum_duration_inside_031 = ROM_031.iloc[8, 1:].astype(float)

# %%
from scipy.stats import zscore

# Combine all lead, rampart, and ROM cases into separate dataframes
lead_cases = pd.DataFrame([
    lead_sum_duration_inside_Case_1_001, lead_sum_duration_inside_Case_2_001, lead_sum_duration_inside_Case_4_001, lead_sum_duration_inside_Case_2_002, lead_sum_duration_inside_Case_3_002,
    lead_sum_duration_inside_Case_1_003, lead_sum_duration_inside_Case_2_003, lead_sum_duration_inside_Case_4_003,
    lead_sum_duration_inside_Case_1_004, lead_sum_duration_inside_Case_2_004, lead_sum_duration_inside_Case_3_005, lead_sum_duration_inside_Case_5_005, lead_sum_duration_inside_Case_1_006,
    lead_sum_duration_inside_Case_2_006, lead_sum_duration_inside_Case_1_007, lead_sum_duration_inside_Case_2_007, lead_sum_duration_inside_Case_2_008, lead_sum_duration_inside_Case_3_008,
    lead_sum_duration_inside_Case_1_009, lead_sum_duration_inside_Case_2_009, lead_sum_duration_inside_Case_1_010, lead_sum_duration_inside_Case_2_010, lead_sum_duration_inside_Case_3_010,
    lead_sum_duration_inside_Case_1_011, lead_sum_duration_inside_Case_2_011, lead_sum_duration_inside_Case_1_013, lead_sum_duration_inside_Case_2_013, lead_sum_duration_inside_Case_1_014,
    lead_sum_duration_inside_Case_2_014, lead_sum_duration_inside_Case_1_015, lead_sum_duration_inside_Case_2_015, lead_sum_duration_inside_Case_1_017, lead_sum_duration_inside_Case_2_017,
    lead_sum_duration_inside_Case_1_018, lead_sum_duration_inside_Case_2_018, lead_sum_duration_inside_Case_2_019, lead_sum_duration_inside_Case_3_019, lead_sum_duration_inside_Case_1_020,
    lead_sum_duration_inside_Case_2_020, lead_sum_duration_inside_Case_1_021, lead_sum_duration_inside_Case_2_021, lead_sum_duration_inside_Case_1_022, lead_sum_duration_inside_Case_4_022,
    lead_sum_duration_inside_Case_1_023, lead_sum_duration_inside_Case_2_023, lead_sum_duration_inside_Case_1_024, lead_sum_duration_inside_Case_2_024, lead_sum_duration_inside_Case_1_026,
    lead_sum_duration_inside_Case_2_026, lead_sum_duration_inside_Case_1_027, lead_sum_duration_inside_Case_1_028, lead_sum_duration_inside_Case_2_028, lead_sum_duration_inside_Case_1_029,
    lead_sum_duration_inside_Case_2_029, lead_sum_duration_inside_Case_2_030, lead_sum_duration_inside_Case_3_030, lead_sum_duration_inside_Case_2_031
])

rampart_cases = pd.DataFrame([
    ram_sum_duration_inside_Case_3_001, ram_sum_duration_inside_Case_6_001, ram_sum_duration_inside_Case_1_002,
    ram_sum_duration_inside_Case_4_002, ram_sum_duration_inside_Case_3_004, ram_sum_duration_inside_Case_4_004, ram_sum_duration_inside_Case_1_005, ram_sum_duration_inside_Case_4_005,
    ram_sum_duration_inside_Case_3_006, ram_sum_duration_inside_Case_4_006, ram_sum_duration_inside_Case_3_007, ram_sum_duration_inside_Case_4_007, ram_sum_duration_inside_Case_1_008,
    ram_sum_duration_inside_Case_4_008, ram_sum_duration_inside_Case_1_019, ram_sum_duration_inside_Case_4_019, ram_sum_duration_inside_Case_2_022, ram_sum_duration_inside_Case_3_022, ram_sum_duration_inside_Case_4_023,
    ram_sum_duration_inside_Case_1_030, ram_sum_duration_inside_Case_1_031
])

rom_cases = pd.DataFrame([
    ROM_sum_duration_inside_001, ROM_sum_duration_inside_002, ROM_sum_duration_inside_003, ROM_sum_duration_inside_004, ROM_sum_duration_inside_005, ROM_sum_duration_inside_006,
    ROM_sum_duration_inside_007, ROM_sum_duration_inside_008, ROM_sum_duration_inside_009, ROM_sum_duration_inside_010, ROM_sum_duration_inside_011,
    ROM_sum_duration_inside_013, ROM_sum_duration_inside_014, ROM_sum_duration_inside_015, ROM_sum_duration_inside_017, ROM_sum_duration_inside_018,
    ROM_sum_duration_inside_019, ROM_sum_duration_inside_020, ROM_sum_duration_inside_021, ROM_sum_duration_inside_022, ROM_sum_duration_inside_023,
    ROM_sum_duration_inside_024, ROM_sum_duration_inside_026, ROM_sum_duration_inside_027, ROM_sum_duration_inside_028, ROM_sum_duration_inside_029,
    ROM_sum_duration_inside_030, ROM_sum_duration_inside_031
])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022','4_023',
    '1_030', '1_031'
]

rampart_cases.index = subject_ids_rampart

subject_ids_rom = [
    '001', '002', '003','004', '005', '006', '007', '008', '009', '010', '011',
    '013', '014', '015', '017', '018', '019', '020', '021', '022', '023',
    '024', '026', '027', '028', '029', '030', '031'
]

rom_cases.index = subject_ids_rom

# Calculate z-scores for each joint in lead, rampart, and ROM cases
lead_zscores = lead_cases.apply(zscore)
rampart_zscores = rampart_cases.apply(zscore)
rom_zscores = rom_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_outliers = lead_zscores[(lead_zscores > 3) | (lead_zscores < -3)]
rampart_outliers = rampart_zscores[(rampart_zscores > 3) | (rampart_zscores < -3)]
rom_outliers = rom_zscores[(rom_zscores > 3) | (rom_zscores < -3)]

# Print the outliers for each case, showcase those that are only outliers and what case they are in
lead_outliers = lead_outliers.dropna(axis=1, how='all')
rampart_outliers = rampart_outliers.dropna(axis=1, how='all')
rom_outliers = rom_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
lead_outliers.to_csv('lead_outliers_sum_duration_inside.csv')
rampart_outliers.to_csv('rampart_outliers_sum_duration_inside.csv')
rom_outliers.to_csv('baseline_outliers_sum_duration_inside.csv')

# Save the z-scores to a CSV file
lead_zscores.to_csv('lead_zscores_sum_duration_inside.csv')
rampart_zscores.to_csv('rampart_zscores_sum_duration_inside.csv')
rom_zscores.to_csv('baseline_zscores_sum_duration_inside.csv')

# Save the lead, rampart, and ROM cases to a CSV file
lead_cases.to_csv('lead_cases_sum_duration_inside.csv')
rampart_cases.to_csv('rampart_cases_sum_duration_inside.csv')
rom_cases.to_csv('baseline_sum_duration_inside.csv')

# %%
# Average out the rampart values
ram_avg = (ram_sum_duration_inside_Case_3_001 + 
           ram_sum_duration_inside_Case_6_001 + ram_sum_duration_inside_Case_1_002 + ram_sum_duration_inside_Case_4_002 + 
           ram_sum_duration_inside_Case_3_004 + ram_sum_duration_inside_Case_4_004 + ram_sum_duration_inside_Case_1_005 + 
           ram_sum_duration_inside_Case_4_005 + ram_sum_duration_inside_Case_3_006 + ram_sum_duration_inside_Case_4_006 + 
           ram_sum_duration_inside_Case_3_007 + ram_sum_duration_inside_Case_4_007 + ram_sum_duration_inside_Case_1_008 + 
           ram_sum_duration_inside_Case_4_008 + ram_sum_duration_inside_Case_1_019 + ram_sum_duration_inside_Case_4_019 + 
           ram_sum_duration_inside_Case_2_022 + ram_sum_duration_inside_Case_3_022 + ram_sum_duration_inside_Case_4_023 + ram_sum_duration_inside_Case_1_030 + 
           ram_sum_duration_inside_Case_1_031) / 21

# Average out the lead values
lead_avg = (lead_sum_duration_inside_Case_1_001 + lead_sum_duration_inside_Case_2_001 + lead_sum_duration_inside_Case_4_001 + 
            lead_sum_duration_inside_Case_2_002 + lead_sum_duration_inside_Case_3_002 + lead_sum_duration_inside_Case_1_003 +
            lead_sum_duration_inside_Case_2_003 + lead_sum_duration_inside_Case_4_003 + lead_sum_duration_inside_Case_1_004 + 
            lead_sum_duration_inside_Case_2_004 + lead_sum_duration_inside_Case_3_005 + lead_sum_duration_inside_Case_5_005 + 
            lead_sum_duration_inside_Case_1_006 + lead_sum_duration_inside_Case_2_006 + lead_sum_duration_inside_Case_1_007 + 
            lead_sum_duration_inside_Case_2_007 + lead_sum_duration_inside_Case_2_008 + lead_sum_duration_inside_Case_3_008 + 
            lead_sum_duration_inside_Case_1_009 + lead_sum_duration_inside_Case_2_009 + lead_sum_duration_inside_Case_1_010 + 
            lead_sum_duration_inside_Case_2_010 + lead_sum_duration_inside_Case_3_010 + lead_sum_duration_inside_Case_1_011 + 
            lead_sum_duration_inside_Case_2_011 + lead_sum_duration_inside_Case_1_013 + lead_sum_duration_inside_Case_2_013 + 
            lead_sum_duration_inside_Case_1_014 + lead_sum_duration_inside_Case_2_014 + lead_sum_duration_inside_Case_1_015 + 
            lead_sum_duration_inside_Case_2_015 + lead_sum_duration_inside_Case_1_017 + lead_sum_duration_inside_Case_2_017 + 
            lead_sum_duration_inside_Case_1_018 + lead_sum_duration_inside_Case_2_018 + lead_sum_duration_inside_Case_2_019 + 
            lead_sum_duration_inside_Case_3_019 + lead_sum_duration_inside_Case_1_020 + lead_sum_duration_inside_Case_2_020 + 
            lead_sum_duration_inside_Case_1_021 + lead_sum_duration_inside_Case_2_021 + lead_sum_duration_inside_Case_1_022 + 
            lead_sum_duration_inside_Case_4_022 + lead_sum_duration_inside_Case_1_023 + lead_sum_duration_inside_Case_2_023 + 
            lead_sum_duration_inside_Case_1_024 + lead_sum_duration_inside_Case_2_024 + lead_sum_duration_inside_Case_1_026 + 
            lead_sum_duration_inside_Case_2_026 + lead_sum_duration_inside_Case_1_027 + lead_sum_duration_inside_Case_1_028 + 
            lead_sum_duration_inside_Case_2_028 + lead_sum_duration_inside_Case_1_029 + lead_sum_duration_inside_Case_2_029 + 
            lead_sum_duration_inside_Case_2_030 + lead_sum_duration_inside_Case_3_030 + lead_sum_duration_inside_Case_2_031) / 57

# Average out the ROM values
ROM_avg = (ROM_sum_duration_inside_001 + ROM_sum_duration_inside_002 + ROM_sum_duration_inside_003 + ROM_sum_duration_inside_004 + ROM_sum_duration_inside_005 + 
           ROM_sum_duration_inside_006 + ROM_sum_duration_inside_007 + ROM_sum_duration_inside_008 + ROM_sum_duration_inside_009 + 
           ROM_sum_duration_inside_010 + ROM_sum_duration_inside_011 + ROM_sum_duration_inside_013 + ROM_sum_duration_inside_014 + 
           ROM_sum_duration_inside_015 + ROM_sum_duration_inside_017 + ROM_sum_duration_inside_018 + ROM_sum_duration_inside_019 + 
           ROM_sum_duration_inside_020 + ROM_sum_duration_inside_021 + ROM_sum_duration_inside_022 + ROM_sum_duration_inside_023 + 
           ROM_sum_duration_inside_024 + ROM_sum_duration_inside_026 + ROM_sum_duration_inside_027 + ROM_sum_duration_inside_028 + 
           ROM_sum_duration_inside_029 + ROM_sum_duration_inside_030 + ROM_sum_duration_inside_031) / 28

# Create a dataframe for the averages
average_df = pd.DataFrame({
    'Rampart Average': ram_avg,
    'Lead Average': lead_avg,
    'ROM Baseline Average': ROM_avg
})

# Plot the comparison
average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Full Sum Duration Inside Threshold Comparison (All Subjects)')
plt.ylabel('Percentage')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the rampart and lead averages
average_df['Difference'] = average_df['Rampart Average'] - average_df['Lead Average']
# Plot the difference
average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Full Sum Duration Inside (All Subjects)')
plt.ylabel('Percentage')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Extract the sum duration above for each case
lead_sum_duration_above_Case_1_001 = Case_1_001.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_001 = Case_2_001.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_3_001 = Case_3_001.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_4_001 = Case_4_001.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_6_001 = Case_6_001.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_1_002 = Case_1_002.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_002 = Case_2_002.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_3_002 = Case_3_002.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_4_002 = Case_4_002.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_003 = Case_1_003.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_003 = Case_2_003.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_4_003 = Case_4_003.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_004 = Case_1_004.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_004 = Case_2_004.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_3_004 = Case_3_004.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_4_004 = Case_4_004.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_1_005 = Case_1_005.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_3_005 = Case_3_005.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_4_005 = Case_4_005.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_5_005 = Case_5_005.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_006 = Case_1_006.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_006 = Case_2_006.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_3_006 = Case_3_006.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_4_006 = Case_4_006.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_007 = Case_1_007.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_007 = Case_2_007.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_3_007 = Case_3_007.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_4_007 = Case_4_007.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_1_008 = Case_1_008.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_008 = Case_2_008.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_3_008 = Case_3_008.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_4_008 = Case_4_008.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_009 = Case_1_009.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_009 = Case_2_009.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_010 = Case_1_010.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_010 = Case_2_010.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_3_010 = Case_3_010.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_011 = Case_1_011.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_011 = Case_2_011.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_013 = Case_1_013.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_013 = Case_2_013.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_014 = Case_1_014.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_014 = Case_2_014.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_015 = Case_1_015.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_015 = Case_2_015.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_017 = Case_1_017.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_017 = Case_2_017.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_018 = Case_1_018.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_018 = Case_2_018.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_1_019 = Case_1_019.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_019 = Case_2_019.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_3_019 = Case_3_019.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_4_019 = Case_4_019.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_020 = Case_1_020.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_020 = Case_2_020.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_021 = Case_1_021.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_021 = Case_2_021.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_022 = Case_1_022.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_2_022 = Case_2_022.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_3_022 = Case_3_022.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_4_022 = Case_4_022.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_023 = Case_1_023.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_023 = Case_2_023.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_4_023 = Case_4_023.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_024 = Case_1_024.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_024 = Case_2_024.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_026 = Case_1_026.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_026 = Case_2_026.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_027 = Case_1_027.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_028 = Case_1_028.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_028 = Case_2_028.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_1_029 = Case_1_029.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_029 = Case_2_029.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_1_030 = Case_1_030.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_030 = Case_2_030.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_3_030 = Case_3_030.iloc[10, 1:].astype(float)
ram_sum_duration_above_Case_1_031 = Case_1_031.iloc[10, 1:].astype(float)
lead_sum_duration_above_Case_2_031 = Case_2_031.iloc[10, 1:].astype(float)

# %%
# Extract the sum duration above for each ROM Baseline
ROM_sum_duration_above_001 = ROM_001.iloc[10, 1:].astype(float)
ROM_sum_duration_above_002 = ROM_002.iloc[10, 1:].astype(float)
ROM_sum_duration_above_003 = ROM_003.iloc[10, 1:].astype(float)
ROM_sum_duration_above_004 = ROM_004.iloc[10, 1:].astype(float)
ROM_sum_duration_above_005 = ROM_005.iloc[10, 1:].astype(float)
ROM_sum_duration_above_006 = ROM_006.iloc[10, 1:].astype(float)
ROM_sum_duration_above_007 = ROM_007.iloc[10, 1:].astype(float)
ROM_sum_duration_above_008 = ROM_008.iloc[10, 1:].astype(float)
ROM_sum_duration_above_009 = ROM_009.iloc[10, 1:].astype(float)
ROM_sum_duration_above_010 = ROM_010.iloc[10, 1:].astype(float)
ROM_sum_duration_above_011 = ROM_011.iloc[10, 1:].astype(float)
ROM_sum_duration_above_013 = ROM_013.iloc[10, 1:].astype(float)
ROM_sum_duration_above_014 = ROM_014.iloc[10, 1:].astype(float)
ROM_sum_duration_above_015 = ROM_015.iloc[10, 1:].astype(float)
ROM_sum_duration_above_017 = ROM_017.iloc[10, 1:].astype(float)
ROM_sum_duration_above_018 = ROM_018.iloc[10, 1:].astype(float)
ROM_sum_duration_above_019 = ROM_019.iloc[10, 1:].astype(float)
ROM_sum_duration_above_020 = ROM_020.iloc[10, 1:].astype(float)
ROM_sum_duration_above_021 = ROM_021.iloc[10, 1:].astype(float)
ROM_sum_duration_above_022 = ROM_022.iloc[10, 1:].astype(float)
ROM_sum_duration_above_023 = ROM_023.iloc[10, 1:].astype(float)
ROM_sum_duration_above_024 = ROM_024.iloc[10, 1:].astype(float)
ROM_sum_duration_above_026 = ROM_026.iloc[10, 1:].astype(float)
ROM_sum_duration_above_027 = ROM_027.iloc[10, 1:].astype(float)
ROM_sum_duration_above_028 = ROM_028.iloc[10, 1:].astype(float)
ROM_sum_duration_above_029 = ROM_029.iloc[10, 1:].astype(float)
ROM_sum_duration_above_030 = ROM_030.iloc[10, 1:].astype(float)
ROM_sum_duration_above_031 = ROM_031.iloc[10, 1:].astype(float)

# %%
from scipy.stats import zscore

# Combine all lead, rampart, and ROM cases into separate dataframes
lead_cases = pd.DataFrame([
    lead_sum_duration_above_Case_1_001, lead_sum_duration_above_Case_2_001, lead_sum_duration_above_Case_4_001, lead_sum_duration_above_Case_2_002, lead_sum_duration_above_Case_3_002,
    lead_sum_duration_above_Case_1_003, lead_sum_duration_above_Case_2_003, lead_sum_duration_above_Case_4_003,
    lead_sum_duration_above_Case_1_004, lead_sum_duration_above_Case_2_004, lead_sum_duration_above_Case_3_005, lead_sum_duration_above_Case_5_005, lead_sum_duration_above_Case_1_006,
    lead_sum_duration_above_Case_2_006, lead_sum_duration_above_Case_1_007, lead_sum_duration_above_Case_2_007, lead_sum_duration_above_Case_2_008, lead_sum_duration_above_Case_3_008,
    lead_sum_duration_above_Case_1_009, lead_sum_duration_above_Case_2_009, lead_sum_duration_above_Case_1_010, lead_sum_duration_above_Case_2_010, lead_sum_duration_above_Case_3_010,
    lead_sum_duration_above_Case_1_011, lead_sum_duration_above_Case_2_011, lead_sum_duration_above_Case_1_013, lead_sum_duration_above_Case_2_013, lead_sum_duration_above_Case_1_014,
    lead_sum_duration_above_Case_2_014, lead_sum_duration_above_Case_1_015, lead_sum_duration_above_Case_2_015, lead_sum_duration_above_Case_1_017, lead_sum_duration_above_Case_2_017,
    lead_sum_duration_above_Case_1_018, lead_sum_duration_above_Case_2_018, lead_sum_duration_above_Case_2_019, lead_sum_duration_above_Case_3_019, lead_sum_duration_above_Case_1_020,
    lead_sum_duration_above_Case_2_020, lead_sum_duration_above_Case_1_021, lead_sum_duration_above_Case_2_021, lead_sum_duration_above_Case_1_022, lead_sum_duration_above_Case_4_022,
    lead_sum_duration_above_Case_1_023, lead_sum_duration_above_Case_2_023, lead_sum_duration_above_Case_1_024, lead_sum_duration_above_Case_2_024, lead_sum_duration_above_Case_1_026,
    lead_sum_duration_above_Case_2_026, lead_sum_duration_above_Case_1_027, lead_sum_duration_above_Case_1_028, lead_sum_duration_above_Case_2_028, lead_sum_duration_above_Case_1_029,
    lead_sum_duration_above_Case_2_029, lead_sum_duration_above_Case_2_030, lead_sum_duration_above_Case_3_030, lead_sum_duration_above_Case_2_031
])

rampart_cases = pd.DataFrame([
    ram_sum_duration_above_Case_3_001, ram_sum_duration_above_Case_6_001, ram_sum_duration_above_Case_1_002,
    ram_sum_duration_above_Case_4_002, ram_sum_duration_above_Case_3_004, ram_sum_duration_above_Case_4_004, ram_sum_duration_above_Case_1_005, ram_sum_duration_above_Case_4_005,
    ram_sum_duration_above_Case_3_006, ram_sum_duration_above_Case_4_006, ram_sum_duration_above_Case_3_007, ram_sum_duration_above_Case_4_007, ram_sum_duration_above_Case_1_008,
    ram_sum_duration_above_Case_4_008, ram_sum_duration_above_Case_1_019, ram_sum_duration_above_Case_4_019, ram_sum_duration_above_Case_2_022, ram_sum_duration_above_Case_3_022, ram_sum_duration_above_Case_4_023,
    ram_sum_duration_above_Case_1_030, ram_sum_duration_above_Case_1_031
])

rom_cases = pd.DataFrame([
    ROM_sum_duration_above_001, ROM_sum_duration_above_002, ROM_sum_duration_above_003, ROM_sum_duration_above_004, ROM_sum_duration_above_005, ROM_sum_duration_above_006,
    ROM_sum_duration_above_007, ROM_sum_duration_above_008, ROM_sum_duration_above_009, ROM_sum_duration_above_010, ROM_sum_duration_above_011,
    ROM_sum_duration_above_013, ROM_sum_duration_above_014, ROM_sum_duration_above_015, ROM_sum_duration_above_017, ROM_sum_duration_above_018,
    ROM_sum_duration_above_019, ROM_sum_duration_above_020, ROM_sum_duration_above_021, ROM_sum_duration_above_022, ROM_sum_duration_above_023,
    ROM_sum_duration_above_024, ROM_sum_duration_above_026, ROM_sum_duration_above_027, ROM_sum_duration_above_028, ROM_sum_duration_above_029,
    ROM_sum_duration_above_030, ROM_sum_duration_above_031
])

# Set the index to reflect the original subjects
subject_ids_lead = [
    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '1_009', '2_009', '1_010', '2_010',
    '3_010', '1_011', '2_011', '1_013', '2_013',
    '1_014', '2_014', '1_015', '2_015', '1_017',
    '2_017', '1_018', '2_018',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031'
]

lead_cases.index = subject_ids_lead

subject_ids_rampart = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022','4_023',
    '1_030', '1_031'
]

rampart_cases.index = subject_ids_rampart

subject_ids_rom = [
    '001', '002','003', '004', '005', '006',
    '007', '008', '009', '010', '011',
    '013', '014', '015', '017', '018',
    '019', '020', '021', '022', '023',
    '024', '026', '027', '028', '029',
    '030', '031'
]

rom_cases.index = subject_ids_rom

# Calculate z-scores for each joint in lead, rampart, and ROM cases
lead_zscores = lead_cases.apply(zscore)
rampart_zscores = rampart_cases.apply(zscore)
rom_zscores = rom_cases.apply(zscore)

# Identify outliers (z-score > 3 or < -3)
lead_outliers = lead_zscores[(lead_zscores > 3) | (lead_zscores < -3)]
rampart_outliers = rampart_zscores[(rampart_zscores > 3) | (rampart_zscores < -3)]
rom_outliers = rom_zscores[(rom_zscores > 3) | (rom_zscores < -3)]

# Print the outliers for each case, showcase those that are only outliers and what case they are in
lead_outliers = lead_outliers.dropna(axis=1, how='all')
rampart_outliers = rampart_outliers.dropna(axis=1, how='all')
rom_outliers = rom_outliers.dropna(axis=1, how='all')

# Save the outliers to a CSV file
lead_outliers.to_csv('lead_outliers_sum_duration_above.csv')
rampart_outliers.to_csv('rampart_outliers_sum_duration_above.csv')
rom_outliers.to_csv('baseline_outliers_sum_duration_above.csv')

# Save the z-scores to a CSV file
lead_zscores.to_csv('lead_zscores_sum_duration_above.csv')
rampart_zscores.to_csv('rampart_zscores_sum_duration_above.csv')
rom_zscores.to_csv('baseline_zscores_sum_duration_above.csv')

# Save the lead, rampart, and ROM cases to a CSV file
lead_cases.to_csv('lead_cases_sum_duration_above.csv')
rampart_cases.to_csv('rampart_cases_sum_duration_above.csv')
rom_cases.to_csv('baseline_sum_duration_above.csv')

# %%
# Average out the rampart values
ram_avg = (ram_sum_duration_above_Case_3_001 +
           ram_sum_duration_above_Case_6_001 + ram_sum_duration_above_Case_1_002 + ram_sum_duration_above_Case_4_002 + 
           ram_sum_duration_above_Case_3_004 + ram_sum_duration_above_Case_4_004 + ram_sum_duration_above_Case_1_005 + 
           ram_sum_duration_above_Case_4_005 + ram_sum_duration_above_Case_3_006 + ram_sum_duration_above_Case_4_006 + 
           ram_sum_duration_above_Case_3_007 + ram_sum_duration_above_Case_4_007 + ram_sum_duration_above_Case_1_008 + 
           ram_sum_duration_above_Case_4_008 + ram_sum_duration_above_Case_1_019 + ram_sum_duration_above_Case_4_019 + 
           ram_sum_duration_above_Case_2_022 + ram_sum_duration_above_Case_3_022 + ram_sum_duration_above_Case_4_023 + ram_sum_duration_above_Case_1_030 + 
           ram_sum_duration_above_Case_1_031) / 21

# Average out the lead values
lead_avg = (lead_sum_duration_above_Case_1_001 + lead_sum_duration_above_Case_2_001 + lead_sum_duration_above_Case_4_001 + 
            lead_sum_duration_above_Case_2_002 + lead_sum_duration_above_Case_3_002 + lead_sum_duration_above_Case_1_003+ 
            lead_sum_duration_above_Case_2_003 + lead_sum_duration_above_Case_4_003 + lead_sum_duration_above_Case_1_004 + 
            lead_sum_duration_above_Case_2_004 + lead_sum_duration_above_Case_3_005 + lead_sum_duration_above_Case_5_005 + 
            lead_sum_duration_above_Case_1_006 + lead_sum_duration_above_Case_2_006 + lead_sum_duration_above_Case_1_007 + 
            lead_sum_duration_above_Case_2_007 + lead_sum_duration_above_Case_2_008 + lead_sum_duration_above_Case_3_008 + 
            lead_sum_duration_above_Case_1_009 + lead_sum_duration_above_Case_2_009 + lead_sum_duration_above_Case_1_010 + 
            lead_sum_duration_above_Case_2_010 + lead_sum_duration_above_Case_3_010 + lead_sum_duration_above_Case_1_011 + 
            lead_sum_duration_above_Case_2_011 + lead_sum_duration_above_Case_1_013 + lead_sum_duration_above_Case_2_013 + 
            lead_sum_duration_above_Case_1_014 + lead_sum_duration_above_Case_2_014 + lead_sum_duration_above_Case_1_015 + 
            lead_sum_duration_above_Case_2_015 + lead_sum_duration_above_Case_1_017 + lead_sum_duration_above_Case_2_017 + 
            lead_sum_duration_above_Case_1_018 + lead_sum_duration_above_Case_2_018 + lead_sum_duration_above_Case_2_019 + 
            lead_sum_duration_above_Case_3_019 + lead_sum_duration_above_Case_1_020 + lead_sum_duration_above_Case_2_020 + 
            lead_sum_duration_above_Case_1_021 + lead_sum_duration_above_Case_2_021 + lead_sum_duration_above_Case_1_022 + 
            lead_sum_duration_above_Case_4_022 + lead_sum_duration_above_Case_1_023 + lead_sum_duration_above_Case_2_023 + 
            lead_sum_duration_above_Case_1_024 + lead_sum_duration_above_Case_2_024 + lead_sum_duration_above_Case_1_026 + 
            lead_sum_duration_above_Case_2_026 + lead_sum_duration_above_Case_1_027 + lead_sum_duration_above_Case_1_028 + 
            lead_sum_duration_above_Case_2_028 + lead_sum_duration_above_Case_1_029 + lead_sum_duration_above_Case_2_029 + 
            lead_sum_duration_above_Case_2_030 + lead_sum_duration_above_Case_3_030 + lead_sum_duration_above_Case_2_031) / 57

# Average out the ROM values
ROM_avg = (ROM_sum_duration_above_001 + ROM_sum_duration_above_002 + ROM_sum_duration_above_003+  ROM_sum_duration_above_004 + ROM_sum_duration_above_005 + 
           ROM_sum_duration_above_006 + ROM_sum_duration_above_007 + ROM_sum_duration_above_008 + ROM_sum_duration_above_009 + 
           ROM_sum_duration_above_010 + ROM_sum_duration_above_011 + ROM_sum_duration_above_013 + ROM_sum_duration_above_014 + 
           ROM_sum_duration_above_015 + ROM_sum_duration_above_017 + ROM_sum_duration_above_018 + ROM_sum_duration_above_019 + 
           ROM_sum_duration_above_020 + ROM_sum_duration_above_021 + ROM_sum_duration_above_022 + ROM_sum_duration_above_023 + 
           ROM_sum_duration_above_024 + ROM_sum_duration_above_026 + ROM_sum_duration_above_027 + ROM_sum_duration_above_028 + 
           ROM_sum_duration_above_029 + ROM_sum_duration_above_030 + ROM_sum_duration_above_031) / 28

# Create a dataframe for the averages
average_df = pd.DataFrame({
    'Rampart Average': ram_avg,
    'Lead Average': lead_avg,
    'ROM Baseline Average': ROM_avg
})

# Plot the comparison
average_df.plot(kind='bar', figsize=(14, 8))
plt.title('Full Sum Duration Above Threshold Comparison (All Subjects)')
plt.ylabel('Percentage')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
# Calculate the difference of the rampart and lead averages
average_df['Difference'] = average_df['Rampart Average'] - average_df['Lead Average']
# Plot the difference
average_df['Difference'].plot(kind='bar', figsize=(14, 8))
plt.title('Difference in Full Sum Duration Above (All Subjects)')
plt.ylabel('Percentage')
plt.xlabel('Joint')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# I looked at the joint angles for all subjects averaged out.

# %% [markdown]
# Plot the standard deviations of some of the values maybe. I could see what the curve looks like and if the data is normal or not.

# %% [markdown]
# # Subset Data to Operators
#
# - Separate the graphs to be just cervical/thoracic and torso-pelvic/Lumbar
# - Stratify percentage of time wtihin the high risk positions.
#     - Look at Sex
#     - Look at profession (Attending, IC fellow, General Fellow, PA)
#     - Look at type of case (PCI vs diagnostic vs structural)

# %%
# Note the cases with the operators are with this format: CaseNumber_OperatorNumber
Lead_Operators = [    '1_001', '2_001', '4_001', '2_002', '3_002',
    '1_003', '2_003', '4_003',
    '1_004', '2_004', '3_005', '5_005', '1_006',
    '2_006', '1_007', '2_007', '2_008', '3_008',
    '2_019', '3_019', '1_020', '2_020',
    '1_021', '2_021', '1_022', '4_022', '1_023',
    '2_023', '1_024', '2_024', '1_026', '2_026',
    '1_027', '1_028', '2_028', '1_029', '2_029',
    '2_030', '3_030', '2_031']
# Note the cases with the operators are with this format: CaseNumber_OperatorNumber
Rampart_Operators = [
    '3_001', '6_001', '1_002',
    '4_002', '3_004', '4_004', '1_005', '4_005',
    '3_006', '4_006', '3_007', '4_007', '1_008',
    '4_008', '1_019', '4_019', '2_022', '3_022', '4_023',
    '1_030', '1_031'
]
# Note the index here is just the OperatorNumber
Baseline_Operators = [
        '001', '002','003', '004', '005', '006',
    '007', '008',
    '019', '020', '021', '022', '023',
    '024', '026', '027', '028', '029',
    '030', '031'
]

# %%
# File paths for all pertinent CSVs
file_paths = {
    "lead_max_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Maximum Values\\lead_max_cases.csv",
    "rampart_max_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Maximum Values\\rampart_max_cases.csv",
    "baseline_max_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_max_cases.csv",
    "lead_min_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Minimum Values\\lead_min_cases.csv",
    "rampart_min_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Minimum Values\\rampart_min_cases.csv",
    "baseline_min_cases": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_min_cases.csv",
    "lead_cases_ranges": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Range Values\\lead_cases_ranges.csv",
    "rampart_cases_ranges": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Range Values\\rampart_cases_ranges.csv",
    "baseline_cases_ranges": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_range_cases.csv",
    "lead_sum_duration_inside": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Sum of Duration Inside\\lead_cases_sum_duration_inside.csv",
    "rampart_sum_duration_inside": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Sum of Duration Inside\\rampart_cases_sum_duration_inside.csv",
    "baseline_sum_duration_inside": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_sum_duration_inside.csv",
    "lead_sum_duration_above": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Sum of Duration Above\\lead_cases_sum_duration_above.csv",
    "rampart_sum_duration_above": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Sum of Duration Above\\rampart_cases_sum_duration_above.csv",
    "baseline_sum_duration_above": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_sum_duration_above.csv",
    "lead_sum_duration_below": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Sum of Duration Below\\lead_cases_sum_duration_below.csv",
    "rampart_sum_duration_below": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Sum of Duration Below\\rampart_cases_sum_duration_below.csv",
    "baseline_sum_duration_below": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_sum_duration_below.csv",
    "lead_mean_inside": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Mean Inside Values\\lead_cases_mean_inside.csv",
    "rampart_mean_inside": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Mean Inside Values\\rampart_cases_mean_inside.csv",
    "baseline_mean_inside": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_mean_inside.csv",
    "lead_mean_above": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Mean Above Values\\lead_cases_mean_above.csv",
    "rampart_mean_above": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Mean Above Values\\rampart_cases_mean_above.csv",
    "baseline_mean_above": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_mean_above.csv",
    "lead_mean_below": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Mean Below Values\\lead_cases_mean_below.csv",
    "rampart_mean_below": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Mean Below Values\\rampart_cases_mean_below.csv",
    "baseline_mean_below": "C:\\Users\\jrzem\\OneDrive - Seton Hill University\\Coding Applications\\Harvard Study\\CSVs\\Baseline Values\\baseline_mean_below.csv",
}

# Read each CSV into a DataFrame
csv_data = {name: pd.read_csv(path) for name, path in file_paths.items()}
